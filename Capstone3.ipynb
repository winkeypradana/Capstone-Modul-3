# %% [markdown]
# # **Travel Insurance Classification** #
#
#
# **Created by: Novta Winkey Pradana**
#
# ---

# %% [markdown]
# # **Business Problem Understanding** #

# %% [markdown]
# ## **Context :** ##
#
# The global travel insurance industry is experiencing significant growth. In 2021, the global market value was USD 17.8 billion, and analysts forecast that the matter will increase at a compound annual growth rate (CAGR) of 15.4% from [2022 to 2030](https://www.grandviewresearch.com/industry-analysis/travel-insurance-market-report#:~:text=Report%20Overview%20The%20global%20travel,for%20the%20travel%20insurance%20market)​. Tourism demand and technological developments drive this growth, raising awareness of the importance of travel [insurance](https://www.gminsights.com/industry-analysis/travel-insurance-market#:~:text=Travel%20Insurance%20Market%20size%20was,the%20importance%20of%20travel%20insurance). In response to this, travel insurance companies can increase customer satisfaction and company profitability by using customer data to predict and manage [claims](https://www.mckinsey.com/industries/financial-services/our-insights/insurance/elevating-customer-experience-a-win-win-for-insurers-and-customers).
#
# In the digital era, adapting to the latest technology is the key to exploiting market potential that continues to grow. Innovations like machine learning and AI have changed how travel insurance companies operate, from improving customer service to speeding up the [claims process](http://www.itij.com/latest/long-read/tech-transforming-travel-insurance). In addition, technology also enhances differentiated customer experience, which is very important in attracting and retaining customers in a [competitive market](http://www.itij.com/latest/long-read/tech-transforming-travel-insurance).
#
#
# Targets:
#
# 0: Did not make a claim
#
# 1: Make a claim

# %% [markdown]
# ## **Problem Statement :** ##
#
# <span style="color:yellow">The stakeholders</span> in this matter are <span style="color:yellow">the manager of the risk and claims departement and the marketing manager at the travel insurance company</span>. <span style="color:yellow">The problem is that not all policyholders submit claims</span>, and those who do submit claims may experience varying levels of claim acceptance. The challenge lies in identifying patterns and factors that predict the likelihood of filing a claim. If the company can identify these factors, <span style="color:yellow">it can help insurance companies simplify their risk management processes, set premiums more accurately, and improve targeting and customer service</span> .

# %% [markdown]
# ## **Goals :** ##
#
# Based on the previously explained problems,<span style="color:yellow"> a model is needed to predict which customers are most likely to submit a claim</span>.
# This model allows travel insurance companies to:
# 1. Adjust their risk assessment and pricing strategy.
# 2. Identify potential high-risk customers and offer customized travel insurance packages.
# 3. Improve preventive customer service for tourists who may need assistance.

# %% [markdown]
# ## **Analytic Approach :** ##
#
# To solve stakeholder problems in the travel insurance industry, I will analyze data to find patterns from existing features and <span style="color:yellow">develop a claims prediction model using machine learning techniques</span>. This model will process and analyze historical customer data to identify ways to influence the likelihood of a claim filing. Once the model has been developed and tested, <span style="color:yellow">risk and claims management departments can use it to adjust risk assessment and premium pricing. Furthermore, marketing and sales teams can leverage the results of this analysis to target high-risk customers with tailored products. In contrast, customer service teams can proactively offer support and preventative services to customers who need help</span>. This approach aims to enhance risk management efficiency and accuracy and improve customer satisfaction and retention.

# %% [markdown]
# ## **Metrix Evaluation :** ##
#
# <p align="center">
#   <img src="https://drive.google.com/uc?id=1y6a7WzH5c5C6uSn2diVAMQ0iiC8EayDV" alt="Gambar dari Google Drive" style="display: block; margin: 0 auto;">
# </p>
#
# - TP: The model predicts prospective travelers who make claims to make claims.
# - TN: The model predicts that prospective travelers who do not make a claim will not make a claim.
# - FP: The model predicts that prospective travelers who do not make a claim will make a claim.
# - FN: The model predicts that prospective travelers who make claims will not make claims.
#
# There are two types of errors:
# - Error type 1 (FP):
# Consequences: Waste marketing costs and company resources.
# - Error type 2 (FN):
# Consequences: Loss of potential candidates.
#
# However, further analysis is needed by assessing the costs of the errors caused to determine priority treatment for these two types of errors. Using the annual report at PT Asuransi Harta Aman Pratama Tbk for [2022](https://asuransi-harta.co.id/wp-content/uploads/2023/05/AnnualReport2022.pdf), the company incurred claims expenses of 153.63 billion rupiah and operating expenses of 126.07 billion. Assuming equal value for each insurance product the company offers, we will divide these amounts into seven equal parts. Since travel insurance at the company forms a part of a bundle that includes seven other insurances, we will distribute it equally among these seven parts. Below is the complete calculation:
#
# 1. Calculate the Value of Business Expenses and Travel Insurance Claim Value:
# - Total claims expenses in 2022: 153.63 billion rupiah
# - Total operating expenses in 2022: 126.07 billion rupiah
# - Value per insurance for claims: 153.63 billion/ 7 = 21.947 billion rupiah
# - Value per insurance for operating expenses: 126.07 billion/ 7 = 18.009 billion rupiah
# - For travel insurance: (21.947 billion/7) = <span style="color:yellow">3.135 billion rupiah</span>
# - For operating expenses: (18.009 billion/7) = <span style="color:yellow">2.573 billion rupiah</span>
#
# 2. Estimated cost of false positives (FP):
# - Direct Line Travel Insurance in the UK reports that claimants completely fabricate around [5%](http://www.itij.com/latest/long-read/how-travel-insurers-are-tackling-fraud) of travel insurance claims. Analysts use this figure to estimate the proportion of FP.
# So, the estimated FP costs are as follows:
#   - <span style="color:yellow">Total costs FP</span> = 5% of the value of travel insurance business expenses = 5% * 2.573 billion = <span style="color:yellow">128.65 million rupiah</span>.
#
# 3. Estimated cost of false negatives (FN):
# - There needs to be detailed information regarding the percentage of travel insurance companies making mistakes in estimates for potential consumer assessments. The investigation reveals an [11%](https://www.finder.com.au/do-travel-travel-insurance-companies-pay-claims#:~:text=Nearly%2090,every%20other%20category%20of%20insurance) rejection rate for travel insurance claims. This rate serves as a basis to assume the proportion of FN, indicating the general percentage of rejected travel insurance claims.
# So, the estimated FN costs are as follows:
#      - <span style="color:yellow"> Total cost of FN</span> = 11% of travel insurance value = 11% * 3.135 billion rupiah =<span style="color:yellow"> 344.85 million rupiah</span>.
#
# Based on an assessment of the error costs incurred, <span style="color:yellow">the result is that the FN value is greater than the FP</span>, so as much as possible, I will create a model that can reduce the FN costs so as not to lose potential candidates. According to [(Murphy, 2012)](http://noiselab.ucsd.edu/ECE228/Murphy_Machine_Learning.pdf) recall (sensitivity) becomes a very relevant metric because recall will measure the fraction of actual positive cases identified by the model, which is especially important for larger FNs than FPs.<span style="color:yellow"> So, based on considerations, the recall metric will be chosen as the primary metric</span>.

# %% [markdown]
# ## **Project Limitation :** ##

# %% [markdown]
# Dealing with imbalance dataset in classification problems impact on recall and precision trade off

# %% [markdown]
# # **Data Understanding** #

# %% [markdown]
# The problems explained in understanding business problems will be analyzed using the Travel Insurance dataset. The dataset contains historical data on travel insurance users who submitted claims and who didn't.
#
# Dataset source : [Link](https://drive.google.com/drive/folders/1iVx5k6tWglqfHb05o0DElg8JHg7VVG_J)
#
# Note:
# - Unbalanced dataset
# - There are categorical and numerical features
# - Each row of data represents customer travel insurance information

# %% [markdown]
# ### **Attributes Information**
#
# | **Attribute**                | **Data Type** | **Description**                                           |
# |----------------------------|---------------|---------------------------------------------------------|
# | Agency              | Object        | Name of agency     |
# | Agency Type         | Object        | Type of travel insurance agencies |
# | Distribution Channel          | Object        | Channel of travel insurance agencies |
# | Product Name    | Object        | Name of the travel insurance products                  |
# | Gender             | Object        | Gender of insured                           |
# | Duration           | Int64        | Duration of travel                            |
# | Destination      | Object         | Destination of travel            |
# | Net Sales      | Float64       | Amount of sales of travel insurance policies            |
# | Commission (in value) | Float64         | Commission received for travel insurance agency                 |
# | Age      | Int64         | Age of insured                      |
# | **Claim**  | **Object**         | **Claim status (Target)**                    |

# %% [markdown]
# Based on the research conducted by [Leggat and Leggat in 2022](https://pubmed.ncbi.nlm.nih.gov/12044271/), as detailed in their study, ten attributes significantly influence travel insurance claims:
#
# 1. Medical and dental conditions
# 2. Age
# 3. Type of claim
# 4. Etiology of the claim
# 5. Utilization of emergency services
# 6. Location
# 7. Sex and occupation
# 8. Duration and purpose of the trip
# 9. Level of insurance coverage
# 10. A general category of the claim
#
# However, the study identifies 'sex and occupation' as having less impact on insurance claims. My dataset encompasses several of these influential attributes identified by Leggat and Leggat. I will set limitations for the aspects not present in my dataset. In line with the study's findings, I have decided not to use the gender attribute in my analysis, considering its minimal influence on claims. I will continue using other features outside Leggat and Leggat's research in my analysis.

# %% [markdown]
# ## Load Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import missingno

from scipy import stats
from scipy.stats import yeojohnson, probplot
from scipy.stats import pointbiserialr
from tabulate import tabulate
from scipy.stats import mannwhitneyu
from scipy.stats import chi2_contingency

# Feature Engineering
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, OrdinalEncoder, RobustScaler, MinMaxScaler, StandardScaler
from sklearn.compose import ColumnTransformer
import category_encoders as ce
from sklearn.preprocessing import PolynomialFeatures

# Model Selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV,StratifiedKFold,train_test_split, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
import lightgbm as lgb
from sklearn.metrics import f1_score, accuracy_score, recall_score, precision_score, classification_report, roc_curve, roc_auc_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# Imbalance Dataset
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import SMOTE

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load Dataset

# %%
# Load dataset
with open("data_travel_insurance.csv","r") as file:
    data = pd.read_csv(file)

# Copy dataset
dfti= data.copy(deep=True)

# %% [markdown]
# ### **Convert target into numeric**

# %% [markdown]
# Before start data skimming, I will convert the target column into numeric.

# %%
from sklearn.model_selection import train_test_split

# Convert target into numeric
dfti['Claim'] = np.where(dfti['Claim']=='Yes', 1, 0)

# %% [markdown]
# ## **Skimming Data**

# %% [markdown]
# In the first phase of data skimming, we conducted a preliminary examination of the travel insurance dataset. This process included reviewing the first five rows and assessing the attribute information. Our primary objectives were to understand the scope of the data, decipher the descriptions of each attribute, understand what each row represents, and discern the relevance of these attributes in the business context.

# %%
dfti.head()
# Out:
#   Agency    Agency Type Distribution Channel              Product Name Gender  \
# 0    C2B       Airlines               Online        Annual Silver Plan      F
# 1    EPX  Travel Agency               Online         Cancellation Plan    NaN
# 2    JZI       Airlines               Online                Basic Plan      M
# 3    EPX  Travel Agency               Online  2 way Comprehensive Plan    NaN
# 4    C2B       Airlines               Online               Bronze Plan      M
#
#    Duration    Destination  Net Sales  Commision (in value)  Age  Claim
# 0       365      SINGAPORE      216.0                  54.0   57      0
# 1         4       MALAYSIA       10.0                   0.0   33      0
# 2        19          INDIA       22.0                   7.7   26      0
# 3        20  UNITED STATES      112.0                   0.0   59      0
# 4         8      SINGAPORE       16.0                   4.0   28      0

# %%
dfti[dfti['Duration']==0].count()
# Out:
# Agency                  47
# Agency Type             47
# Distribution Channel    47
# Product Name            47
# Gender                  31
# Duration                47
# Destination             47
# Net Sales               47
# Commision (in value)    47
# Age                     47
# Claim                   47
# dtype: int64

# %%
# Checking the data type for each column and classifying them as numeric or categorical
def check_data_type(series):
    if pd.api.types.is_numeric_dtype(series):
        return 'Numerical'
    else:
        return 'Categorical'

# Apply the function to each column and create a new data frame for the results.
data_types = dfti.apply(check_data_type)

# Create a data frame with the required information
data_info_df = pd.DataFrame({
    'feature'            : dfti.columns.values,
    'data_type'          : dfti.dtypes.values,
    'data_type_variable' : data_types.values,
    'null_value(%)'      : dfti.isna().mean().values * 100,
    'n_unique'           : dfti.nunique().values,
    'duplicate'          : [dfti.duplicated().sum()] * len(dfti.columns),
    'Negative_value_num' : [len(dfti[col][dfti[col] < 0])/ len(dfti) * 100 if pd.api.types.is_numeric_dtype(dfti[col]) else 0 for col in dfti.columns],
    'Zero_value_num'     : [len(dfti[col][dfti[col] == 0])/ len(dfti) * 100 if pd.api.types.is_numeric_dtype(dfti[col]) else 0 for col in dfti.columns],
    'Zero_value_obj'     : [len(dfti[col][dfti[col] == ''])/ len(dfti) * 100 if pd.api.types.is_string_dtype(dfti[col]) else 0 for col in dfti.columns],
    'sample_unique'      : [dfti[col].unique() for col in dfti.columns],
}).round(3)

data_info_df
# Out:
#                  feature data_type data_type_variable  null_value(%)  \
# 0                 Agency    object        Categorical          0.000
# 1            Agency Type    object        Categorical          0.000
# 2   Distribution Channel    object        Categorical          0.000
# 3           Product Name    object        Categorical          0.000
# 4                 Gender    object        Categorical         71.393
# 5               Duration     int64          Numerical          0.000
# 6            Destination    object        Categorical          0.000
# 7              Net Sales   float64          Numerical          0.000
# 8   Commision (in value)   float64          Numerical          0.000
# 9                    Age     int64          Numerical          0.000
# 10                 Claim     int64          Numerical          0.000
#
#     n_unique  duplicate  Negative_value_num  Zero_value_num  Zero_value_obj  \
# 0         16       4667               0.000           0.000             0.0
# 1          2       4667               0.000           0.000             0.0
# 2          2       4667               0.000           0.000             0.0
# 3         26       4667               0.000           0.000             0.0
# 4          2       4667               0.000           0.000             0.0
# 5        437       4667               0.005           0.106             0.0
# 6        138       4667               0.000           0.000             0.0
# 7       1006       4667               1.090           2.912             0.0
# 8        915       4667               0.000          55.777             0.0
# 9         89       4667               0.000           0.005             0.0
# 10         2       4667               0.000          98.473             0.0
#
#                                         sample_unique
# 0   [C2B, EPX, JZI, CWT, LWC, ART, CSR, SSI, RAB, ...
# 1                           [Airlines, Travel Agency]
# 2                                   [Online, Offline]
# 3   [Annual Silver Plan, Cancellation Plan, Basic ...
# 4                                         [F, nan, M]
# 5   [365, 4, 19, 20, 8, 2, 25, 90, 24, 43, 103, 37...
# 6   [SINGAPORE, MALAYSIA, INDIA, UNITED STATES, KO...
# 7   [216.0, 10.0, 22.0, 112.0, 16.0, 50.0, 78.0, 8...
# 8   [54.0, 0.0, 7.7, 4.0, 9.1, 63.21, 10.5, 11.88,...
# 9   [57, 33, 26, 59, 28, 36, 22, 39, 27, 48, 43, 5...
# 10                                             [0, 1]

# %%
# Displays descriptive statistics from numerical and categorical variables
display(dfti.describe(), dfti.describe(include='object'))
# Out:
#            Duration     Net Sales  Commision (in value)           Age  \
# count  44328.000000  44328.000000          44328.000000  44328.000000
# mean      49.424292     40.550948              9.707692     39.925600
# std      109.153961     48.661970             19.625637     13.954926
# min       -1.000000   -357.500000              0.000000      0.000000
# 25%        9.000000     18.000000              0.000000     35.000000
# 50%       22.000000     26.500000              0.000000     36.000000
# 75%       53.000000     48.000000             11.550000     43.000000
# max     4881.000000    810.000000            283.500000    118.000000
#
#               Claim
# count  44328.000000
# mean       0.015273
# std        0.122636
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#        Agency    Agency Type Distribution Channel       Product Name Gender  \
# count   44328          44328                44328              44328  12681
# unique     16              2                    2                 26      2
# top       EPX  Travel Agency               Online  Cancellation Plan      M
# freq    24656          32113                43572              12979   6504
#
#        Destination
# count        44328
# unique         138
# top      SINGAPORE
# freq          9267

# %% [markdown]
# Insight from data skimming:
#
# - **Dataset Preview**:
#   - The data includes a variety of columns such as 'Agency', 'Agency Type', 'Distribution Channel', 'Product Name', 'Gender', 'Duration', 'Destination', 'Net Sales', 'Commision (in value)', 'Age', and 'Claim'.
#   - There are missing values in the 'Gender' column, with approximately 71% of data unavailable.
#
# - **Dataset Size**:
#   - The dataset contains 35,462 rows and 11 columns, indicating its size and complexity.
#
# - **Data Information**:
#   - Columns 'Agency', 'Agency Type', 'Distribution Channel', 'Product Name', 'Gender', 'Destination', and 'Claim' are categorical data.
#   - 'Duration', 'Net Sales', 'Commision (in value)', and 'Age' are numerical data.
#   - The highest proportion of missing values is in the 'Gender' column.
#   - There is considerable variation in the number of unique values for each feature.
#   - No significant negative values are found in numerical data, but some numerical columns have a substantial percentage of zero values.
#   - Examples of unique values for each feature provide an initial overview of the variation in the data.
#
# - **Descriptive Statistics**:
#   - Statistics for numerical variables show the range of data, mean, standard deviation, and minimum and maximum values.
#   - 'Duration' has a wide range with a maximum value of 4,881 days, while 'Age' has a maximum value of 118 years, which may indicate the presence of outliers or data entry errors.
#   - Categorical columns show the number of unique categories, the frequency of the most common type, and the total count of each kind.

# %% [markdown]
# After thoroughly skimming through the data, I've prepared a cohesive summary that bridges the dataset's attributes with their relevance in the business context and an overview of the diverse values encountered within the dataset.
#
# **Business Context and Attribute Relevance:**
#
# 1. **Sales Mechanisms**: The attributes 'Agency', 'Agency Type', and 'Distribution Channel' shed light on the various strategies and channels used for selling insurance policies.
# 2. **Product Details and Financials**: 'Product Name', 'Duration', 'Destination', 'Net Sales', and 'Commission (in value)' provide a deep dive into the specifics of the insurance products offered and their financial aspects.
# 3. **Customer Demographics**: Understanding the demographics of customers is facilitated by the 'Gender' and 'Age' attributes.
# 4. **Claim Outcomes**: The 'Claim' attribute indicates whether a policyholder has made an insurance claim.
#
# **Dataset Values Analysis:**
#
# 1. **Variety in Categories**: Attributes like 'Agency', 'Product Name', and 'Destination' are rich with unique categories, showcasing a diverse range of options and choices.
# 2. **Numerical Ranges**: 'Duration', 'Net Sales', 'Commission', and 'Age' span various numerical ranges, indicating different customer choices and policy details.
# 3. **Gender Insights**: The 'Gender' category, despite having missing values, adds a layer of demographic insight.
# 4. **Claim Decisions**: The 'Claim' category is binary, consisting of 'Yes' or 'No', directly reflecting the outcome of insurance policies.
#
# In summary, this dataset is comprehensive and relevant for delving into queries related to travel insurance claims. Its completeness and depth of information make it a viable candidate for further detailed analysis.

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# Before we delve into building predictive models, it is crucial to understand the distribution of our numeric features. This step is part of our exploratory data analysis (EDA), which will help us uncover patterns, detect outliers, and test assumptions about the data. We'll start by visualizing the distribution of numeric variables using histograms and box plots, essential tools in [EDA](https://www.codecademy.com/article/eda-data-visualization#) that provide insights into the data's minimum and maximum values, central location, spread, and unusual patterns like skewness or multimodality​​. Moreover, we will perform the Anderson-Darling test to assess the normality of our distributions statistically. This test helps determine if the data is close enough to a normal distribution for applying statistical tools, a crucial step in validating many of the [assumptions underlying predictive modeling](https://www.isixsigma.com/dictionary/anderson-darling-normality-test/).

# %% [markdown]
# ### **Numerical Feature** ###

# %% [markdown]
# #### **Data Distribution**

# %% [markdown]
# ##### **Distribution of Numerical Data With Boxplot**

# %%
# Creating box plots for the numerical features
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Box plot for 'Duration'
sns.boxplot(data=dfti, x='Duration', ax=axes[0, 0])
axes[0, 0].set_title('Box Plot of Duration')

# Box plot for 'Net Sales'
sns.boxplot(data=dfti, x='Net Sales', ax=axes[0, 1])
axes[0, 1].set_title('Box Plot of Net Sales')

# Box plot for 'Commision (in value)'
sns.boxplot(data=dfti, x='Commision (in value)', ax=axes[1, 0])
axes[1, 0].set_title('Box Plot of Commision (in value)')

# Box plot for 'Age'
sns.boxplot(data=dfti, x='Age', ax=axes[1, 1])
axes[1, 1].set_title('Box Plot of Age')

plt.tight_layout()
plt.show()

# Calculating skewness
skewness = dfti[['Duration', 'Net Sales', 'Commision (in value)', 'Age']].skew().to_frame(name='Skewness')
skewness
# Out:
#                        Skewness
# Duration              24.635427
# Net Sales              3.325892
# Commision (in value)   4.041866
# Age                    2.984204

# %% [markdown]
# Insight :
# | Feature              | Skewness | Skewness Description                                   | Box Plot Findings                                       |
# |----------------------|----------|--------------------------------------------------------|---------------------------------------------------------|
# | Duration             | 24.63    | Highly right-skewed with several extremely high values. | Many high outliers, low median and quartiles.           |
# | Net Sales            | 3.32     | Right-skewed with some high values.                     | Many high outliers, low median.                         |
# | Commission (in value)| 4.04     | Right-skewed, similar to Net Sales.                     | Many high outliers, low median.                         |
# | Age                  | 2.98     | Slightly right-skewed.                                  | Some high outliers, more evenly distributed.            |

# %% [markdown]
# ##### **Distribution of Numerical Data With Histogram**

# %%
# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Creating plots
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Histogram for 'Duration'
sns.histplot(dfti['Duration'], bins=30, kde=True, ax=axes[0, 0])
axes[0, 0].set_title('Distribution of Duration')

# Histogram for 'Net Sales'
sns.histplot(dfti['Net Sales'], bins=30, kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Distribution of Net Sales')

# Histogram for 'Commision (in value)'
sns.histplot(dfti['Commision (in value)'], bins=30, kde=True, ax=axes[1, 0])
axes[1, 0].set_title('Distribution of Commision (in value)')

# Histogram for 'Age'
sns.histplot(dfti['Age'], bins=30, kde=True, ax=axes[1, 1])
axes[1, 1].set_title('Distribution of Age')

plt.tight_layout()
plt.show()

# %% [markdown]
# Insight :
#
# | Feature              | Description of Distribution                         | Insights from Histogram                               |
# |----------------------|-----------------------------------------------------|-------------------------------------------------------|
# | Duration             | Concentrated at lower values with extreme highs.    | Majority of policies have short durations. Significant presence of outliers with very long durations. |
# | Net Sales            | Concentrated at lower values with some extreme highs.| Most sales are moderate, but there are outliers indicating very high sales in a few cases. |
# | Commission (in value)| Mostly lower values with some extreme highs.        | Majority of transactions yield low commissions, but there are outliers with exceptionally high commissions. |
# | Age                  | More evenly distributed with some high outliers.    | Age distribution is relatively even, but includes some outliers at higher ages. |

# %% [markdown]
# ##### **Distribution of Numerical Data With The Anderson-Darling Test**

# %%
# Selecting numeric columns
numeric_columns = dfti.select_dtypes(include=['number']).columns

# Conducting the Anderson-Darling Test for each numeric column
test_results = []
for column in numeric_columns:
    stat, critical_values, _ = stats.anderson(dfti[column], dist='norm')
    conclusion = 'Not normally distributed' if stat > critical_values[2] else 'Normally distributed'
    test_results.append([column, stat, critical_values[2], conclusion])

# Creating a table of the results
headers = ['Column', 'Statistic', 'Critical Value (5%)', 'Conclusion']
formatted_table = tabulate(test_results, headers=headers, tablefmt='pretty')
print(formatted_table)
# Out:
# +----------------------+--------------------+---------------------+--------------------------+
# |        Column        |     Statistic      | Critical Value (5%) |        Conclusion        |
# +----------------------+--------------------+---------------------+--------------------------+
# |       Duration       | 7084.944678817235  |        0.787        | Not normally distributed |
# |      Net Sales       | 4106.2513905529995 |        0.787        | Not normally distributed |
# | Commision (in value) | 6443.789885289276  |        0.787        | Not normally distributed |
# |         Age          | 3393.3198345600395 |        0.787        | Not normally distributed |
# |        Claim         | 16847.95528992155  |        0.787        | Not normally distributed |
# +----------------------+--------------------+---------------------+--------------------------+

# %% [markdown]
# | Feature              | Insight From Anderson-Darling Test                                                                                          |
# |----------------------|---------------------------------------------------------------------------------------------------|
# | Duration             | The duration is heavily skewed, likely due to extreme outliers. Care should be taken in handling these for analysis. |
# | Net Sales            | Sales figures are varied, with some transactions significantly higher than most, indicating potential outliers or heavy-tailed distribution. |
# | Commission (in value)| The commission has a high variation with some extreme values, suggesting a need for robust statistical methods that do not assume normality. |
# | Age                  | Age distribution is not normal, possibly due to high-age outliers. This could affect modeling if age is a predictor. |

# %% [markdown]
# #### **Data Correlation**
#
# ##### **Point-Biserial Correlation**

# %% [markdown]
# After establishing a foundational understanding of our data distributions, we progressed to exploring the relationships between the numeric features and the binary 'Claim' target variable using point-biserial correlation.The point-biserial correlation assesses relationships between continuous variables (like 'Age', 'Duration', and 'Net Sales') and the binary 'Claim' variable. This method is chosen for its effectiveness in quantifying the association between continuous and dichotomous variables, offering a clear range (-1 to 1) for interpreting the correlation's strength and direction. Its application is ideal for datasets with naturally dichotomous outcomes, making it a relevant and insightful tool in our exploratory data analysis ([Laerd Statistics](https://statistics.laerd.com/spss-tutorials/point-biserial-correlation-using-spss-statistics.php), [Statistics Solutions](https://www.statisticssolutions.com/point-biserial-correlation-coefficient/)).

# %%
# Make a copy of the dataframe
dfx = dfti.copy()

# Convert 'Claim' to numeric, coercing errors
dfx['Claim'] = pd.to_numeric(dfx['Claim'], errors='coerce')

# Identify numeric features in the dataset
numeric_features = dfx.select_dtypes(include=['float64', 'int64']).columns.tolist()

# Compute point-biserial correlation for each numeric feature with the target 'Claim'
point_biserial_correlations = {}
for feature in numeric_features:
    if feature != 'Claim':
        correlation, _ = pointbiserialr(dfx[feature], dfx['Claim'])
        point_biserial_correlations[feature] = correlation

# Converting the results to a DataFrame
correlation_table = pd.DataFrame.from_dict(point_biserial_correlations, orient='index', columns=['Correlation'])

# Sort the table by correlation values
correlation_table.sort_values(by='Correlation', ascending=False, inplace=True)

# Converting the correlation table to a format suitable for tabulate
correlation_table_tabulate = correlation_table.reset_index()
correlation_table_tabulate.columns = ['Feature', 'Correlation']

# Displaying the table using tabulate
print(tabulate(correlation_table_tabulate, headers='keys', tablefmt='grid', showindex=False))
# Out:
# +----------------------+---------------+
# | Feature              |   Correlation |
# +======================+===============+
# | Net Sales            |     0.135676  |
# +----------------------+---------------+
# | Commision (in value) |     0.102868  |
# +----------------------+---------------+
# | Duration             |     0.0654275 |
# +----------------------+---------------+
# | Age                  |    -0.0121754 |
# +----------------------+---------------+

# %% [markdown]
# | Feature              | Correlation | Interpretation |
# |----------------------|-------------|----------------|
# | Net Sales            | 0.135       | There is a weak positive relationship between 'Net Sales' and the likelihood of a claim. As the net sales increase, there is a slightly higher probability of a claim being made, suggesting that higher-value policies might be more prone to claims. |
# | Commission (in value)| 0.102      | Shows a weak positive correlation. Policies with higher commissions might be associated with a somewhat higher probability of a claim, indicating that policies providing more incentive to agents might be more prone to claims. |
# | Duration             | 0.065      | A very weak positive relationship. Longer travel duration has a marginally higher association with the likelihood of a claim, possibly due to increased exposure or risk on longer trips. |
# | Age                  | -0.012     | A very weak negative correlation, almost negligible. It suggests that as age increases, the likelihood of a claim slightly decreases, but this relationship might not be practically significant. |
#
# **Comprehensive Insights Corellation between Claim and Numerical Features :**
# - **Net Sales** and **Commission** show the most notable positive correlations with claims, though still weak. These variables could be significant in risk management strategies.
# - **Duration** shows a fragile positive relationship, indicating it may not be a substantial claim predictor.
# - **Age** has a negligible negative correlation, suggesting it might not be a significant factor in predicting claims.

# %% [markdown]
# Employing point-biserial correlation, we quantitatively assessed how each numeric feature correlates with the likelihood of a claim. This analysis offered preliminary insights into which features might be more influential in predicting claims. The next step is to study bivariate analysis based on the insights gained from correlation analysis.

# %% [markdown]
# #### **Bivariate Correlation**

# %%
# Separate the data into two groups based on 'Claim'
df_claim = dfx[dfx['Claim'] == 1]
df_no_claim = dfx[dfx['Claim'] == 0]

# Identify numeric features for comparison
numeric_features = dfx.select_dtypes(include=['float64', 'int64']).columns.tolist()

# Remove 'Claim' from the list of numeric features
numeric_features.remove('Claim')

# Plotting distributions and performing statistical tests
results = []
for feature in numeric_features:
    plt.figure(figsize=(10, 5))
    sns.boxplot(x='Claim', y=feature, data=dfti)
    plt.title(f"Distribution of {feature} by Claim Status")
    plt.show()

    # Mann-Whitney U test for non-normal distributions
    stat, p = mannwhitneyu(df_claim[feature], df_no_claim[feature])
    results.append({'Feature': feature, 'Mann-Whitney U Statistic': stat, 'p-value': p})

# Converting the results to a DataFrame
mann_whitney_results = pd.DataFrame(results)
mann_whitney_results.sort_values(by='p-value', inplace=True)
mann_whitney_results
# Out:
#                 Feature  Mann-Whitney U Statistic       p-value
# 2  Commision (in value)                21104369.5  1.504970e-98
# 1             Net Sales                21227978.0  4.792142e-85
# 0              Duration                18138848.0  2.430812e-24
# 3                   Age                13031329.5  5.464729e-08

# %% [markdown]
# Insight:
#
# 1. From Boxplot:
#     -   Duration: If the median duration is higher in the 'Claim' group, it suggests longer trips are more likely to have claims.
#     -   Net Sales: Higher median net sales in the 'Claim' group could indicate higher-value policies are more prone to claims.
#     -   Commission (in value): A higher median commission in the 'Claim' group might imply that policies with higher commissions see more claims.
#     -   Age: A notable difference in median age between groups could suggest an age-related trend in filing claims
#
# 2. From Mann-Whitney Test:
#     -   Duration: Insurance coverage duration shows a significant but less pronounced difference between the groups compared to Commission and Net Sales.
#     -   Net Sales: Net Sales also exhibits a significant difference in distribution between the groups, suggesting it's closely related to claim occurrences.
#     -   Commission (in value): The distribution of 'Commission (in value)' shows the most significant difference between the Claim and No Claim groups, indicating a strong association with the likelihood of a claim.
#     -   Age: Age shows the least significant difference among the tested features but still indicates some association with claim status.

# %% [markdown]
# Overall Insight from Bivariate Correlation:
#
# The boxplots and Mann-Whitney U test results together suggest that features like duration, net sales, and commission have a significant association with the likelihood of a claim being made. These insights can be instrumental for risk assessment and policy pricing strategies in travel insurance.

# %% [markdown]
# After completing our bivariate correlation analysis, where we examined the relationships between numeric features and the 'Claim' target variable, we now explore our dataset's categorical dimensions.

# %% [markdown]
# ### **Categorical Feature** ###

# %% [markdown]
# First, start by evaluating how often each category appears in the dataset. This evaluation provides an idea of the frequency and distribution of classes. Next, test the relationship between categorical features and targets with the Chi-square test, which is the right choice for categorical data. Finally, bivariate analysis with cross-tabulation provides a deeper understanding of the relationship between categorical and target feature pairs.

# %% [markdown]
# ##### **Distribution of Categorical Data With Barplot**

# %%
# Identify categorical features in the dataset
categorical_features = dfti.select_dtypes(include=['object']).columns.tolist()

# Define other categorical features excluding 'Destination' and 'Product Name'
other_categorical_features = [feature for feature in categorical_features if feature not in ['Destination', 'Product Name', 'Agency']]

# Set the number of top categories to display
top_n = 10

# Setting up the figure size for multiple plots
plt.figure(figsize=(15, 25))
plt.subplots_adjust(hspace=0.5)

# Plot for 'Agency' with top 10 categories
plt.subplot(len(other_categorical_features) + 3, 1, 1)
sns.countplot(y='Agency', data=dfti, order=dfti['Agency'].value_counts().index[:top_n], palette='Set2')
plt.title('Top 10 Agencies')
plt.xlabel('Frequency')
plt.ylabel('Agency')

# Plot for 'Destination' with top 10 categories
plt.subplot(len(other_categorical_features) + 3, 1, 2)
sns.countplot(y='Destination', data=dfti, order=dfti['Destination'].value_counts().index[:top_n], palette='Set3')
plt.title('Top 10 Destinations')
plt.xlabel('Frequency')
plt.ylabel('Destination')

# Plot for 'Product Name' with top 10 categories
plt.subplot(len(other_categorical_features) + 3, 1, 3)
sns.countplot(y='Product Name', data=dfti, order=dfti['Product Name'].value_counts().index[:top_n], palette='Set1')
plt.title('Top 10 Product Names')
plt.xlabel('Frequency')
plt.ylabel('Product Name')

# Plots for other categorical features with unique colors for each category
for i, feature in enumerate(other_categorical_features, 4):
    plt.subplot(len(other_categorical_features) + 3, 1, i)
    # Using a different color palette for each category within the feature
    unique_categories = dfti[feature].nunique()
    palette = sns.color_palette("husl", n_colors=unique_categories)
    sns.countplot(y=feature, data=dfti, palette=palette)
    plt.title(f'Distribution of {feature}')
    plt.xlabel('Frequency')
    plt.ylabel(feature)

plt.tight_layout()
plt.show()

# %% [markdown]
# Insight :
# 1. Agency and Product Distribution: The data indicates a market dominated by one agency, EPX, and shows that cancellation plans are the most commonly purchased insurance products. This result suggests that travelers prioritize flexibility in their travel arrangements.
# 2. Destination Preferences: The top travel destinations are regional, with Singapore, Thailand, and Malaysia leading, which may reflect regional travel patterns or dataset bias.
# 3. Sales and Claims: Travel agencies are the main channel for insurance distribution, heavily favoring online sales. There is a significant gender imbalance in the purchase of travel insurance. Additionally, the number of claims filed could be higher than the number of policies sold, indicating that most travelers do not experience events leading to claims.
#
# The travel insurance market is concentrated in significant agents and products, so it heavily favors online purchases and regional travel. A low claim rate indicates customer satisfaction or a gap in product usability and relevance. After this, we'll focus on data correlation.

# %% [markdown]
# #### **Data Correlation**
#
# ##### **Chi Square Test**

# %% [markdown]
# The [Chi-square test](https://pubmed.ncbi.nlm.nih.gov/28295394/#:~:text=URL%3A%20https%3A%2F%2Fpubmed) is a robust statistical method for determining if there is a significant association between two categorical variables. It is particularly relevant for our dataset because it can test whether the distribution of claims across different categories, like insurance agencies or plan types, is due to chance or signifies a natural correlation. This test is appropriate when the data do not require a normal distribution assumption and when variables are nominal or ordinal, as with our categorical data.​

# %%
# Identify categorical features
categorical_features = dfx.select_dtypes(include=['object']).columns.tolist()

# Initialize a dictionary to store Chi-square test results
chi_square_results = {}

# Conducting Chi-square tests
for feature in categorical_features:
    contingency_table = pd.crosstab(dfx[feature], dfx['Claim'])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    chi_square_results[feature] = {'Chi2 Statistic': chi2, 'p-value': p}

# Convert the results to a DataFrame for better visualization
chi_square_results_df = pd.DataFrame(chi_square_results).T

# Display the results
print(chi_square_results_df)
# Out:
#                       Chi2 Statistic        p-value
# Agency                   1466.488409  8.164566e-304
# Agency Type               476.972086  9.741264e-106
# Distribution Channel        0.000190   9.890165e-01
# Product Name             1683.528126   0.000000e+00
# Gender                      4.285241   3.844463e-02
# Destination               760.883436   3.571354e-87

# %% [markdown]
# Insight from chi-square test results:
#
# | Feature               | Insight |
# |----------------------|---------|
# | Agency               | There is a highly significant relationship between the agency selling the insurance policy and the likelihood of a claim. Specific institutional settings correlate with a propensity for higher or lower claims. |
# | Agency Type          | There is a significant relationship between the type of agency and claims, indicating that the likelihood of filing a claim differs between travel agencies and airlines. |
# | Distribution Channel | There is no significant relationship between the distribution channel and claims. The method of purchasing insurance (online or offline) does not significantly influence the possibility of a claim. |
# | Product Name         | There is a highly significant relationship between the insurance product name and claims, suggesting that certain insurance products are significantly more or less likely to be associated with claims. |
# | Gender               | There is a statistically significant, though weak, relationship between the policyholder's gender and claims, which may suggest that gender could influence claim behavior. |
# | Destination          | The significant relationship between travel destination and claims indicates that the destination of travel strongly influences the likelihood of a claim occurring. |

# %% [markdown]
# Based on the chi-square test results, we can draw some key conclusions and identify areas for further analysis. The test reveals strong correlations between factors like agency, agency type, product name, and destination with the incidence of travel insurance claims. In contrast, the distribution channel does not correlate significantly with claims. Gender, while showing a statistically significant correlation, presents a weaker relationship, suggesting nuances that merit deeper investigation.
#
# The next logical step is to conduct a bivariate analysis using cross-tabulation to bridge this analysis and gain a more comprehensive understanding. This approach will allow us to examine the interactions between pairs of categorical features and the target variable (claims) in more detail.

# %% [markdown]
# #### **Bivariate Correlation**

# %% [markdown]
# ##### **Cross Tabulation**

# %% [markdown]
# [Cross tabulation](https://www.alchemer.com/resources/blog/cross-tabulation/#) is a valuable technique for bivariate correlation analysis as it helps to clarify the relationship between two categorical variables, making complex data sets more manageable and insights more discernible. This approach is particularly useful in market research or survey analysis, where it can reveal patterns and connections that inform strategic decisions.

# %%
# Identify categorical features in the dataset
categorical_features = dfti.select_dtypes(include=['object']).columns.tolist()

# Perform cross-tabulation for each categorical feature against 'Claim'
cross_tab_results = {}
for feature in categorical_features:
    cross_tab = pd.crosstab(dfti[feature], dfti['Claim'])
    cross_tab_results[feature] = cross_tab

cross_tab_results.keys()  # Displaying the processed features

for feature, cross_tab in cross_tab_results.items():
    print(f"Cross-tabulation for {feature}:\n{cross_tab}\n")
# Out:
# Cross-tabulation for Agency:
# Claim       0    1
# Agency
# ADM        55    0
# ART       229    0
# C2B      5346  407
# CBH        68    1
# CCR       124    2
# CSR        67    1
# CWT      5916   64
# EPX     24523  133
# JWT       518    4
# JZI      4411   22
# KML       276    5
# LWC       426   29
# RAB       512    1
# SSI       760    5
# TST       352    2
# TTW        68    1
#
# Cross-tabulation for Agency Type:
# Claim              0    1
# Agency Type
# Airlines       11776  439
# Travel Agency  31875  238
#
# Cross-tabulation for Distribution Channel:
# Claim                     0    1
# Distribution Channel
# Offline                 745   11
# Online                42906  666
#
# Cross-tabulation for Product Name:
# Claim                                     0    1
# Product Name
# 1 way Comprehensive Plan               2329    7
# 2 way Comprehensive Plan               9246   95
# 24 Protect                              172    0
# Annual Gold Plan                        126   16
# Annual Silver Plan                      866  109
# Annual Travel Protect Gold               56    7
# Annual Travel Protect Platinum           32    2
# Annual Travel Protect Silver             55    4
# Basic Plan                             3818   16
# Bronze Plan                            2685  162
# Cancellation Plan                     12948   31
# Child Comprehensive Plan                  8    0
# Comprehensive Plan                      249    4
# Gold Plan                               225   12
# Individual Comprehensive Plan            48    0
# Premier Plan                            128    2
# Rental Vehicle Excess Insurance        5916   64
# Silver Plan                            1444  108
# Single Trip Travel Protect Gold         128    7
# Single Trip Travel Protect Platinum      42    5
# Single Trip Travel Protect Silver       113    4
# Spouse or Parents Comprehensive Plan     12    1
# Ticket Protector                        760    5
# Travel Cruise Protect                   351    2
# Travel Cruise Protect Family              1    0
# Value Plan                             1893   14
#
# Cross-tabulation for Gender:
# Claim      0    1
# Gender
# F       5923  254
# M       6283  221
#
# Cross-tabulation for Destination:
# Claim           0   1
# Destination
# ANGOLA          1   0
# ARGENTINA      13   0
# ARMENIA         1   0
# AUSTRALIA    2548  30
# AUSTRIA        72   0
# ...           ...  ..
# VANUATU         4   0
# VENEZUELA       4   0
# VIET NAM     1185   9
# ZAMBIA          2   0
# ZIMBABWE        3   0
#
# [138 rows x 2 columns]

# %% [markdown]
# | Feature | Insight |
# | ------ | ------- |
# | Insurance Agency | Some agencies like C2B have higher claims, indicating possibly broader coverage or riskier customer profiles. |
# | Agency Type | Airlines see more claims than Travel Agency, suggesting riskier travel or a higher propensity to claim. |
# | Distribution Channel | More claims are filed Online, possibly due to convenience or increased customer awareness. |
# | Product Name | Bronze Plan and 2 way Comprehensive Plan have more claims, indicating they may offer more relevant coverage for riskier travels. |
# | Gender | Claims frequency is similar across genders, showing no significant difference in travel insurance claims. |
# | Travel Destination | Destinations like Australia and Viet Nam have higher claims, hinting at higher risks or a greater likelihood of travelers filing claims. |

# %% [markdown]
# Having completed the cross-tabulation as part of this project's exploratory data analysis (EDA), we've gained valuable insights into the relationships between categorical variables and our target variable. The next phase of our project will involve data preprocessing. In this phase, we'll focus on preparing the data for modeling.

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **Handling Missing Value** ##

# %%
# Display the count of null values per column
null_counts = dfti.isna().sum()

# Calculate the percentage of null values for each column
null_percentage = (dfti.isna().sum() / len(dfti)) * 100

# Combine the count and percentage into a DataFrame for easy viewing
null_summary = pd.DataFrame({
    'Feature': null_counts.index,
    'Null Counts': null_counts.values,
    'Percentage (%)': null_percentage.values
})

# Display the count of null values per column
null_summary
# Out:
#                  Feature  Null Counts  Percentage (%)
# 0                 Agency            0        0.000000
# 1            Agency Type            0        0.000000
# 2   Distribution Channel            0        0.000000
# 3           Product Name            0        0.000000
# 4                 Gender        31647       71.392799
# 5               Duration            0        0.000000
# 6            Destination            0        0.000000
# 7              Net Sales            0        0.000000
# 8   Commision (in value)            0        0.000000
# 9                    Age            0        0.000000
# 10                 Claim            0        0.000000

# %% [markdown]
# The percentage of missing values in the Gender column is 71%. However, to handle these missing values, I dropped the Gender column altogether because gender doesn't significantly impact the claims; as explained earlier, this step will be carried out in the feature engineering phase. Next, I proceeded to check for any duplicated values in the dataset.

# %% [markdown]
# ## **Handling Data Duplicated**

# %%
#Check duplicates
dfti.duplicated().sum()

#Show duplicates
duplic = dfti.duplicated
dfti[duplic]
# Out:
#       Agency    Agency Type Distribution Channel  \
# 331      EPX  Travel Agency               Online
# 360      EPX  Travel Agency               Online
# 473      EPX  Travel Agency               Online
# 488      EPX  Travel Agency               Online
# 636      EPX  Travel Agency               Online
# ...      ...            ...                  ...
# 44309    EPX  Travel Agency               Online
# 44311    CWT  Travel Agency               Online
# 44313    EPX  Travel Agency               Online
# 44315    EPX  Travel Agency               Online
# 44321    EPX  Travel Agency               Online
#
#                           Product Name Gender  Duration Destination  \
# 331                  Cancellation Plan    NaN         2   SINGAPORE
# 360                  Cancellation Plan    NaN         6    MALAYSIA
# 473                  Cancellation Plan    NaN        11    MALAYSIA
# 488                  Cancellation Plan    NaN         2   SINGAPORE
# 636           1 way Comprehensive Plan    NaN         3    MALAYSIA
# ...                                ...    ...       ...         ...
# 44309         2 way Comprehensive Plan    NaN        49    VIET NAM
# 44311  Rental Vehicle Excess Insurance    NaN         5    THAILAND
# 44313                Cancellation Plan    NaN         5       CHINA
# 44315         1 way Comprehensive Plan    NaN         5    THAILAND
# 44321                Cancellation Plan    NaN         4       ITALY
#
#        Net Sales  Commision (in value)  Age  Claim
# 331         10.0                  0.00   36      0
# 360         10.0                  0.00   36      0
# 473         10.0                  0.00   36      0
# 488         10.0                  0.00   36      0
# 636         20.0                  0.00   36      0
# ...          ...                   ...  ...    ...
# 44309       20.0                  0.00   36      0
# 44311       29.7                 17.82   38      0
# 44313       14.0                  0.00   36      0
# 44315       20.0                  0.00   36      0
# 44321       10.0                  0.00   36      0
#
# [4667 rows x 11 columns]

# %% [markdown]
# There are 4667 duplicate rows. I decided to drop the duplicate data and reset the index afterward.

# %%
# Drop data duplicates
dfti.drop_duplicates(inplace=True)

# Check for any remaining duplicates
number_of_duplicates = dfti.duplicated().sum()

# Reset the index after dropping duplicates
dfti.reset_index(drop=True, inplace=True)

# Check the new shape of the DataFrame
new_shape = dfti.shape

# Output the number of duplicates and the new DataFrame shape
print("Number of duplicates:", number_of_duplicates)
print("New DataFrame shape:", new_shape)
# Out:
# Number of duplicates: 0
# New DataFrame shape: (39661, 11)

# %% [markdown]
# After I dropped 4667 duplicate rows, I reset the index. 39661 rows remaining and no more exact data. After this, I will handle outliers.

# %% [markdown]
# ## **Handling Outlier**

# %% [markdown]
# A two-pronged approach is employed to handle outliers in the dataset: first, conducting descriptive statistical analysis to gain an overview of the central tendencies and dispersion, and second, utilizing boxplot examination to identify and understand the extent of the outliers visually. This comprehensive method ensures a thorough understanding of the data's distribution, aiding in making informed decisions about effectively addressing the outliers.

# %%
#Check statistics descriptive on numerical feature
dfti.describe()
# Out:
#            Duration     Net Sales  Commision (in value)           Age  \
# count  39661.000000  39661.000000          39661.000000  39661.000000
# mean      52.397822     42.342794             10.442622     39.930284
# std      113.542824     50.025244             20.355921     13.526346
# min       -1.000000   -357.500000              0.000000      0.000000
# 25%       11.000000     19.000000              0.000000     34.000000
# 50%       25.000000     29.000000              0.000000     36.000000
# 75%       57.000000     50.000000             11.880000     45.000000
# max     4881.000000    810.000000            283.500000    118.000000
#
#               Claim
# count  39661.000000
# mean       0.017019
# std        0.129345
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
#Check outlier on numerical feature
dfti.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# Based on the results of the boxplot analysis, it is evident that the entire dataset contains outliers. This observation highlights the presence of data points that significantly deviate from the typical range, indicating variability in the dataset that may warrant further investigation or consideration in the context of data analysis and interpretation. After this process, we will proceed to handle outliers in duration.

# %% [markdown]
# ### **Handling Outliers in Duration**
#
# To handle outliers in the duration column, I will bin the duration column based on the author's preferences by dividing the data based on the time range as follows:
#
# 1. 1-4 months = 1-120 days
# 2. 5-8 months = 121-241 days
# 3. 9-12 months = 242- 361 days
# 4. '>12 months = > 361 days

# %%
# Binning the 'Duration' column based on the specified ranges
bins_duration = [1, 120, 241, 361, dfti['Duration'].max()]
labels_duration = ["1-4 months", "5-8 months", "9-12 months", ">12 months"]

# Bin the 'Duration' data
dfti['Duration Category'] = pd.cut(dfti['Duration'], bins=bins_duration, labels=labels_duration, right=True)

# Checking the distribution of the new custom duration categories
duration_category = dfti['Duration Category'].value_counts()

duration_category
# Out:
# 1-4 months     35534
# 5-8 months      2107
# >12 months      1274
# 9-12 months      323
# Name: Duration Category, dtype: int64

# %%
# Drop NaN values on Duration Category
dfti.dropna(subset=['Duration Category'], inplace=True)

# %% [markdown]
# I have done binning in the duration column to handle outliers in duration and drop NaN values that arise due to binning. After this, I will handle outliers in net sales.

# %% [markdown]
# ### **Handling Outlier in Net Sales**

# %%
# Calculating the Interquartile Range (IQR) for Net Sales
Q1 = dfti['Net Sales'].quantile(0.25)
Q3 = dfti['Net Sales'].quantile(0.75)
IQR = Q3 - Q1

# Identifying outliers
outliers = dfti[(dfti['Net Sales'] < (Q1 - 1.5 * IQR)) | (dfti['Net Sales'] > (Q3 + 1.5 * IQR))]

# Calculating the percentage of outliers
outlier_count = outliers.shape[0]
total_count = dfti.shape[0]
outlier_percentage = (outlier_count / total_count) * 100

# Checking the distribution of claims among the outliers
claim_distribution_outliers = outliers['Claim'].value_counts()

outlier_percentage, outlier_count, total_count, claim_distribution_outliers
# Out:
# (9.159488251185076,
#  3594,
#  39238,
#  0    3396
#  1     198
#  Name: Claim, dtype: int64)

# %% [markdown]
# After checking more deeply using IQR on Net Sales, there were 9.15 outliers. Outliers in business data, like 'Net Sales', often reflect crucial real-world phenomena. Eliminating these can obscure vital business insights, as [Boldosova and Luoto's research](https://www.emerald.com/insight/content/doi/10.1108/MRR-03-2019-0106/full/html) on data interpretation in business highlights. Moreover, removing outliers without careful consideration risks overfitting in predictive models, reducing their effectiveness on new data. So, I decided not to deal with those outliers. After this process, we will proceed to handle outliers in commision.

# %% [markdown]
# ### **Handling Outlier in Commision (In Value)**

# %%
# Calculating the Interquartile Range (IQR) for 'Commision (in value)'
Q1_commission = dfti['Commision (in value)'].quantile(0.25)
Q3_commission = dfti['Commision (in value)'].quantile(0.75)
IQR_commission = Q3_commission - Q1_commission

# Identifying outliers for 'Commision (in value)'
outliers_commission = dfti[(dfti['Commision (in value)'] < (Q1_commission - 1.5 * IQR_commission)) | 
                        (dfti['Commision (in value)'] > (Q3_commission + 1.5 * IQR_commission))]

# Calculating the percentage of outliers for 'Commision (in value)'
outlier_count_commission = outliers_commission.shape[0]
outlier_percentage_commission = (outlier_count_commission / total_count) * 100

# Checking the distribution of claims among the outliers for 'Commision (in value)'
claim_distribution_outliers_commission = outliers_commission['Claim'].value_counts()

outlier_percentage_commission, outlier_count_commission, total_count, claim_distribution_outliers_commission
# Out:
# (10.40063204036903,
#  4081,
#  39238,
#  0    3883
#  1     198
#  Name: Claim, dtype: int64)

# %% [markdown]
# After checking more deeply using IQR on Commision, there were 10.40% outliers. We opting not to handle outliers in 'Commision (in value)' because the outliers in 'Commission (in value)' data can be reasonably justified by prioritizing the accurate representation of business phenomena. These outliers may reflect significant or unusual transactions essential for [understanding business activities](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5548942/#:~:text=Outliers%20significantly%20affect%20the%20process,values%20and%20outliers%20are%20processed). Omitting them could lead to losing crucial insights, distorting the business landscape. After this process, we will proceed to handle outliers in age.

# %% [markdown]
# ### **Handling Outliers in Age**
#
# I will bin the age column based on the Republic of Indonesia Health Ministerial Decree [number 25 of 2016](http://hukor.kemkes.go.id/uploads/produk_hukum/PMK_No._25_ttg_Rencana_Aksi_Nasional_Kesehatan_Lanjut_Usia_Tahun_2016-2019_.pdf). Here are the criteria:
# - Babies 0-1 years old
# - Children 2-10 years
# - Teenager 11-19 years old
# - Adult 20-44 years
# - Pre-Senior Age 45-59 years
# - Senior aged ≥ 60 years

# %%
# Define the updated age bins and labels
updated_bins = [0, 1, 10, 19, 44, 59, dfti['Age'].max()]
updated_labels = ["Babies", "Children", "Teenager", "Adult", "Pra-Senior Age", "Senior"]

# Bin the data with the updated criteria
dfti['Age Group'] = pd.cut(dfti['Age'], bins=updated_bins, labels=updated_labels, right=False)

# Checking the distribution of the new age groups
updated_age_group = dfti['Age Group'].value_counts()

updated_age_group
# Out:
# Adult             28794
# Pra-Senior Age     7410
# Senior             2454
# Teenager             99
# Children             23
# Babies                2
# Name: Age Group, dtype: int64

# %%
# Drop NaN values on Age Group
dfti.dropna(subset=['Age Group'], inplace=True)

# %%
dfti.head()
# Out:
#   Agency    Agency Type Distribution Channel              Product Name Gender  \
# 0    C2B       Airlines               Online        Annual Silver Plan      F
# 1    EPX  Travel Agency               Online         Cancellation Plan    NaN
# 2    JZI       Airlines               Online                Basic Plan      M
# 3    EPX  Travel Agency               Online  2 way Comprehensive Plan    NaN
# 4    C2B       Airlines               Online               Bronze Plan      M
#
#    Duration    Destination  Net Sales  Commision (in value)  Age  Claim  \
# 0       365      SINGAPORE      216.0                  54.0   57      0
# 1         4       MALAYSIA       10.0                   0.0   33      0
# 2        19          INDIA       22.0                   7.7   26      0
# 3        20  UNITED STATES      112.0                   0.0   59      0
# 4         8      SINGAPORE       16.0                   4.0   28      0
#
#   Duration Category       Age Group
# 0        >12 months  Pra-Senior Age
# 1        1-4 months           Adult
# 2        1-4 months           Adult
# 3        1-4 months          Senior
# 4        1-4 months           Adult

# %% [markdown]
# The 'Age' column in the dataset has been categorized (binned) by the guidelines set out in the Health Regulation of the Republic of Indonesia. This binning process aligns the age data with standardized age groups, facilitating a more structured and relevant analysis that adheres to recognized national health standards. This alignment not only enhances the accuracy of the analysis but also ensures consistency with regulatory frameworks, making the findings more applicable and informative in a health policy context. Apart from that, there has been a drop in NaN caused by binning. After this process, we will proceed to handle data type.

# %% [markdown]
# ## **Handling Data Type**

# %%
data_info_df
# Out:
#                  feature data_type data_type_variable  null_value(%)  \
# 0                 Agency    object        Categorical          0.000
# 1            Agency Type    object        Categorical          0.000
# 2   Distribution Channel    object        Categorical          0.000
# 3           Product Name    object        Categorical          0.000
# 4                 Gender    object        Categorical         71.393
# 5               Duration     int64          Numerical          0.000
# 6            Destination    object        Categorical          0.000
# 7              Net Sales   float64          Numerical          0.000
# 8   Commision (in value)   float64          Numerical          0.000
# 9                    Age     int64          Numerical          0.000
# 10                 Claim     int64          Numerical          0.000
#
#     n_unique  duplicate  Negative_value_num  Zero_value_num  Zero_value_obj  \
# 0         16       4667               0.000           0.000             0.0
# 1          2       4667               0.000           0.000             0.0
# 2          2       4667               0.000           0.000             0.0
# 3         26       4667               0.000           0.000             0.0
# 4          2       4667               0.000           0.000             0.0
# 5        437       4667               0.005           0.106             0.0
# 6        138       4667               0.000           0.000             0.0
# 7       1006       4667               1.090           2.912             0.0
# 8        915       4667               0.000          55.777             0.0
# 9         89       4667               0.000           0.005             0.0
# 10         2       4667               0.000          98.473             0.0
#
#                                         sample_unique
# 0   [C2B, EPX, JZI, CWT, LWC, ART, CSR, SSI, RAB, ...
# 1                           [Airlines, Travel Agency]
# 2                                   [Online, Offline]
# 3   [Annual Silver Plan, Cancellation Plan, Basic ...
# 4                                         [F, nan, M]
# 5   [365, 4, 19, 20, 8, 2, 25, 90, 24, 43, 103, 37...
# 6   [SINGAPORE, MALAYSIA, INDIA, UNITED STATES, KO...
# 7   [216.0, 10.0, 22.0, 112.0, 16.0, 50.0, 78.0, 8...
# 8   [54.0, 0.0, 7.7, 4.0, 9.1, 63.21, 10.5, 11.88,...
# 9   [57, 33, 26, 59, 28, 36, 22, 39, 27, 48, 43, 5...
# 10                                             [0, 1]

# %% [markdown]
# The data types within the dataset have been verified and are appropriately aligned, ensuring that each variable is correctly formatted for effective analysis. This alignment of data types is crucial as it lays the foundation for accurate and efficient data processing, analysis, and subsequent interpretation of results. It guarantees that the computational operations and analytical methods applied to the dataset will function as intended, thus enhancing the reliability of the analysis. After this process, we will proceed to handle rare label.

# %% [markdown]
# ## **Handling Rare Label**

# %% [markdown]
# Rare labels in a dataset refer to categories within a categorical variable that occur infrequently. These labels represent a small percentage of the data and are distinct from the more commonly occurring categories.

# %%
# First, we need to correctly identify the categorical columns in the dataset.
categorical_columns = dfti.select_dtypes(include=['object']).columns.tolist()

# Calculate the frequency distribution for each categorical variable in percentage
label_frequency_percent = {col: dfti[col].value_counts(normalize=True) * 100 for col in categorical_columns}

# Now, we will create a nested list of the data to be able to use it with tabulate directly.
# The outer list corresponds to the rows of the table and the inner lists correspond to the columns of each row.
data_for_tabulate = []

# Iterate over the dictionary to populate the data for tabulate
for variable, freq_series in label_frequency_percent.items():
    data_for_tabulate.append([variable, freq_series.index[0], f"{freq_series.iloc[0]:.2f}%"])
    for idx in range(1, len(freq_series)):
        data_for_tabulate.append(["", freq_series.index[idx], f"{freq_series.iloc[idx]:.2f}%"])

# Display the frequency distribution in percentage using tabulate
print(tabulate(data_for_tabulate, headers=["Variable", "Category", "Frequency (%)"], tablefmt="pipe"))
# Out:
# | Variable             | Category                                   | Frequency (%)   |
# |:---------------------|:-------------------------------------------|:----------------|
# | Agency               | EPX                                        | 53.41%          |
# |                      | CWT                                        | 14.68%          |
# |                      | C2B                                        | 14.12%          |
# |                      | JZI                                        | 10.78%          |
# |                      | SSI                                        | 1.75%           |
# |                      | RAB                                        | 1.19%           |
# |                      | LWC                                        | 1.16%           |
# |                      | TST                                        | 0.88%           |
# |                      | KML                                        | 0.64%           |
# |                      | ART                                        | 0.47%           |
# |                      | CCR                                        | 0.25%           |
# |                      | CBH                                        | 0.18%           |
# |                      | CSR                                        | 0.18%           |
# |                      | TTW                                        | 0.17%           |
# |                      | ADM                                        | 0.14%           |
# | Agency Type          | Travel Agency                              | 71.69%          |
# |                      | Airlines                                   | 28.31%          |
# | Distribution Channel | Online                                     | 98.27%          |
# |                      | Offline                                    | 1.73%           |
# | Product Name         | Cancellation Plan                          | 27.97%          |
# |                      | 2 way Comprehensive Plan                   | 20.90%          |
# |                      | Rental Vehicle Excess Insurance            | 14.68%          |
# |                      | Basic Plan                                 | 9.27%           |
# |                      | Bronze Plan                                | 6.98%           |
# |                      | 1 way Comprehensive Plan                   | 4.54%           |
# |                      | Silver Plan                                | 3.87%           |
# |                      | Value Plan                                 | 3.24%           |
# |                      | Annual Silver Plan                         | 2.31%           |
# |                      | Ticket Protector                           | 1.75%           |
# |                      | Travel Cruise Protect                      | 0.88%           |
# |                      | Gold Plan                                  | 0.61%           |
# |                      | Comprehensive Plan                         | 0.58%           |
# |                      | 24 Protect                                 | 0.42%           |
# |                      | Annual Gold Plan                           | 0.36%           |
# |                      | Single Trip Travel Protect Gold            | 0.34%           |
# |                      | Premier Plan                               | 0.31%           |
# |                      | Single Trip Travel Protect Silver          | 0.30%           |
# |                      | Annual Travel Protect Gold                 | 0.16%           |
# |                      | Annual Travel Protect Silver               | 0.15%           |
# |                      | Individual Comprehensive Plan              | 0.12%           |
# |                      | Single Trip Travel Protect Platinum        | 0.12%           |
# |                      | Annual Travel Protect Platinum             | 0.09%           |
# |                      | Spouse or Parents Comprehensive Plan       | 0.03%           |
# |                      | Child Comprehensive Plan                   | 0.02%           |
# |                      | Travel Cruise Protect Family               | 0.00%           |
# | Gender               | M                                          | 50.33%          |
# |                      | F                                          | 49.67%          |
# | Destination          | SINGAPORE                                  | 21.08%          |
# |                      | THAILAND                                   | 9.34%           |
# |                      | MALAYSIA                                   | 8.02%           |
# |                      | CHINA                                      | 7.49%           |
# |                      | AUSTRALIA                                  | 6.30%           |
# |                      | INDONESIA                                  | 5.18%           |
# |                      | UNITED STATES                              | 4.40%           |
# |                      | HONG KONG                                  | 3.98%           |
# |                      | PHILIPPINES                                | 3.71%           |
# |                      | JAPAN                                      | 3.58%           |
# |                      | KOREA, REPUBLIC OF                         | 2.57%           |
# |                      | VIET NAM                                   | 2.55%           |
# |                      | INDIA                                      | 2.39%           |
# |                      | UNITED KINGDOM                             | 2.25%           |
# |                      | TAIWAN, PROVINCE OF CHINA                  | 1.88%           |
# |                      | BRUNEI DARUSSALAM                          | 1.27%           |
# |                      | MYANMAR                                    | 1.23%           |
# |                      | CANADA                                     | 0.93%           |
# |                      | NEW ZEALAND                                | 0.93%           |
# |                      | FRANCE                                     | 0.85%           |
# |                      | ITALY                                      | 0.79%           |
# |                      | GERMANY                                    | 0.79%           |
# |                      | CAMBODIA                                   | 0.77%           |
# |                      | NETHERLANDS                                | 0.63%           |
# |                      | SPAIN                                      | 0.60%           |
# |                      | SWITZERLAND                                | 0.53%           |
# |                      | UNITED ARAB EMIRATES                       | 0.51%           |
# |                      | SRI LANKA                                  | 0.41%           |
# |                      | NORWAY                                     | 0.31%           |
# |                      | SOUTH AFRICA                               | 0.29%           |
# |                      | LAO PEOPLE'S DEMOCRATIC REPUBLIC           | 0.26%           |
# |                      | IRELAND                                    | 0.21%           |
# |                      | ICELAND                                    | 0.20%           |
# |                      | MACAO                                      | 0.19%           |
# |                      | NEPAL                                      | 0.19%           |
# |                      | GREECE                                     | 0.19%           |
# |                      | AUSTRIA                                    | 0.18%           |
# |                      | DENMARK                                    | 0.18%           |
# |                      | BANGLADESH                                 | 0.17%           |
# |                      | PORTUGAL                                   | 0.17%           |
# |                      | PERU                                       | 0.15%           |
# |                      | FINLAND                                    | 0.15%           |
# |                      | TURKEY                                     | 0.13%           |
# |                      | RUSSIAN FEDERATION                         | 0.12%           |
# |                      | CROATIA                                    | 0.12%           |
# |                      | SWEDEN                                     | 0.12%           |
# |                      | CZECH REPUBLIC                             | 0.11%           |
# |                      | SAUDI ARABIA                               | 0.09%           |
# |                      | ISRAEL                                     | 0.09%           |
# |                      | MONGOLIA                                   | 0.08%           |
# |                      | BELGIUM                                    | 0.07%           |
# |                      | POLAND                                     | 0.07%           |
# |                      | BRAZIL                                     | 0.07%           |
# |                      | PAKISTAN                                   | 0.06%           |
# |                      | MEXICO                                     | 0.05%           |
# |                      | MALDIVES                                   | 0.04%           |
# |                      | KENYA                                      | 0.04%           |
# |                      | TANZANIA, UNITED REPUBLIC OF               | 0.04%           |
# |                      | OMAN                                       | 0.04%           |
# |                      | HUNGARY                                    | 0.03%           |
# |                      | KAZAKHSTAN                                 | 0.03%           |
# |                      | ARGENTINA                                  | 0.03%           |
# |                      | MOROCCO                                    | 0.03%           |
# |                      | GEORGIA                                    | 0.03%           |
# |                      | COLOMBIA                                   | 0.03%           |
# |                      | CYPRUS                                     | 0.03%           |
# |                      | EGYPT                                      | 0.03%           |
# |                      | JORDAN                                     | 0.03%           |
# |                      | QATAR                                      | 0.03%           |
# |                      | PAPUA NEW GUINEA                           | 0.03%           |
# |                      | FIJI                                       | 0.02%           |
# |                      | BAHRAIN                                    | 0.02%           |
# |                      | UKRAINE                                    | 0.02%           |
# |                      | ROMANIA                                    | 0.02%           |
# |                      | MAURITIUS                                  | 0.02%           |
# |                      | MALTA                                      | 0.02%           |
# |                      | CHILE                                      | 0.02%           |
# |                      | UZBEKISTAN                                 | 0.02%           |
# |                      | ECUADOR                                    | 0.02%           |
# |                      | BULGARIA                                   | 0.02%           |
# |                      | ESTONIA                                    | 0.02%           |
# |                      | TUNISIA                                    | 0.02%           |
# |                      | BOLIVIA                                    | 0.02%           |
# |                      | SERBIA                                     | 0.01%           |
# |                      | SLOVENIA                                   | 0.01%           |
# |                      | AZERBAIJAN                                 | 0.01%           |
# |                      | LUXEMBOURG                                 | 0.01%           |
# |                      | COSTA RICA                                 | 0.01%           |
# |                      | VENEZUELA                                  | 0.01%           |
# |                      | BHUTAN                                     | 0.01%           |
# |                      | LEBANON                                    | 0.01%           |
# |                      | BELARUS                                    | 0.01%           |
# |                      | UGANDA                                     | 0.01%           |
# |                      | GUAM                                       | 0.01%           |
# |                      | GHANA                                      | 0.01%           |
# |                      | BERMUDA                                    | 0.01%           |
# |                      | ZIMBABWE                                   | 0.01%           |
# |                      | VANUATU                                    | 0.01%           |
# |                      | MACEDONIA, THE FORMER YUGOSLAV REPUBLIC OF | 0.01%           |
# |                      | ETHIOPIA                                   | 0.01%           |
# |                      | TRINIDAD AND TOBAGO                        | 0.01%           |
# |                      | ZAMBIA                                     | 0.01%           |
# |                      | KYRGYZSTAN                                 | 0.01%           |
# |                      | NAMIBIA                                    | 0.01%           |
# |                      | PANAMA                                     | 0.01%           |
# |                      | GUINEA                                     | 0.01%           |
# |                      | PUERTO RICO                                | 0.01%           |
# |                      | LITHUANIA                                  | 0.01%           |
# |                      | MALI                                       | 0.01%           |
# |                      | NORTHERN MARIANA ISLANDS                   | 0.01%           |
# |                      | SAMOA                                      | 0.00%           |
# |                      | SENEGAL                                    | 0.00%           |
# |                      | CAMEROON                                   | 0.00%           |
# |                      | CAYMAN ISLANDS                             | 0.00%           |
# |                      | TAJIKISTAN                                 | 0.00%           |
# |                      | ARMENIA                                    | 0.00%           |
# |                      | FAROE ISLANDS                              | 0.00%           |
# |                      | DOMINICAN REPUBLIC                         | 0.00%           |
# |                      | MOLDOVA, REPUBLIC OF                       | 0.00%           |
# |                      | BENIN                                      | 0.00%           |
# |                      | GUINEA-BISSAU                              | 0.00%           |
# |                      | REPUBLIC OF MONTENEGRO                     | 0.00%           |
# |                      | GUYANA                                     | 0.00%           |
# |                      | BOTSWANA                                   | 0.00%           |
# |                      | RWANDA                                     | 0.00%           |
# |                      | LATVIA                                     | 0.00%           |
# |                      | JAMAICA                                    | 0.00%           |
# |                      | ANGOLA                                     | 0.00%           |
# |                      | FRENCH POLYNESIA                           | 0.00%           |
# |                      | URUGUAY                                    | 0.00%           |
# |                      | NIGERIA                                    | 0.00%           |
# |                      | TURKMENISTAN                               | 0.00%           |
# |                      | KUWAIT                                     | 0.00%           |
# |                      | IRAN, ISLAMIC REPUBLIC OF                  | 0.00%           |
# |                      | REUNION                                    | 0.00%           |

# %% [markdown]
# Insight :
#
# Rare labels, such as less common agencies or destinations with very low frequencies, suggest a wide diversity in the data. These rare labels could offer unique insights into specific, less common scenarios or customer behaviors. However, their rarity also means they might not significantly impact broad trends or patterns in the data. This diversity in our dataset can be crucial for detailed analyses, especially when looking for niche trends or unusual ways.

# %% [markdown]
# In anomaly detection and data analysis, retaining rare labels in a dataset is supported by research that underscores the complex nature and potential significance of these infrequent occurrences. Studies in anomaly detection reveal that anomalies, although temporally rare, can exhibit a substantial spatial footprint, suggesting varied frequencies among different types of rare events. Further, the importance of comprehensive ground truth and labeling is highlighted, where biases can arise from incomplete or selective labeling. This complexity and variability of rare labels reinforce the rationale for not handling them, as they might [represent critical patterns or insights within the dataset](https://ar5iv.labs.arxiv.org/html/2211.10129), enhancing the depth and accuracy of the analysis​​. After this process, we will proceed to handle cardinality.

# %% [markdown]
# ## **Handling Cardinality**

# %%
# Checking the cardinality (number of unique values) in each categorical column
cardinality_check = dfti.select_dtypes(include=['object']).nunique()

print(cardinality_check)
# Out:
# Agency                   15
# Agency Type               2
# Distribution Channel      2
# Product Name             26
# Gender                    2
# Destination             135
# dtype: int64

# %% [markdown]
# Insight :
# 1. Agency: 15 unique values suggest a moderate variety of agencies involved.
# 2. Agency Type & Distribution Channel: Both have two unique values, indicating binary classifications within the dataset.
# 3. Product Name: 26 unique values denote a more comprehensive range of products.
# 4. Gender: 2 unique values likely refer to male and female categories.
# 5. Destination: 135 unique values show a high geographical diversity.
#
# These cardinalities imply that simple encoding techniques may suffice for some features. In contrast, others with higher uniqueness, like destinations, agencies, and product names, may need more complex methods to manage dimensionality in machine learning models. After this process, we will proceed to handle collinearity.

# %% [markdown]
# ## **Handling Collinearity**

# %%
# Calculating the correlation matrix to check for collinearity
collinearity_matrix = dfti.corr()

print(collinearity_matrix)
# Out:
#                       Duration  Net Sales  Commision (in value)       Age  \
# Duration              1.000000   0.376445              0.302623  0.024674
# Net Sales             0.376445   1.000000              0.635287  0.026003
# Commision (in value)  0.302623   0.635287              1.000000  0.100862
# Age                   0.024674   0.026003              0.100862  1.000000
# Claim                 0.062616   0.135840              0.101117 -0.015562
#
#                          Claim
# Duration              0.062616
# Net Sales             0.135840
# Commision (in value)  0.101117
# Age                  -0.015562
# Claim                 1.000000

# %% [markdown]
# Insight:
#
# 1. Duration and Net Sales show a moderate positive correlation (approximately 0.376).
# 2. Net Sales and Commision (in value) have a stronger positive correlation (approximately 0.635).
# 3. Commision (in value) and Duration also have a positive correlation, though it's weaker (approximately 0.302).
# 4. Correlations involving Age are weak.
#
# These correlations, especially between Net Sales and Commision (in value), suggest that these variables are somewhat collinear. Therefore, it can be essential to consider when building predictive models, as collinearity can affect the performance and interpretation of specific algorithms. Depending on the modeling approach, we may need to address this through feature engineering or by choosing algorithms less sensitive to collinearity. After this process, we will continue to carry out feature engineering.

# %% [markdown]
# ## **Feature Engineering**

# %% [markdown]
# Feature engineering streamlines the predictive modeling process by refining raw data into a robust dataset. It begins with data splitting to delineate training and testing sets, ensuring an unbiased model evaluation. Encoding then translates categorical variables into a machine-readable numeric format, while scaling adjusts feature ranges for uniformity. New features are created to capture additional insights, and feature selection is applied to remove redundant or irrelevant data, honing the model's focus on the most impactful variables. Together, these steps are foundational in enhancing model accuracy and predictive power.

# %%
# Remove 'Gender', 'Age', and 'Duration' columns as they are not used
dfti.drop(['Gender', 'Age', 'Duration'], axis=1, inplace=True)

# %% [markdown]
# I will be dropping the Gender column, as previously explained, based on the rationale that gender does not influence claims significantly. In addition, I will also drop the Age and Duration columns since these have been subjected to binning, rendering the original columns unnecessary and redundant. Following this process, I will move on to encoding.

# %% [markdown]
# ### **Encoding**

# %% [markdown]
# By employing these encoding techniques, we can maintain the categorical data's richness while transforming it into a format amenable to machine learning models.

# %% [markdown]
# 1. Agency will be binary encoded due to its non-ordinal nature and high unique value count.
# 2. Agency Type is to be one-hot encoded, fitting its few unique, non-ordinal values.
# 3. Distribution Channel will also receive one-hot encoding, mirroring Agency Type.
# 4. Product Name, like Agency, will be binary encoded to manage its high cardinality.
# 5. Destination is set for binary encoding, avoiding the feature bloat of one-hot encoding.
# 6. Age Group will be ordinally encoded into integers 0-5, reflecting ordered age categories.
# 7. Duration Category' will be ordinally encoded into integers 0-3, corresponding to travel duration ranges.
#
# Summary Table:
#
# | Feature Name           | Encoding Method   |
# |------------------------|-------------------|
# | Agency                 | Binary Encoding   |
# | Agency Type            | One-Hot Encoding  |
# | Distribution Channel   | One-Hot Encoding  |
# | Product Name           | Binary Encoding   |
# | Destination            | Binary Encoding   |
# | Age Group              | Ordinal Encoding  |
# | Duration Category      | Ordinal Encoding  |
#
#
# This encoding approach streamlines categorical features for practical model training. After knowing the encoding method, we will continue to set the pipeline.

# %% [markdown]
# ### **Setup Pipeline**

# %% [markdown]
# Setting up a data processing pipeline is essential in machine learning workflows, ensuring consistent and efficient dataset handling. This structured approach in the pipeline prepares the data effectively for subsequent modeling.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline
from typing import Literal
from category_encoders import OneHotEncoder, OrdinalEncoder, BinaryEncoder

# Define columns for one-hot and ordinal encoding
categorical_features = ['Agency Type', 'Distribution Channel']
ordinal_features = ['Age Group', 'Duration Category']
numerical_features = ['Net Sales', 'Commision (in value)']

# Define Column Transformer
preprocessor = ColumnTransformer(
        transformers=[
            ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features),
            ('ord', OrdinalEncoder(), ordinal_features),
            ('scaler', RobustScaler(), numerical_features),
            ('binary_encoder', BinaryEncoder(), ['Agency', 'Product Name', 'Destination']),            
        ],
        remainder='passthrough',
        verbose_feature_names_out=False
    ).set_output(transform='pandas')

# Define the main pipeline with feature engineering steps directly included
pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        
    ])

pipeline
# Out:
# Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='passthrough',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('cat',
#                                                   OneHotEncoder(cols=None,
#                                                                 drop_invariant=False,
#                                                                 handle_missing='value',
#                                                                 handle_unknown='ignore',
#                                                                 return_df=True,
#                                                                 use_cat_names=False,
#                                                                 verbose=0),
#                                                   ['Agency Type',
#                                                    'Distribution Channel']),
#                                                  ('ord',
#                                                   Or...
#                                                                unit_variance=False,
#                                                                with_centering=True,
#                                                                with_scaling=True),
#                                                   ['Net Sales',
#                                                    'Commision (in value)']),
#                                                  ('binary_encoder',
#                                                   BinaryEncoder(base=2,
#                                                                 cols=None,
#                                                                 drop_invariant=False,
#                                                                 handle_missing='value',
#                                                                 handle_unknown='value',
#                                                                 mapping=None,
#                                                                 return_df=True,
#                                                                 verbose=0),
#                                                   ['Agency', 'Product Name',
#                                                    'Destination'])],
#                                    verbose=False,
#                                    verbose_feature_names_out=False))],
#          verbose=False)

# %% [markdown]
# After meticulously establishing the data processing pipeline harmonizing and refining the dataset, the next logical phase is to embark on the modeling experiment. This transition from data preparation to modeling is crucial. It's where the cleaned and structured data can be leveraged to build, test, and evaluate various machine learning models, exploring their capabilities in predicting outcomes with precision and reliability.

# %% [markdown]
# ## **Modelling Experiment**

# %% [markdown]
# ## Data Splitting

# %% [markdown]
# To enhance the model's predictive accuracy for future datasets with a similar format and to prevent data leakage, it is essential to perform data splitting again before training the model. This step ensures that the model is tested on a fresh subset of data, mirroring real-world scenarios where it encounters unseen data, reinforcing its robustness and reliability.

# %%
# Split Seen and Unseen
df, unseen = train_test_split(dfti, test_size=0.2, random_state=42, stratify=dfti['Claim'])

# %% [markdown]
# I have finished splitting the data. After that, I will set up the modeling experiment.

# %% [markdown]
# #### **Setup Pycaret**

# %% [markdown]
# The first stage in the modeling experiment is to set up py caret, which uses the pipeline that we created previously.

# %%
from pycaret.classification import *

# %% [markdown]
# With the PyCaret setup complete, the stage is set for robust experimentation. The data, now primed within PyCaret's environment, awaits the application of various algorithms. After that, determine the best model from benchmark modeling.

# %% [markdown]
# ### **Benchmarking Models**

# %% [markdown]
# [Benchmarking in machine learning](https://www.nature.com/articles/s42254-022-00441-7) is a compass for navigating the vast landscape of algorithms and architectural choices, guiding researchers toward the most effective solutions for their scientific inquiries. In essence, benchmarking crystallizes the capabilities of various models, elucidating their strengths and weaknesses in specific contexts​​. It is the bedrock upon which the reliability and generalizability of machine learning technologies are evaluated, especially as datasets grow in size and complexity.

# %% [markdown]
# #### **Benchmark With ADASYN (Adaptive Synthetic Sampling) Method**

# %% [markdown]
# [Adaptive synthetic (ADASYN) sampling](https://ieeexplore.ieee.org/document/4633969) helps approximate imbalanced data. The essential idea of ADASYN is to use a weighted distribution for different minority class examples according to their level of difficulty in learning, where more synthetic data is generated for minority class examples that are harder to learn compared to those that are easier to understand. Benchmark models using ADASYN provide valuable insight into the effectiveness of such techniques in creating good classification.

# %%
from pycaret.classification import setup
from imblearn.over_sampling import ADASYN
from pycaret.internal.preprocess.transformers import TransformerWrapper, FixImbalancer

# Initialize experiment setup for the first experiment
adasyn = ClassificationExperiment()
adasyn.setup(
    experiment_name='ADASYN Resampling',
    custom_pipeline=[
        ('pipeline', pipeline),
        ('resampling', TransformerWrapper(transformer=FixImbalancer(ADASYN(random_state=42))))
    ], 
    data=df, target='Claim', preprocess=False, train_size=0.8, session_id=123)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4937c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4937c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4937c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4937c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4937c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4937c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4937c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4937c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4937c_row1_col1" class="data row1 col1" >Claim</td>
#     </tr>
#     <tr>
#       <th id="T_4937c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4937c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4937c_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_4937c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4937c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4937c_row3_col1" class="data row3 col1" >(31025, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_4937c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4937c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4937c_row4_col1" class="data row4 col1" >(54966, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_4937c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4937c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4937c_row5_col1" class="data row5 col1" >(48761, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_4937c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4937c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4937c_row6_col1" class="data row6 col1" >(6205, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_4937c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4937c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_4937c_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_4937c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4937c_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_4937c_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#   </tbody>
# </table>

# %%
experimentmodel1 = adasyn.compare_models(n_select=5, sort='Recall')
# Out:
# <style type="text/css">
# #T_96b38 th {
#   text-align: left;
# }
# #T_96b38_row0_col0, #T_96b38_row0_col1, #T_96b38_row0_col2, #T_96b38_row0_col4, #T_96b38_row0_col5, #T_96b38_row0_col6, #T_96b38_row0_col7, #T_96b38_row1_col0, #T_96b38_row1_col1, #T_96b38_row1_col2, #T_96b38_row1_col3, #T_96b38_row1_col4, #T_96b38_row1_col5, #T_96b38_row1_col6, #T_96b38_row1_col7, #T_96b38_row2_col0, #T_96b38_row2_col1, #T_96b38_row2_col3, #T_96b38_row2_col4, #T_96b38_row2_col5, #T_96b38_row2_col6, #T_96b38_row2_col7, #T_96b38_row3_col0, #T_96b38_row3_col1, #T_96b38_row3_col2, #T_96b38_row3_col3, #T_96b38_row3_col4, #T_96b38_row3_col5, #T_96b38_row3_col6, #T_96b38_row3_col7, #T_96b38_row4_col0, #T_96b38_row4_col1, #T_96b38_row4_col2, #T_96b38_row4_col3, #T_96b38_row4_col4, #T_96b38_row4_col5, #T_96b38_row4_col6, #T_96b38_row4_col7, #T_96b38_row5_col0, #T_96b38_row5_col1, #T_96b38_row5_col2, #T_96b38_row5_col3, #T_96b38_row5_col4, #T_96b38_row5_col5, #T_96b38_row5_col6, #T_96b38_row5_col7, #T_96b38_row6_col0, #T_96b38_row6_col1, #T_96b38_row6_col2, #T_96b38_row6_col3, #T_96b38_row6_col4, #T_96b38_row6_col5, #T_96b38_row6_col6, #T_96b38_row7_col0, #T_96b38_row7_col1, #T_96b38_row7_col2, #T_96b38_row7_col3, #T_96b38_row7_col4, #T_96b38_row7_col5, #T_96b38_row7_col6, #T_96b38_row7_col7, #T_96b38_row8_col0, #T_96b38_row8_col1, #T_96b38_row8_col2, #T_96b38_row8_col3, #T_96b38_row8_col4, #T_96b38_row8_col6, #T_96b38_row8_col7, #T_96b38_row9_col0, #T_96b38_row9_col1, #T_96b38_row9_col2, #T_96b38_row9_col3, #T_96b38_row9_col4, #T_96b38_row9_col5, #T_96b38_row9_col6, #T_96b38_row9_col7, #T_96b38_row10_col0, #T_96b38_row10_col1, #T_96b38_row10_col2, #T_96b38_row10_col3, #T_96b38_row10_col4, #T_96b38_row10_col5, #T_96b38_row10_col6, #T_96b38_row10_col7, #T_96b38_row11_col0, #T_96b38_row11_col1, #T_96b38_row11_col2, #T_96b38_row11_col3, #T_96b38_row11_col4, #T_96b38_row11_col5, #T_96b38_row11_col6, #T_96b38_row11_col7, #T_96b38_row12_col0, #T_96b38_row12_col1, #T_96b38_row12_col2, #T_96b38_row12_col3, #T_96b38_row12_col5, #T_96b38_row12_col7, #T_96b38_row13_col0, #T_96b38_row13_col1, #T_96b38_row13_col2, #T_96b38_row13_col3, #T_96b38_row13_col5, #T_96b38_row13_col6, #T_96b38_row13_col7, #T_96b38_row14_col0, #T_96b38_row14_col1, #T_96b38_row14_col2, #T_96b38_row14_col3, #T_96b38_row14_col4, #T_96b38_row14_col5, #T_96b38_row14_col6, #T_96b38_row14_col7, #T_96b38_row15_col0, #T_96b38_row15_col2, #T_96b38_row15_col3, #T_96b38_row15_col4, #T_96b38_row15_col5, #T_96b38_row15_col6, #T_96b38_row15_col7 {
#   text-align: left;
# }
# #T_96b38_row0_col3, #T_96b38_row2_col2, #T_96b38_row6_col7, #T_96b38_row8_col5, #T_96b38_row12_col4, #T_96b38_row12_col6, #T_96b38_row13_col4, #T_96b38_row15_col1 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_96b38_row0_col8, #T_96b38_row1_col8, #T_96b38_row2_col8, #T_96b38_row4_col8, #T_96b38_row5_col8, #T_96b38_row6_col8, #T_96b38_row7_col8, #T_96b38_row8_col8, #T_96b38_row9_col8, #T_96b38_row10_col8, #T_96b38_row11_col8, #T_96b38_row12_col8, #T_96b38_row13_col8, #T_96b38_row14_col8, #T_96b38_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_96b38_row3_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_96b38">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96b38_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_96b38_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_96b38_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_96b38_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_96b38_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_96b38_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_96b38_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_96b38_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_96b38_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96b38_level0_row0" class="row_heading level0 row0" >qda</th>
#       <td id="T_96b38_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_96b38_row0_col1" class="data row0 col1" >0.7685</td>
#       <td id="T_96b38_row0_col2" class="data row0 col2" >0.7735</td>
#       <td id="T_96b38_row0_col3" class="data row0 col3" >0.7165</td>
#       <td id="T_96b38_row0_col4" class="data row0 col4" >0.0543</td>
#       <td id="T_96b38_row0_col5" class="data row0 col5" >0.1005</td>
#       <td id="T_96b38_row0_col6" class="data row0 col6" >0.0708</td>
#       <td id="T_96b38_row0_col7" class="data row0 col7" >0.1519</td>
#       <td id="T_96b38_row0_col8" class="data row0 col8" >0.0880</td>
#     </tr>
#     <tr>
#       <th id="T_96b38_level0_row1" class="row_heading level0 row1" >dummy</th>
#       <td id="T_96b38_row1_col0" class="data row1 col0" >Dummy Classifier</td>
#       <td id="T_96b38_row1_col1" class="data row1 col1" >0.3070</td>
#       <td id="T_96b38_row1_col2" class="data row1 col2" >0.5000</td>
#       <td id="T_96b38_row1_col3" class="data row1 col3" >0.7000</td>
#       <td id="T_96b38_row1_col4" class="data row1 col4" >0.0121</td>
#       <td id="T_96b38_row1_col5" class="data row1 col5" >0.0238</td>
#       <td id="T_96b38_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_96b38_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_96b38_row1_col8" class="data row1 col8" >0.1040</td>
#     </tr>
#     <tr>
#       <th id="T_96b38_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_96b38_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_96b38_row2_col1" class="data row2 col1" >0.7940</td>
#       <td id="T_96b38_row2_col2" class="data row2 col2" >0.8047</td>
#       <td id="T_96b38_row2_col3" class="data row2 col3" >0.6978</td>
#       <td id="T_96b38_row2_col4" class="data row2 col4" >0.0565</td>
#       <td id="T_96b38_row2_col5" class="data row2 col5" >0.1045</td>
#       <td id="T_96b38_row2_col6" class="data row2 col6" >0.0751</td>
#       <td id="T_96b38_row2_col7" class="data row2 col7" >0.1569</td>
#       <td id="T_96b38_row2_col8" class="data row2 col8" >0.8480</td>
#     </tr>
#     <tr>
#       <th id="T_96b38_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_96b38_row3_col0" class="data row3 col0" >Ridge Classifier</td>
#       <td id="T_96b38_row3_col1" class="data row3 col1" >0.8135</td>
#       <td id="T_96b38_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_96b38_row3_col3" class="data row3 col3" >0.6697</td>
#       <td id="T_96b38_row3_col4" class="data row3 col4" >0.0599</td>
#       <td id="T_96b38_row3_col5" class="data row3 col5" >0.1100</td>
#       <td id="T_96b38_row3_col6" class="data row3 col6" >0.0809</td>
#       <td id="T_96b38_row3_col7" class="data row3 col7" >0.1602</td>
#       <td id="T_96b38_row3_col8" class="data row3 col8" >0.0760</td>
#     </tr>
#     <tr>
#       <th id="T_96b38_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_96b38_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_96b38_row4_col1" class="data row4 col1" >0.8134</td>
#       <td id="T_96b38_row4_col2" class="data row4 col2" >0.8012</td>
#       <td id="T_96b38_row4_col3" class="data row4 col3" >0.6697</td>
#       <td id="T_96b38_row4_col4" class="data row4 col4" >0.0599</td>
#       <td id="T_96b38_row4_col5" class="data row4 col5" >0.1099</td>
#       <td id="T_96b38_row4_col6" class="data row4 col6" >0.0809</td>
#       <td id="T_96b38_row4_col7" class="data row4 col7" >0.1601</td>
#       <td id="T_96b38_row4_col8" class="data row4 col8" >0.1300</td>
#     </tr>
#     <tr>
#       <th id="T_96b38_level0_row5" class="row_heading level0 row5" >nb</th>
#       <td id="T_96b38_row5_col0" class="data row5 col0" >Naive Bayes</td>
#       <td id="T_96b38_row5_col1" class="data row5 col1" >0.7917</td>
#       <td id="T_96b38_row5_col2" class="data row5 col2" >0.7502</
# Processing:   0%|          | 0/73 [00:00<?, ?it/s]

# %% [markdown]
# Create a model from the three best ADASYN compare results based on reacall value.

# %%
lr_adasyn = adasyn.create_model(experimentmodel1[1])
ridge_adasyn= adasyn.create_model(experimentmodel1[2])
lda_adasyn = adasyn.create_model(experimentmodel1[3])
# Out:
# <style type="text/css">
# #T_60fa9_row10_col0, #T_60fa9_row10_col1, #T_60fa9_row10_col2, #T_60fa9_row10_col3, #T_60fa9_row10_col4, #T_60fa9_row10_col5, #T_60fa9_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_60fa9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60fa9_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_60fa9_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_60fa9_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_60fa9_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_60fa9_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_60fa9_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_60fa9_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60fa9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_60fa9_row0_col0" class="data row0 col0" >0.0169</td>
#       <td id="T_60fa9_row0_col1" class="data row0 col1" >0.5000</td>
#       <td id="T_60fa9_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_60fa9_row0_col3" class="data row0 col3" >0.0169</td>
#       <td id="T_60fa9_row0_col4" class="data row0 col4" >0.0333</td>
#       <td id="T_60fa9_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_60fa9_row0_col6" class="data row0 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_60fa9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_60fa9_row1_col0" class="data row1 col0" >0.9831</td>
#       <td id="T_60fa9_row1_col1" class="data row1 col1" >0.5000</td>
#       <td id="T_60fa9_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_60fa9_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_60fa9_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_60fa9_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_60fa9_row1_col6" class="data row1 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_60fa9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_60fa9_row2_col0" class="data row2 col0" >0.9831</td>
#       <td id="T_60fa9_row2_col1" class="data row2 col1" >0.5000</td>
#       <td id="T_60fa9_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_60fa9_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_60fa9_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_60fa9_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_60fa9_row2_col6" class="data row2 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_60fa9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_60fa9_row3_col0" class="data row3 col0" >0.0173</td>
#       <td id="T_60fa9_row3_col1" class="data row3 col1" >0.5000</td>
#       <td id="T_60fa9_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_60fa9_row3_col3" class="data row3 col3" >0.0173</td>
#       <td id="T_60fa9_row3_col4" class="data row3 col4" >0.0341</td>
#       <td id="T_60fa9_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_60fa9_row3_col6" class="data row3 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_60fa9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_60fa9_row4_col0" class="data row4 col0" >0.0173</td>
#       <td id="T_60fa9_row4_col1" class="data row4 col1" >0.5000</td>
#       <td id="T_60fa9_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_60fa9_row4_col3" class="data row4 col3" >0.0173</td>
#       <td id="T_60fa9_row4_col4" class="data row4 col4" >0.0341</td>
#       <td id="T_60fa9_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_60fa9_row4_col6" class="data row4 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_60fa9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_60fa9_row5_col0" class="data row5 col0" >0.0173</td>
#       <td id="T_60fa9_row5_col1" class="data row5 col1" >0.5000</td>
#       <td id="T_60fa9_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_60fa9_row5_col3" class="data row5 col3" >0.0173</td>
#       <td id="T_60fa9_row5_col4" class="data row5 col4" >0.0341</td>
#       <td id="T_60fa9_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_60fa9_row5_col6" class="data row5 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_60fa9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_60fa9_row6_col0" class="data row6 col0" >0.9827</td>
#       <td id="T_60fa9_row6_col1" class="data row6 col1" >0.5000</td>
#       <td id="T_60fa9_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_60fa9_row6_col3" class="data row6 col3" >0.0000</td>
#       <td id="T_60fa9_row6_col4" class="data row6 col4" >0.0000</td>
#       <td id="T_60fa9_row6_col5" class="data row6 col5" >0.0000</td>
#       <td id="T_60fa9_row6_col6" class="data row6 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_60fa9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_60fa9_row7_col0" class="data row7 col0" >0.0173</td>
#       <td id="T_60fa9_row7_col1" class="data row7 col1" >0.5000</td>
#       <td id="T_60fa9_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_60fa9_row7_col3" class="data row7 col3" >0.0173</td>
#       <td id="T_60fa9_row7_col4" class="data row7 col4" >0.0341</td>
#       <td id="T_60fa9_row7_col5" class="data row7 col5" >0.0000</td>
#       <td id="T_60fa9_row7_col6" class="data row7 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_60fa9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_60fa9_row8_col0" class="data row8 col0" >0.0173</td>
#       <td id="T_60fa9_row8_col1" class="data row8 col1" >0.5000</td>
#       <td id="T_60fa9_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_60fa9_row8_col3" class="data row8 col3" >0.0173</td>
#       <td id="T_60fa9_row8_col4" class="data row8 col4" >0.0341</td>
#       <td id="T_60fa9_row8_col5" class="data row8 col5" >0.0000</td>
#       <td id="T_60fa9_row8_col6" class="data row8 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_60fa9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_60fa9_row9_col0" class="data row9 col0" >0.0173</td>
#       <td id="T_60fa9_row9_col1" class="data row9 col1" >0.5000</td>
#       <td id="T_60fa9_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_60fa9_row9_col3" class="data row9 col3" >0.0173</td>
#       <td id="T_60fa9_row9_col4" class="data row9 col4" >0.0341</td>
#       <td id="T_60fa9_row9_col5" class="data row9 col5" >0.0000</td>
#       <td id="T_60fa9_row9_col6" class="data row9 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_60fa9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_60fa9_row10_col0" class="data row10 col0" >0.3070</td>
#       <td id="T_60fa9_row10_col1" class="data row10 col1" >0.5000</td>
#       <td id="T_60fa9_row10_col2" class="data row10 col2" >0.7000</td>
#       <td id="T_60fa9_row10_col3" class="data row10 col3" >0.0121</td>
#       <td id="T_60fa9_row10_col4" class="data row10 col4" >0.0238</td>
#       <td id="T_60fa9_row10_col5" class="data row10 col5" >0.0000</td>
#       <td id="T_60fa9_row10_col6" class="data row10 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_60fa9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_60fa9_row11_col0" class="data row11 col0" >0.4425</td>
#       <td id="T_60fa9_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_60fa9_row11_col2" class="data row11 col2" >0.4583</td>
#       <td id="T_60fa9_row11_col3" class="data row11 col3" >0.0079</td>
#       <td id="T_60fa9_row11_col4
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# <style type="text/css">
# #T_82e90_row10_col0, #T_82e90_row10_col1, #T_82e90_row10_col2, #T_82e90_row10_col3, #T_82e90_row10_col4, #T_82e90_row10_col5, #T_82e90_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_82e90">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82e90_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_82e90_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_82e90_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_82e90_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_82e90_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_82e90_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_82e90_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82e90_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_82e90_row0_col0" class="data row0 col0" >0.8143</td>
#       <td id="T_82e90_row0_col1" class="data row0 col1" >0.8268</td>
#       <td id="T_82e90_row0_col2" class="data row0 col2" >0.6190</td>
#       <td id="T_82e90_row0_col3" class="data row0 col3" >0.0552</td>
#       <td id="T_82e90_row0_col4" class="data row0 col4" >0.1014</td>
#       <td id="T_82e90_row0_col5" class="data row0 col5" >0.0725</td>
#       <td id="T_82e90_row0_col6" class="data row0 col6" >0.1436</td>
#     </tr>
#     <tr>
#       <th id="T_82e90_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_82e90_row1_col0" class="data row1 col0" >0.7998</td>
#       <td id="T_82e90_row1_col1" class="data row1 col1" >0.7952</td>
#       <td id="T_82e90_row1_col2" class="data row1 col2" >0.6905</td>
#       <td id="T_82e90_row1_col3" class="data row1 col3" >0.0565</td>
#       <td id="T_82e90_row1_col4" class="data row1 col4" >0.1045</td>
#       <td id="T_82e90_row1_col5" class="data row1 col5" >0.0756</td>
#       <td id="T_82e90_row1_col6" class="data row1 col6" >0.1567</td>
#     </tr>
#     <tr>
#       <th id="T_82e90_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_82e90_row2_col0" class="data row2 col0" >0.7929</td>
#       <td id="T_82e90_row2_col1" class="data row2 col1" >0.8338</td>
#       <td id="T_82e90_row2_col2" class="data row2 col2" >0.7381</td>
#       <td id="T_82e90_row2_col3" class="data row2 col3" >0.0581</td>
#       <td id="T_82e90_row2_col4" class="data row2 col4" >0.1076</td>
#       <td id="T_82e90_row2_col5" class="data row2 col5" >0.0787</td>
#       <td id="T_82e90_row2_col6" class="data row2 col6" >0.1670</td>
#     </tr>
#     <tr>
#       <th id="T_82e90_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_82e90_row3_col0" class="data row3 col0" >0.7994</td>
#       <td id="T_82e90_row3_col1" class="data row3 col1" >0.7861</td>
#       <td id="T_82e90_row3_col2" class="data row3 col2" >0.6744</td>
#       <td id="T_82e90_row3_col3" class="data row3 col3" >0.0565</td>
#       <td id="T_82e90_row3_col4" class="data row3 col4" >0.1043</td>
#       <td id="T_82e90_row3_col5" class="data row3 col5" >0.0747</td>
#       <td id="T_82e90_row3_col6" class="data row3 col6" >0.1534</td>
#     </tr>
#     <tr>
#       <th id="T_82e90_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_82e90_row4_col0" class="data row4 col0" >0.7949</td>
#       <td id="T_82e90_row4_col1" class="data row4 col1" >0.7975</td>
#       <td id="T_82e90_row4_col2" class="data row4 col2" >0.6744</td>
#       <td id="T_82e90_row4_col3" class="data row4 col3" >0.0553</td>
#       <td id="T_82e90_row4_col4" class="data row4 col4" >0.1023</td>
#       <td id="T_82e90_row4_col5" class="data row4 col5" >0.0726</td>
#       <td id="T_82e90_row4_col6" class="data row4 col6" >0.1507</td>
#     </tr>
#     <tr>
#       <th id="T_82e90_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_82e90_row5_col0" class="data row5 col0" >0.7716</td>
#       <td id="T_82e90_row5_col1" class="data row5 col1" >0.8155</td>
#       <td id="T_82e90_row5_col2" class="data row5 col2" >0.7209</td>
#       <td id="T_82e90_row5_col3" class="data row5 col3" >0.0529</td>
#       <td id="T_82e90_row5_col4" class="data row5 col4" >0.0986</td>
#       <td id="T_82e90_row5_col5" class="data row5 col5" >0.0685</td>
#       <td id="T_82e90_row5_col6" class="data row5 col6" >0.1516</td>
#     </tr>
#     <tr>
#       <th id="T_82e90_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_82e90_row6_col0" class="data row6 col0" >0.7772</td>
#       <td id="T_82e90_row6_col1" class="data row6 col1" >0.7550</td>
#       <td id="T_82e90_row6_col2" class="data row6 col2" >0.6512</td>
#       <td id="T_82e90_row6_col3" class="data row6 col3" >0.0495</td>
#       <td id="T_82e90_row6_col4" class="data row6 col4" >0.0920</td>
#       <td id="T_82e90_row6_col5" class="data row6 col5" >0.0617</td>
#       <td id="T_82e90_row6_col6" class="data row6 col6" >0.1339</td>
#     </tr>
#     <tr>
#       <th id="T_82e90_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_82e90_row7_col0" class="data row7 col0" >0.7933</td>
#       <td id="T_82e90_row7_col1" class="data row7 col1" >0.7789</td>
#       <td id="T_82e90_row7_col2" class="data row7 col2" >0.7209</td>
#       <td id="T_82e90_row7_col3" class="data row7 col3" >0.0583</td>
#       <td id="T_82e90_row7_col4" class="data row7 col4" >0.1078</td>
#       <td id="T_82e90_row7_col5" class="data row7 col5" >0.0783</td>
#       <td id="T_82e90_row7_col6" class="data row7 col6" >0.1639</td>
#     </tr>
#     <tr>
#       <th id="T_82e90_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_82e90_row8_col0" class="data row8 col0" >0.7949</td>
#       <td id="T_82e90_row8_col1" class="data row8 col1" >0.8316</td>
#       <td id="T_82e90_row8_col2" class="data row8 col2" >0.7674</td>
#       <td id="T_82e90_row8_col3" class="data row8 col3" >0.0620</td>
#       <td id="T_82e90_row8_col4" class="data row8 col4" >0.1148</td>
#       <td id="T_82e90_row8_col5" class="data row8 col5" >0.0855</td>
#       <td id="T_82e90_row8_col6" class="data row8 col6" >0.1790</td>
#     </tr>
#     <tr>
#       <th id="T_82e90_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_82e90_row9_col0" class="data row9 col0" >0.8014</td>
#       <td id="T_82e90_row9_col1" class="data row9 col1" >0.8260</td>
#       <td id="T_82e90_row9_col2" class="data row9 col2" >0.7209</td>
#       <td id="T_82e90_row9_col3" class="data row9 col3" >0.0605</td>
#       <td id="T_82e90_row9_col4" class="data row9 col4" >0.1117</td>
#       <td id="T_82e90_row9_col5" class="data row9 col5" >0.0824</td>
#       <td id="T_82e90_row9_col6" class="data row9 col6" >0.1689</td>
#     </tr>
#     <tr>
#       <th id="T_82e90_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_82e90_row10_col0" class="data row10 col0" >0.7940</td>
#       <td id="T_82e90_row10_col1" class="data row10 col1" >0.8047</td>
#       <td id="T_82e90_row10_col2" class="data row10 col2" >0.6978</td>
#       <td id="T_82e90_row10_col3" class="data row10 col3" >0.0565</td>
#       <td id="T_82e90_row10_col4" class="data row10 col4" >0.1045</td>
#       <td id="T_82e90_row10_col5" class="data row10 col5" >0.0751</td>
#       <td id="T_82e90_row10_col6" class="data row10 col6" >0.1569</td>
#     </tr>
#     <tr>
#       <th id="T_82e90_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_82e90_row11_col0" class="data row11 col0" >0.0115</td>
#       <td id="T_82e90_row11_col1" class="data row11 col1" >0.0250</td>
#       <td id="T_82e90_row11_col2" class="data row11 col2" >0.0420</td>
#       <td id="T_82e90_row11_col3" class="data row11 col3" >0.0034</td>
#       <td id="T_82e90_row11_col4
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# <style type="text/css">
# #T_e81b3_row10_col0, #T_e81b3_row10_col1, #T_e81b3_row10_col2, #T_e81b3_row10_col3, #T_e81b3_row10_col4, #T_e81b3_row10_col5, #T_e81b3_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e81b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e81b3_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e81b3_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_e81b3_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e81b3_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_e81b3_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_e81b3_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_e81b3_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e81b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e81b3_row0_col0" class="data row0 col0" >0.8263</td>
#       <td id="T_e81b3_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_e81b3_row0_col2" class="data row0 col2" >0.6190</td>
#       <td id="T_e81b3_row0_col3" class="data row0 col3" >0.0590</td>
#       <td id="T_e81b3_row0_col4" class="data row0 col4" >0.1077</td>
#       <td id="T_e81b3_row0_col5" class="data row0 col5" >0.0792</td>
#       <td id="T_e81b3_row0_col6" class="data row0 col6" >0.1515</td>
#     </tr>
#     <tr>
#       <th id="T_e81b3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e81b3_row1_col0" class="data row1 col0" >0.8175</td>
#       <td id="T_e81b3_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_e81b3_row1_col2" class="data row1 col2" >0.6190</td>
#       <td id="T_e81b3_row1_col3" class="data row1 col3" >0.0562</td>
#       <td id="T_e81b3_row1_col4" class="data row1 col4" >0.1030</td>
#       <td id="T_e81b3_row1_col5" class="data row1 col5" >0.0742</td>
#       <td id="T_e81b3_row1_col6" class="data row1 col6" >0.1457</td>
#     </tr>
#     <tr>
#       <th id="T_e81b3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e81b3_row2_col0" class="data row2 col0" >0.8090</td>
#       <td id="T_e81b3_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_e81b3_row2_col2" class="data row2 col2" >0.7143</td>
#       <td id="T_e81b3_row2_col3" class="data row2 col3" >0.0610</td>
#       <td id="T_e81b3_row2_col4" class="data row2 col4" >0.1124</td>
#       <td id="T_e81b3_row2_col5" class="data row2 col5" >0.0838</td>
#       <td id="T_e81b3_row2_col6" class="data row2 col6" >0.1698</td>
#     </tr>
#     <tr>
#       <th id="T_e81b3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e81b3_row3_col0" class="data row3 col0" >0.8215</td>
#       <td id="T_e81b3_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_e81b3_row3_col2" class="data row3 col2" >0.6279</td>
#       <td id="T_e81b3_row3_col3" class="data row3 col3" >0.0595</td>
#       <td id="T_e81b3_row3_col4" class="data row3 col4" >0.1087</td>
#       <td id="T_e81b3_row3_col5" class="data row3 col5" >0.0795</td>
#       <td id="T_e81b3_row3_col6" class="data row3 col6" >0.1528</td>
#     </tr>
#     <tr>
#       <th id="T_e81b3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e81b3_row4_col0" class="data row4 col0" >0.8159</td>
#       <td id="T_e81b3_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_e81b3_row4_col2" class="data row4 col2" >0.6279</td>
#       <td id="T_e81b3_row4_col3" class="data row4 col3" >0.0577</td>
#       <td id="T_e81b3_row4_col4" class="data row4 col4" >0.1057</td>
#       <td id="T_e81b3_row4_col5" class="data row4 col5" >0.0764</td>
#       <td id="T_e81b3_row4_col6" class="data row4 col6" >0.1491</td>
#     </tr>
#     <tr>
#       <th id="T_e81b3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e81b3_row5_col0" class="data row5 col0" >0.8010</td>
#       <td id="T_e81b3_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_e81b3_row5_col2" class="data row5 col2" >0.7209</td>
#       <td id="T_e81b3_row5_col3" class="data row5 col3" >0.0604</td>
#       <td id="T_e81b3_row5_col4" class="data row5 col4" >0.1115</td>
#       <td id="T_e81b3_row5_col5" class="data row5 col5" >0.0822</td>
#       <td id="T_e81b3_row5_col6" class="data row5 col6" >0.1686</td>
#     </tr>
#     <tr>
#       <th id="T_e81b3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e81b3_row6_col0" class="data row6 col0" >0.8002</td>
#       <td id="T_e81b3_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_e81b3_row6_col2" class="data row6 col2" >0.6279</td>
#       <td id="T_e81b3_row6_col3" class="data row6 col3" >0.0533</td>
#       <td id="T_e81b3_row6_col4" class="data row6 col4" >0.0982</td>
#       <td id="T_e81b3_row6_col5" class="data row6 col5" >0.0684</td>
#       <td id="T_e81b3_row6_col6" class="data row6 col6" >0.1395</td>
#     </tr>
#     <tr>
#       <th id="T_e81b3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e81b3_row7_col0" class="data row7 col0" >0.8147</td>
#       <td id="T_e81b3_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_e81b3_row7_col2" class="data row7 col2" >0.6744</td>
#       <td id="T_e81b3_row7_col3" class="data row7 col3" >0.0611</td>
#       <td id="T_e81b3_row7_col4" class="data row7 col4" >0.1120</td>
#       <td id="T_e81b3_row7_col5" class="data row7 col5" >0.0828</td>
#       <td id="T_e81b3_row7_col6" class="data row7 col6" >0.1630</td>
#     </tr>
#     <tr>
#       <th id="T_e81b3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e81b3_row8_col0" class="data row8 col0" >0.8110</td>
#       <td id="T_e81b3_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_e81b3_row8_col2" class="data row8 col2" >0.7674</td>
#       <td id="T_e81b3_row8_col3" class="data row8 col3" >0.0671</td>
#       <td id="T_e81b3_row8_col4" class="data row8 col4" >0.1234</td>
#       <td id="T_e81b3_row8_col5" class="data row8 col5" >0.0945</td>
#       <td id="T_e81b3_row8_col6" class="data row8 col6" >0.1896</td>
#     </tr>
#     <tr>
#       <th id="T_e81b3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e81b3_row9_col0" class="data row9 col0" >0.8179</td>
#       <td id="T_e81b3_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_e81b3_row9_col2" class="data row9 col2" >0.6977</td>
#       <td id="T_e81b3_row9_col3" class="data row9 col3" >0.0640</td>
#       <td id="T_e81b3_row9_col4" class="data row9 col4" >0.1172</td>
#       <td id="T_e81b3_row9_col5" class="data row9 col5" >0.0882</td>
#       <td id="T_e81b3_row9_col6" class="data row9 col6" >0.1725</td>
#     </tr>
#     <tr>
#       <th id="T_e81b3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_e81b3_row10_col0" class="data row10 col0" >0.8135</td>
#       <td id="T_e81b3_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_e81b3_row10_col2" class="data row10 col2" >0.6697</td>
#       <td id="T_e81b3_row10_col3" class="data row10 col3" >0.0599</td>
#       <td id="T_e81b3_row10_col4" class="data row10 col4" >0.1100</td>
#       <td id="T_e81b3_row10_col5" class="data row10 col5" >0.0809</td>
#       <td id="T_e81b3_row10_col6" class="data row10 col6" >0.1602</td>
#     </tr>
#     <tr>
#       <th id="T_e81b3_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_e81b3_row11_col0" class="data row11 col0" >0.0080</td>
#       <td id="T_e81b3_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_e81b3_row11_col2" class="data row11 col2" >0.0503</td>
#       <td id="T_e81b3_row11_col3" class="data row11 col3" >0.0037</td>
#       <td id="T_e81b3_row11_col4
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# Having identified the three top-performing models based on recall value; Logistic Regression, Ridge Classifier and Linear Discriminant Analysis. The next logical step is benchmarking with SMOTE (Synthetic Minority Over-sampling Technique).

# %% [markdown]
# #### **Benchmark With Smote Method**

# %% [markdown]
# [The Synthetic Minority Over-sampling Technique (SMOTE)](https://arxiv.org/abs/1106.1813) is a widely recognized method for addressing class imbalance in datasets. SMOTE creates synthetic samples from the minority class to promote equal representation. It achieves this by interpolating between existing minority class instances to generate new, synthetic instances. By employing SMOTE during benchmarking, we can assess the impact of a balanced class distribution on the performance of models like Naive Bayes, Logistic Regression, and Ridge Classifier. This insight is pivotal for understanding how each model handles a more balanced dataset and maintains performance metrics, especially for minority class predictions.

# %%
from pycaret.internal.preprocess.transformers import TransformerWrapper, FixImbalancer

# Initialize experiment setup for the second experiment
smote = ClassificationExperiment()
smote.setup(
    experiment_name='SMOTE Resampling', 
    custom_pipeline=[
        ('pipeline', pipeline),
        ('resampling', TransformerWrapper(transformer=FixImbalancer(SMOTE(random_state=42))))
    ], 
    data=df, target='Claim', preprocess=False, train_size=0.8, session_id=123)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3a01a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a01a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3a01a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a01a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a01a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3a01a_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_3a01a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3a01a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3a01a_row1_col1" class="data row1 col1" >Claim</td>
#     </tr>
#     <tr>
#       <th id="T_3a01a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3a01a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3a01a_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_3a01a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3a01a_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_3a01a_row3_col1" class="data row3 col1" >(31025, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_3a01a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3a01a_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_3a01a_row4_col1" class="data row4 col1" >(54991, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_3a01a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3a01a_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_3a01a_row5_col1" class="data row5 col1" >(48786, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_3a01a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3a01a_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_3a01a_row6_col1" class="data row6 col1" >(6205, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_3a01a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3a01a_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_3a01a_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_3a01a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3a01a_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_3a01a_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#   </tbody>
# </table>

# %%
experimentmodel2 = smote.compare_models(n_select=5, sort='Recall')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             22:20:24
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <style type="text/css">
# #T_a8af3 th {
#   text-align: left;
# }
# #T_a8af3_row0_col0, #T_a8af3_row0_col1, #T_a8af3_row0_col2, #T_a8af3_row0_col4, #T_a8af3_row0_col5, #T_a8af3_row0_col6, #T_a8af3_row0_col7, #T_a8af3_row1_col0, #T_a8af3_row1_col1, #T_a8af3_row1_col3, #T_a8af3_row1_col4, #T_a8af3_row1_col5, #T_a8af3_row1_col6, #T_a8af3_row1_col7, #T_a8af3_row2_col0, #T_a8af3_row2_col1, #T_a8af3_row2_col2, #T_a8af3_row2_col3, #T_a8af3_row2_col4, #T_a8af3_row2_col5, #T_a8af3_row2_col6, #T_a8af3_row2_col7, #T_a8af3_row3_col0, #T_a8af3_row3_col1, #T_a8af3_row3_col2, #T_a8af3_row3_col3, #T_a8af3_row3_col4, #T_a8af3_row3_col5, #T_a8af3_row3_col6, #T_a8af3_row3_col7, #T_a8af3_row4_col0, #T_a8af3_row4_col1, #T_a8af3_row4_col2, #T_a8af3_row4_col3, #T_a8af3_row4_col4, #T_a8af3_row4_col5, #T_a8af3_row4_col6, #T_a8af3_row4_col7, #T_a8af3_row5_col0, #T_a8af3_row5_col1, #T_a8af3_row5_col2, #T_a8af3_row5_col3, #T_a8af3_row5_col4, #T_a8af3_row5_col5, #T_a8af3_row5_col6, #T_a8af3_row6_col0, #T_a8af3_row6_col1, #T_a8af3_row6_col2, #T_a8af3_row6_col3, #T_a8af3_row6_col4, #T_a8af3_row6_col5, #T_a8af3_row6_col6, #T_a8af3_row6_col7, #T_a8af3_row7_col0, #T_a8af3_row7_col1, #T_a8af3_row7_col2, #T_a8af3_row7_col3, #T_a8af3_row7_col4, #T_a8af3_row7_col5, #T_a8af3_row7_col6, #T_a8af3_row7_col7, #T_a8af3_row8_col0, #T_a8af3_row8_col1, #T_a8af3_row8_col2, #T_a8af3_row8_col3, #T_a8af3_row8_col4, #T_a8af3_row8_col5, #T_a8af3_row8_col6, #T_a8af3_row8_col7, #T_a8af3_row9_col0, #T_a8af3_row9_col1, #T_a8af3_row9_col2, #T_a8af3_row9_col3, #T_a8af3_row9_col4, #T_a8af3_row9_col5, #T_a8af3_row9_col6, #T_a8af3_row9_col7, #T_a8af3_row10_col0, #T_a8af3_row10_col1, #T_a8af3_row10_col2, #T_a8af3_row10_col3, #T_a8af3_row10_col4, #T_a8af3_row10_col5, #T_a8af3_row10_col6, #T_a8af3_row10_col7, #T_a8af3_row11_col0, #T_a8af3_row11_col1, #T_a8af3_row11_col2, #T_a8af3_row11_col3, #T_a8af3_row11_col7, #T_a8af3_row12_col0, #T_a8af3_row12_col1, #T_a8af3_row12_col2, #T_a8af3_row12_col3, #T_a8af3_row12_col4, #T_a8af3_row12_col5, #T_a8af3_row12_col6, #T_a8af3_row12_col7, #T_a8af3_row13_col0, #T_a8af3_row13_col1, #T_a8af3_row13_col2, #T_a8af3_row13_col3, #T_a8af3_row13_col4, #T_a8af3_row13_col5, #T_a8af3_row13_col6, #T_a8af3_row13_col7, #T_a8af3_row14_col0, #T_a8af3_row14_col1, #T_a8af3_row14_col2, #T_a8af3_row14_col3, #T_a8af3_row14_col4, #T_a8af3_row14_col5, #T_a8af3_row14_col6, #T_a8af3_row14_col7, #T_a8af3_row15_col0, #T_a8af3_row15_col2, #T_a8af3_row15_col3, #T_a8af3_row15_col4, #T_a8af3_row15_col5, #T_a8af3_row15_col6, #T_a8af3_row15_col7 {
#   text-align: left;
# }
# #T_a8af3_row0_col3, #T_a8af3_row1_col2, #T_a8af3_row5_col7, #T_a8af3_row11_col4, #T_a8af3_row11_col5, #T_a8af3_row11_col6, #T_a8af3_row15_col1 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a8af3_row0_col8, #T_a8af3_row2_col8, #T_a8af3_row3_col8, #T_a8af3_row4_col8, #T_a8af3_row5_col8, #T_a8af3_row6_col8, #T_a8af3_row7_col8, #T_a8af3_row8_col8, #T_a8af3_row9_col8, #T_a8af3_row10_col8, #T_a8af3_row11_col8, #T_a8af3_row12_col8, #T_a8af3_row13_col8, #T_a8af3_row14_col8, #T_a8af3_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_a8af3_row1_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a8af3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8af3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a8af3_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a8af3_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a8af3_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a8af3_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a8af3_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a8af3_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a8af3_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_a8af3_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8af3_level0_row0" class="row_heading level0 row0" >qda</th>
#       <td id="T_a8af3_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_a8af3_row0_col1" class="data row0 col1" >0.7439</td>
#       <td id="T_a8af3_row0_col2" class="data row0 col2" >0.7697</td>
#       <td id="T_a8af3_row0_col3" class="data row0 col3" >0.7188</td>
#       <td id="T_a8af3_row0_col4" class="data row0 col4" >0.0501</td>
#       <td id="T_a8af3_row0_col5" class="data row0 col5" >0.0933</td>
#       <td id="T_a8af3_row0_col6" class="data row0 col6" >0.0631</td>
#       <td id="T_a8af3_row0_col7" class="data row0 col7" >0.1414</td>
#       <td id="T_a8af3_row0_col8" class="data row0 col8" >0.0880</td>
#     </tr>
#     <tr>
#       <th id="T_a8af3_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_a8af3_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_a8af3_row1_col1" class="data row1 col1" >0.7996</td>
#       <td id="T_a8af3_row1_col2" class="data row1 col2" >0.8043</td>
#       <td id="T_a8af3_row1_col3" class="data row1 col3" >0.7025</td>
#       <td id="T_a8af3_row1_col4" class="data row1 col4" >0.0583</td>
#       <td id="T_a8af3_row1_col5" class="data row1 col5" >0.1077</td>
#       <td id="T_a8af3_row1_col6" class="data row1 col6" >0.0784</td>
#       <td id="T_a8af3_row1_col7" class="data row1 col7" >0.1617</td>
#       <td id="T_a8af3_row1_col8" class="data row1 col8" >0.0630</td>
#     </tr>
#     <tr>
#       <th id="T_a8af3_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_a8af3_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_a8af3_row2_col1" class="data row2 col1" >0.8189</td>
#       <td id="T_a8af3_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_a8af3_row2_col3" class="data row2 col3" >0.6650</td>
#       <td id="T_a8af3_row2_col4" class="data row2 col4" >0.0613</td>
#       <td id="T_a8af3_row2_col5" class="data row2 col5" >0.1122</td>
#       <td id="T_a8af3_row2_col6" class="data row2 col6" >0.0833</td>
#       <td id="T_a8af3_row2_col7" class="data row2 col7" >0.1624</td>
#       <td id="T_a8af3_row2_col8" class="data row2 col8" >0.0710</td>
#     </tr>
#     <tr>
#       <th id="T_a8af3_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_a8af3_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_a8af3_row3_col1" class="data row3 col1" >0.8189</td>
#       <td id="T_a8af3_row3_col2" class="data row3 col2" >0.8008</td>
#       <td id="T_a8af3_row3_col3" class="data row3 col3" >0.6650</td>
#       <td id="T_a8af3_row3_col4" class="data row3 col4" >0.0613</td>
#       <td id="T_a8af3_row3_col5" class="data row3 col5" >0.1122</td>
#       <td id="T_a8af3_row3_col6" class="data row3 col6" >0.0833</td>
#       <td id="T_a8af3_row3_col7" class="data row3 col7" >0.1623</td>
#       <td id="T_a8af3_row3_col8" class="data row3 col8" >0.0780</td>
#     </tr>
#     <tr>
#       <th id="T_a8af3_level0_row4" class="row_heading level0 row4" >nb</th>
#       <td id="T_a8af3_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_a8af3_row4_col1" class="data row4 col1" >0.7942</td>
#       <td id="T_a8af3_row4_col2" class="data row4 col2" >0.7495</td>
#       <td id="T_a8af3_row4_col3" class="data row4 col3" >0.6556</td>
#       <td id="T_a8af3_row4_col4" class="data row4 col4" >0.0539</td>
#       <td id="T_a8af3_row4_col5" class="data row4 col5" >0.0995</td>
#       <td id="T_a8af3_row4_col6" class="data row4 col6" >0.0699</td>
#       <td id="T_a8af3_row4_col7" class="data row4 col7" >0.1447</td>
#       <td id="T_a8af3_row4_col8" class="data row4 col8" >0.0900</td>
#     </tr>
#     <tr>
#       <th id="T_a8af3_level0_row5" class="row_heading level0 row5" >svm</th>
#       <td id="T_a8af3_row5_col0" class="data row5 col0" >SVM - Linear Kernel</td>
#       <td id="T_a8af3_row5_col1" class="data row5 col1" >0.8445</td>
#       <td id="T_a8af3_row5_col2" class="data row5 col2" >0.0000<
# Processing:   0%|          | 0/73 [00:00<?, ?it/s]

# %% [markdown]
# Create a model from the three best SMOTE compare results based on recall value.

# %%
qda_smote = smote.create_model(experimentmodel2[0])
lr_smote = smote.create_model(experimentmodel2[1])
ridge_smote = smote.create_model(experimentmodel2[2])
# Out:
# <style type="text/css">
# #T_c7b27_row10_col0, #T_c7b27_row10_col1, #T_c7b27_row10_col2, #T_c7b27_row10_col3, #T_c7b27_row10_col4, #T_c7b27_row10_col5, #T_c7b27_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_c7b27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7b27_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_c7b27_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_c7b27_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_c7b27_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_c7b27_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_c7b27_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_c7b27_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7b27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7b27_row0_col0" class="data row0 col0" >0.6785</td>
#       <td id="T_c7b27_row0_col1" class="data row0 col1" >0.7528</td>
#       <td id="T_c7b27_row0_col2" class="data row0 col2" >0.6905</td>
#       <td id="T_c7b27_row0_col3" class="data row0 col3" >0.0356</td>
#       <td id="T_c7b27_row0_col4" class="data row0 col4" >0.0678</td>
#       <td id="T_c7b27_row0_col5" class="data row0 col5" >0.0368</td>
#       <td id="T_c7b27_row0_col6" class="data row0 col6" >0.1013</td>
#     </tr>
#     <tr>
#       <th id="T_c7b27_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7b27_row1_col0" class="data row1 col0" >0.7470</td>
#       <td id="T_c7b27_row1_col1" class="data row1 col1" >0.7538</td>
#       <td id="T_c7b27_row1_col2" class="data row1 col2" >0.7143</td>
#       <td id="T_c7b27_row1_col3" class="data row1 col3" >0.0464</td>
#       <td id="T_c7b27_row1_col4" class="data row1 col4" >0.0872</td>
#       <td id="T_c7b27_row1_col5" class="data row1 col5" >0.0573</td>
#       <td id="T_c7b27_row1_col6" class="data row1 col6" >0.1358</td>
#     </tr>
#     <tr>
#       <th id="T_c7b27_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c7b27_row2_col0" class="data row2 col0" >0.8292</td>
#       <td id="T_c7b27_row2_col1" class="data row2 col1" >0.7941</td>
#       <td id="T_c7b27_row2_col2" class="data row2 col2" >0.6905</td>
#       <td id="T_c7b27_row2_col3" class="data row2 col3" >0.0659</td>
#       <td id="T_c7b27_row2_col4" class="data row2 col4" >0.1203</td>
#       <td id="T_c7b27_row2_col5" class="data row2 col5" >0.0923</td>
#       <td id="T_c7b27_row2_col6" class="data row2 col6" >0.1763</td>
#     </tr>
#     <tr>
#       <th id="T_c7b27_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c7b27_row3_col0" class="data row3 col0" >0.7889</td>
#       <td id="T_c7b27_row3_col1" class="data row3 col1" >0.7785</td>
#       <td id="T_c7b27_row3_col2" class="data row3 col2" >0.6744</td>
#       <td id="T_c7b27_row3_col3" class="data row3 col3" >0.0538</td>
#       <td id="T_c7b27_row3_col4" class="data row3 col4" >0.0997</td>
#       <td id="T_c7b27_row3_col5" class="data row3 col5" >0.0698</td>
#       <td id="T_c7b27_row3_col6" class="data row3 col6" >0.1473</td>
#     </tr>
#     <tr>
#       <th id="T_c7b27_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c7b27_row4_col0" class="data row4 col0" >0.6358</td>
#       <td id="T_c7b27_row4_col1" class="data row4 col1" >0.7359</td>
#       <td id="T_c7b27_row4_col2" class="data row4 col2" >0.6977</td>
#       <td id="T_c7b27_row4_col3" class="data row4 col3" >0.0326</td>
#       <td id="T_c7b27_row4_col4" class="data row4 col4" >0.0622</td>
#       <td id="T_c7b27_row4_col5" class="data row4 col5" >0.0301</td>
#       <td id="T_c7b27_row4_col6" class="data row4 col6" >0.0898</td>
#     </tr>
#     <tr>
#       <th id="T_c7b27_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c7b27_row5_col0" class="data row5 col0" >0.8376</td>
#       <td id="T_c7b27_row5_col1" class="data row5 col1" >0.8228</td>
#       <td id="T_c7b27_row5_col2" class="data row5 col2" >0.7907</td>
#       <td id="T_c7b27_row5_col3" class="data row5 col3" >0.0794</td>
#       <td id="T_c7b27_row5_col4" class="data row5 col4" >0.1444</td>
#       <td id="T_c7b27_row5_col5" class="data row5 col5" >0.1166</td>
#       <td id="T_c7b27_row5_col6" class="data row5 col6" >0.2173</td>
#     </tr>
#     <tr>
#       <th id="T_c7b27_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c7b27_row6_col0" class="data row6 col0" >0.7691</td>
#       <td id="T_c7b27_row6_col1" class="data row6 col1" >0.7426</td>
#       <td id="T_c7b27_row6_col2" class="data row6 col2" >0.6279</td>
#       <td id="T_c7b27_row6_col3" class="data row6 col3" >0.0462</td>
#       <td id="T_c7b27_row6_col4" class="data row6 col4" >0.0861</td>
#       <td id="T_c7b27_row6_col5" class="data row6 col5" >0.0556</td>
#       <td id="T_c7b27_row6_col6" class="data row6 col6" >0.1229</td>
#     </tr>
#     <tr>
#       <th id="T_c7b27_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c7b27_row7_col0" class="data row7 col0" >0.6805</td>
#       <td id="T_c7b27_row7_col1" class="data row7 col1" >0.7533</td>
#       <td id="T_c7b27_row7_col2" class="data row7 col2" >0.7674</td>
#       <td id="T_c7b27_row7_col3" class="data row7 col3" >0.0404</td>
#       <td id="T_c7b27_row7_col4" class="data row7 col4" >0.0768</td>
#       <td id="T_c7b27_row7_col5" class="data row7 col5" >0.0454</td>
#       <td id="T_c7b27_row7_col6" class="data row7 col6" >0.1240</td>
#     </tr>
#     <tr>
#       <th id="T_c7b27_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c7b27_row8_col0" class="data row8 col0" >0.6950</td>
#       <td id="T_c7b27_row8_col1" class="data row8 col1" >0.7750</td>
#       <td id="T_c7b27_row8_col2" class="data row8 col2" >0.7209</td>
#       <td id="T_c7b27_row8_col3" class="data row8 col3" >0.0399</td>
#       <td id="T_c7b27_row8_col4" class="data row8 col4" >0.0757</td>
#       <td id="T_c7b27_row8_col5" class="data row8 col5" >0.0443</td>
#       <td id="T_c7b27_row8_col6" class="data row8 col6" >0.1169</td>
#     </tr>
#     <tr>
#       <th id="T_c7b27_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c7b27_row9_col0" class="data row9 col0" >0.7776</td>
#       <td id="T_c7b27_row9_col1" class="data row9 col1" >0.7880</td>
#       <td id="T_c7b27_row9_col2" class="data row9 col2" >0.8140</td>
#       <td id="T_c7b27_row9_col3" class="data row9 col3" >0.0604</td>
#       <td id="T_c7b27_row9_col4" class="data row9 col4" >0.1125</td>
#       <td id="T_c7b27_row9_col5" class="data row9 col5" >0.0830</td>
#       <td id="T_c7b27_row9_col6" class="data row9 col6" >0.1823</td>
#     </tr>
#     <tr>
#       <th id="T_c7b27_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c7b27_row10_col0" class="data row10 col0" >0.7439</td>
#       <td id="T_c7b27_row10_col1" class="data row10 col1" >0.7697</td>
#       <td id="T_c7b27_row10_col2" class="data row10 col2" >0.7188</td>
#       <td id="T_c7b27_row10_col3" class="data row10 col3" >0.0501</td>
#       <td id="T_c7b27_row10_col4" class="data row10 col4" >0.0933</td>
#       <td id="T_c7b27_row10_col5" class="data row10 col5" >0.0631</td>
#       <td id="T_c7b27_row10_col6" class="data row10 col6" >0.1414</td>
#     </tr>
#     <tr>
#       <th id="T_c7b27_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c7b27_row11_col0" class="data row11 col0" >0.0650</td>
#       <td id="T_c7b27_row11_col1" class="data row11 col1" >0.0256</td>
#       <td id="T_c7b27_row11_col2" class="data row11 col2" >0.0538</td>
#       <td id="T_c7b27_row11_col3" class="data row11 col3" >0.0140</td>
#       <td id="T_c7b27_row11_col4
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# <style type="text/css">
# #T_9f844_row10_col0, #T_9f844_row10_col1, #T_9f844_row10_col2, #T_9f844_row10_col3, #T_9f844_row10_col4, #T_9f844_row10_col5, #T_9f844_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9f844">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f844_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9f844_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9f844_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9f844_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9f844_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9f844_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9f844_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f844_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9f844_row0_col0" class="data row0 col0" >0.8163</td>
#       <td id="T_9f844_row0_col1" class="data row0 col1" >0.8286</td>
#       <td id="T_9f844_row0_col2" class="data row0 col2" >0.6667</td>
#       <td id="T_9f844_row0_col3" class="data row0 col3" >0.0596</td>
#       <td id="T_9f844_row0_col4" class="data row0 col4" >0.1094</td>
#       <td id="T_9f844_row0_col5" class="data row0 col5" >0.0808</td>
#       <td id="T_9f844_row0_col6" class="data row0 col6" >0.1598</td>
#     </tr>
#     <tr>
#       <th id="T_9f844_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9f844_row1_col0" class="data row1 col0" >0.8022</td>
#       <td id="T_9f844_row1_col1" class="data row1 col1" >0.7933</td>
#       <td id="T_9f844_row1_col2" class="data row1 col2" >0.6905</td>
#       <td id="T_9f844_row1_col3" class="data row1 col3" >0.0572</td>
#       <td id="T_9f844_row1_col4" class="data row1 col4" >0.1056</td>
#       <td id="T_9f844_row1_col5" class="data row1 col5" >0.0768</td>
#       <td id="T_9f844_row1_col6" class="data row1 col6" >0.1582</td>
#     </tr>
#     <tr>
#       <th id="T_9f844_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9f844_row2_col0" class="data row2 col0" >0.7917</td>
#       <td id="T_9f844_row2_col1" class="data row2 col1" >0.8332</td>
#       <td id="T_9f844_row2_col2" class="data row2 col2" >0.7381</td>
#       <td id="T_9f844_row2_col3" class="data row2 col3" >0.0577</td>
#       <td id="T_9f844_row2_col4" class="data row2 col4" >0.1071</td>
#       <td id="T_9f844_row2_col5" class="data row2 col5" >0.0781</td>
#       <td id="T_9f844_row2_col6" class="data row2 col6" >0.1662</td>
#     </tr>
#     <tr>
#       <th id="T_9f844_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9f844_row3_col0" class="data row3 col0" >0.7990</td>
#       <td id="T_9f844_row3_col1" class="data row3 col1" >0.7817</td>
#       <td id="T_9f844_row3_col2" class="data row3 col2" >0.6744</td>
#       <td id="T_9f844_row3_col3" class="data row3 col3" >0.0564</td>
#       <td id="T_9f844_row3_col4" class="data row3 col4" >0.1041</td>
#       <td id="T_9f844_row3_col5" class="data row3 col5" >0.0745</td>
#       <td id="T_9f844_row3_col6" class="data row3 col6" >0.1531</td>
#     </tr>
#     <tr>
#       <th id="T_9f844_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9f844_row4_col0" class="data row4 col0" >0.7998</td>
#       <td id="T_9f844_row4_col1" class="data row4 col1" >0.7977</td>
#       <td id="T_9f844_row4_col2" class="data row4 col2" >0.6744</td>
#       <td id="T_9f844_row4_col3" class="data row4 col3" >0.0566</td>
#       <td id="T_9f844_row4_col4" class="data row4 col4" >0.1045</td>
#       <td id="T_9f844_row4_col5" class="data row4 col5" >0.0749</td>
#       <td id="T_9f844_row4_col6" class="data row4 col6" >0.1536</td>
#     </tr>
#     <tr>
#       <th id="T_9f844_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9f844_row5_col0" class="data row5 col0" >0.7849</td>
#       <td id="T_9f844_row5_col1" class="data row5 col1" >0.8148</td>
#       <td id="T_9f844_row5_col2" class="data row5 col2" >0.7209</td>
#       <td id="T_9f844_row5_col3" class="data row5 col3" >0.0561</td>
#       <td id="T_9f844_row5_col4" class="data row5 col4" >0.1040</td>
#       <td id="T_9f844_row5_col5" class="data row5 col5" >0.0743</td>
#       <td id="T_9f844_row5_col6" class="data row5 col6" >0.1589</td>
#     </tr>
#     <tr>
#       <th id="T_9f844_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9f844_row6_col0" class="data row6 col0" >0.7905</td>
#       <td id="T_9f844_row6_col1" class="data row6 col1" >0.7613</td>
#       <td id="T_9f844_row6_col2" class="data row6 col2" >0.6512</td>
#       <td id="T_9f844_row6_col3" class="data row6 col3" >0.0525</td>
#       <td id="T_9f844_row6_col4" class="data row6 col4" >0.0972</td>
#       <td id="T_9f844_row6_col5" class="data row6 col5" >0.0673</td>
#       <td id="T_9f844_row6_col6" class="data row6 col6" >0.1411</td>
#     </tr>
#     <tr>
#       <th id="T_9f844_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9f844_row7_col0" class="data row7 col0" >0.8006</td>
#       <td id="T_9f844_row7_col1" class="data row7 col1" >0.7780</td>
#       <td id="T_9f844_row7_col2" class="data row7 col2" >0.7209</td>
#       <td id="T_9f844_row7_col3" class="data row7 col3" >0.0603</td>
#       <td id="T_9f844_row7_col4" class="data row7 col4" >0.1113</td>
#       <td id="T_9f844_row7_col5" class="data row7 col5" >0.0820</td>
#       <td id="T_9f844_row7_col6" class="data row7 col6" >0.1684</td>
#     </tr>
#     <tr>
#       <th id="T_9f844_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9f844_row8_col0" class="data row8 col0" >0.8046</td>
#       <td id="T_9f844_row8_col1" class="data row8 col1" >0.8303</td>
#       <td id="T_9f844_row8_col2" class="data row8 col2" >0.7674</td>
#       <td id="T_9f844_row8_col3" class="data row8 col3" >0.0650</td>
#       <td id="T_9f844_row8_col4" class="data row8 col4" >0.1198</td>
#       <td id="T_9f844_row8_col5" class="data row8 col5" >0.0907</td>
#       <td id="T_9f844_row8_col6" class="data row8 col6" >0.1852</td>
#     </tr>
#     <tr>
#       <th id="T_9f844_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9f844_row9_col0" class="data row9 col0" >0.8062</td>
#       <td id="T_9f844_row9_col1" class="data row9 col1" >0.8239</td>
#       <td id="T_9f844_row9_col2" class="data row9 col2" >0.7209</td>
#       <td id="T_9f844_row9_col3" class="data row9 col3" >0.0620</td>
#       <td id="T_9f844_row9_col4" class="data row9 col4" >0.1142</td>
#       <td id="T_9f844_row9_col5" class="data row9 col5" >0.0850</td>
#       <td id="T_9f844_row9_col6" class="data row9 col6" >0.1720</td>
#     </tr>
#     <tr>
#       <th id="T_9f844_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9f844_row10_col0" class="data row10 col0" >0.7996</td>
#       <td id="T_9f844_row10_col1" class="data row10 col1" >0.8043</td>
#       <td id="T_9f844_row10_col2" class="data row10 col2" >0.7025</td>
#       <td id="T_9f844_row10_col3" class="data row10 col3" >0.0583</td>
#       <td id="T_9f844_row10_col4" class="data row10 col4" >0.1077</td>
#       <td id="T_9f844_row10_col5" class="data row10 col5" >0.0784</td>
#       <td id="T_9f844_row10_col6" class="data row10 col6" >0.1617</td>
#     </tr>
#     <tr>
#       <th id="T_9f844_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_9f844_row11_col0" class="data row11 col0" >0.0085</td>
#       <td id="T_9f844_row11_col1" class="data row11 col1" >0.0241</td>
#       <td id="T_9f844_row11_col2" class="data row11 col2" >0.0348</td>
#       <td id="T_9f844_row11_col3" class="data row11 col3" >0.0033</td>
#       <td id="T_9f844_row11_col4
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# <style type="text/css">
# #T_d65aa_row10_col0, #T_d65aa_row10_col1, #T_d65aa_row10_col2, #T_d65aa_row10_col3, #T_d65aa_row10_col4, #T_d65aa_row10_col5, #T_d65aa_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d65aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d65aa_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_d65aa_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_d65aa_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_d65aa_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_d65aa_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_d65aa_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_d65aa_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d65aa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d65aa_row0_col0" class="data row0 col0" >0.8292</td>
#       <td id="T_d65aa_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_d65aa_row0_col2" class="data row0 col2" >0.6190</td>
#       <td id="T_d65aa_row0_col3" class="data row0 col3" >0.0599</td>
#       <td id="T_d65aa_row0_col4" class="data row0 col4" >0.1092</td>
#       <td id="T_d65aa_row0_col5" class="data row0 col5" >0.0809</td>
#       <td id="T_d65aa_row0_col6" class="data row0 col6" >0.1534</td>
#     </tr>
#     <tr>
#       <th id="T_d65aa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d65aa_row1_col0" class="data row1 col0" >0.8171</td>
#       <td id="T_d65aa_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_d65aa_row1_col2" class="data row1 col2" >0.6190</td>
#       <td id="T_d65aa_row1_col3" class="data row1 col3" >0.0560</td>
#       <td id="T_d65aa_row1_col4" class="data row1 col4" >0.1028</td>
#       <td id="T_d65aa_row1_col5" class="data row1 col5" >0.0740</td>
#       <td id="T_d65aa_row1_col6" class="data row1 col6" >0.1454</td>
#     </tr>
#     <tr>
#       <th id="T_d65aa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d65aa_row2_col0" class="data row2 col0" >0.8062</td>
#       <td id="T_d65aa_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_d65aa_row2_col2" class="data row2 col2" >0.7143</td>
#       <td id="T_d65aa_row2_col3" class="data row2 col3" >0.0601</td>
#       <td id="T_d65aa_row2_col4" class="data row2 col4" >0.1109</td>
#       <td id="T_d65aa_row2_col5" class="data row2 col5" >0.0823</td>
#       <td id="T_d65aa_row2_col6" class="data row2 col6" >0.1680</td>
#     </tr>
#     <tr>
#       <th id="T_d65aa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d65aa_row3_col0" class="data row3 col0" >0.8284</td>
#       <td id="T_d65aa_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_d65aa_row3_col2" class="data row3 col2" >0.6279</td>
#       <td id="T_d65aa_row3_col3" class="data row3 col3" >0.0618</td>
#       <td id="T_d65aa_row3_col4" class="data row3 col4" >0.1125</td>
#       <td id="T_d65aa_row3_col5" class="data row3 col5" >0.0836</td>
#       <td id="T_d65aa_row3_col6" class="data row3 col6" >0.1575</td>
#     </tr>
#     <tr>
#       <th id="T_d65aa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d65aa_row4_col0" class="data row4 col0" >0.8219</td>
#       <td id="T_d65aa_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_d65aa_row4_col2" class="data row4 col2" >0.6279</td>
#       <td id="T_d65aa_row4_col3" class="data row4 col3" >0.0596</td>
#       <td id="T_d65aa_row4_col4" class="data row4 col4" >0.1089</td>
#       <td id="T_d65aa_row4_col5" class="data row4 col5" >0.0797</td>
#       <td id="T_d65aa_row4_col6" class="data row4 col6" >0.1531</td>
#     </tr>
#     <tr>
#       <th id="T_d65aa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d65aa_row5_col0" class="data row5 col0" >0.8131</td>
#       <td id="T_d65aa_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_d65aa_row5_col2" class="data row5 col2" >0.7209</td>
#       <td id="T_d65aa_row5_col3" class="data row5 col3" >0.0642</td>
#       <td id="T_d65aa_row5_col4" class="data row5 col4" >0.1179</td>
#       <td id="T_d65aa_row5_col5" class="data row5 col5" >0.0889</td>
#       <td id="T_d65aa_row5_col6" class="data row5 col6" >0.1765</td>
#     </tr>
#     <tr>
#       <th id="T_d65aa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d65aa_row6_col0" class="data row6 col0" >0.8078</td>
#       <td id="T_d65aa_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_d65aa_row6_col2" class="data row6 col2" >0.6279</td>
#       <td id="T_d65aa_row6_col3" class="data row6 col3" >0.0553</td>
#       <td id="T_d65aa_row6_col4" class="data row6 col4" >0.1017</td>
#       <td id="T_d65aa_row6_col5" class="data row6 col5" >0.0721</td>
#       <td id="T_d65aa_row6_col6" class="data row6 col6" >0.1441</td>
#     </tr>
#     <tr>
#       <th id="T_d65aa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d65aa_row7_col0" class="data row7 col0" >0.8203</td>
#       <td id="T_d65aa_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_d65aa_row7_col2" class="data row7 col2" >0.6744</td>
#       <td id="T_d65aa_row7_col3" class="data row7 col3" >0.0629</td>
#       <td id="T_d65aa_row7_col4" class="data row7 col4" >0.1151</td>
#       <td id="T_d65aa_row7_col5" class="data row7 col5" >0.0861</td>
#       <td id="T_d65aa_row7_col6" class="data row7 col6" >0.1668</td>
#     </tr>
#     <tr>
#       <th id="T_d65aa_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d65aa_row8_col0" class="data row8 col0" >0.8183</td>
#       <td id="T_d65aa_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_d65aa_row8_col2" class="data row8 col2" >0.7442</td>
#       <td id="T_d65aa_row8_col3" class="data row8 col3" >0.0678</td>
#       <td id="T_d65aa_row8_col4" class="data row8 col4" >0.1243</td>
#       <td id="T_d65aa_row8_col5" class="data row8 col5" >0.0955</td>
#       <td id="T_d65aa_row8_col6" class="data row8 col6" >0.1874</td>
#     </tr>
#     <tr>
#       <th id="T_d65aa_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d65aa_row9_col0" class="data row9 col0" >0.8268</td>
#       <td id="T_d65aa_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_d65aa_row9_col2" class="data row9 col2" >0.6744</td>
#       <td id="T_d65aa_row9_col3" class="data row9 col3" >0.0652</td>
#       <td id="T_d65aa_row9_col4" class="data row9 col4" >0.1189</td>
#       <td id="T_d65aa_row9_col5" class="data row9 col5" >0.0901</td>
#       <td id="T_d65aa_row9_col6" class="data row9 col6" >0.1714</td>
#     </tr>
#     <tr>
#       <th id="T_d65aa_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_d65aa_row10_col0" class="data row10 col0" >0.8189</td>
#       <td id="T_d65aa_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_d65aa_row10_col2" class="data row10 col2" >0.6650</td>
#       <td id="T_d65aa_row10_col3" class="data row10 col3" >0.0613</td>
#       <td id="T_d65aa_row10_col4" class="data row10 col4" >0.1122</td>
#       <td id="T_d65aa_row10_col5" class="data row10 col5" >0.0833</td>
#       <td id="T_d65aa_row10_col6" class="data row10 col6" >0.1624</td>
#     </tr>
#     <tr>
#       <th id="T_d65aa_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_d65aa_row11_col0" class="data row11 col0" >0.0077</td>
#       <td id="T_d65aa_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_d65aa_row11_col2" class="data row11 col2" >0.0451</td>
#       <td id="T_d65aa_row11_col3" class="data row11 col3" >0.0037</td>
#       <td id="T_d65aa_row11_col4
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# Having identified the three top-performing models— Quadratic Discriminant Analysis, Logistic Regression, and Ridge Classifier—the next logical step is benchmarking with penalized method.

# %% [markdown]
# #### **Benchmark With Penalized and Resampling Method**

# %% [markdown]
# [Penalized models]((https://www.sciencedirect.com/science/article/pii/S1053811923004044)) solve class imbalance by adjusting the learning algorithm to prioritize the minority class. This approach modifies the loss function, assigning higher penalties for misclassifying minority class instances. Therefore, the third benchmark was carried out using the penalized method.

# %%
from pycaret.classification import ClassificationExperiment
from pycaret.internal.preprocess.transformers import TransformerWrapper, FixImbalancer

# Initialize experiment setup for the third experiment
penalize = ClassificationExperiment()
penalize.setup(
    experiment_name='Penalize Experiment', 
    custom_pipeline=[
        ('pipeline', pipeline),
        ('resampling', TransformerWrapper(transformer=FixImbalancer(SMOTE(random_state=42))))
    ], 
    data=df, target='Claim', preprocess=False, train_size=0.8, session_id=123
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_96f45">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96f45_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_96f45_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96f45_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_96f45_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_96f45_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_96f45_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_96f45_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_96f45_row1_col1" class="data row1 col1" >Claim</td>
#     </tr>
#     <tr>
#       <th id="T_96f45_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_96f45_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_96f45_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_96f45_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_96f45_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_96f45_row3_col1" class="data row3 col1" >(31025, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_96f45_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_96f45_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_96f45_row4_col1" class="data row4 col1" >(54991, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_96f45_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_96f45_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_96f45_row5_col1" class="data row5 col1" >(48786, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_96f45_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_96f45_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_96f45_row6_col1" class="data row6 col1" >(6205, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_96f45_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_96f45_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_96f45_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_96f45_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_96f45_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_96f45_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#   </tbody>
# </table>

# %%
experimentmodel3 = penalize.compare_models(n_select=5, sort='Recall')
# Out:
# <style type="text/css">
# #T_cdcef th {
#   text-align: left;
# }
# #T_cdcef_row0_col0, #T_cdcef_row0_col1, #T_cdcef_row0_col2, #T_cdcef_row0_col4, #T_cdcef_row0_col5, #T_cdcef_row0_col6, #T_cdcef_row0_col7, #T_cdcef_row1_col0, #T_cdcef_row1_col1, #T_cdcef_row1_col2, #T_cdcef_row1_col3, #T_cdcef_row1_col4, #T_cdcef_row1_col5, #T_cdcef_row1_col6, #T_cdcef_row1_col7, #T_cdcef_row2_col0, #T_cdcef_row2_col1, #T_cdcef_row2_col2, #T_cdcef_row2_col3, #T_cdcef_row2_col4, #T_cdcef_row2_col5, #T_cdcef_row2_col6, #T_cdcef_row2_col7, #T_cdcef_row3_col0, #T_cdcef_row3_col1, #T_cdcef_row3_col2, #T_cdcef_row3_col3, #T_cdcef_row3_col4, #T_cdcef_row3_col5, #T_cdcef_row3_col6, #T_cdcef_row3_col7, #T_cdcef_row4_col0, #T_cdcef_row4_col1, #T_cdcef_row4_col2, #T_cdcef_row4_col3, #T_cdcef_row4_col4, #T_cdcef_row4_col5, #T_cdcef_row4_col6, #T_cdcef_row4_col7, #T_cdcef_row5_col0, #T_cdcef_row5_col1, #T_cdcef_row5_col2, #T_cdcef_row5_col3, #T_cdcef_row5_col4, #T_cdcef_row5_col5, #T_cdcef_row5_col6, #T_cdcef_row6_col0, #T_cdcef_row6_col1, #T_cdcef_row6_col3, #T_cdcef_row6_col4, #T_cdcef_row6_col5, #T_cdcef_row6_col6, #T_cdcef_row6_col7, #T_cdcef_row7_col0, #T_cdcef_row7_col1, #T_cdcef_row7_col2, #T_cdcef_row7_col3, #T_cdcef_row7_col4, #T_cdcef_row7_col5, #T_cdcef_row7_col6, #T_cdcef_row7_col7, #T_cdcef_row8_col0, #T_cdcef_row8_col1, #T_cdcef_row8_col2, #T_cdcef_row8_col3, #T_cdcef_row8_col4, #T_cdcef_row8_col5, #T_cdcef_row8_col6, #T_cdcef_row8_col7, #T_cdcef_row9_col0, #T_cdcef_row9_col1, #T_cdcef_row9_col2, #T_cdcef_row9_col3, #T_cdcef_row9_col4, #T_cdcef_row9_col7, #T_cdcef_row10_col0, #T_cdcef_row10_col1, #T_cdcef_row10_col2, #T_cdcef_row10_col3, #T_cdcef_row10_col4, #T_cdcef_row10_col5, #T_cdcef_row10_col6, #T_cdcef_row10_col7, #T_cdcef_row11_col0, #T_cdcef_row11_col1, #T_cdcef_row11_col2, #T_cdcef_row11_col3, #T_cdcef_row11_col4, #T_cdcef_row11_col5, #T_cdcef_row11_col6, #T_cdcef_row11_col7, #T_cdcef_row12_col0, #T_cdcef_row12_col1, #T_cdcef_row12_col2, #T_cdcef_row12_col3, #T_cdcef_row12_col4, #T_cdcef_row12_col5, #T_cdcef_row12_col6, #T_cdcef_row12_col7, #T_cdcef_row13_col0, #T_cdcef_row13_col1, #T_cdcef_row13_col2, #T_cdcef_row13_col3, #T_cdcef_row13_col4, #T_cdcef_row13_col5, #T_cdcef_row13_col6, #T_cdcef_row13_col7, #T_cdcef_row14_col0, #T_cdcef_row14_col1, #T_cdcef_row14_col2, #T_cdcef_row14_col3, #T_cdcef_row14_col5, #T_cdcef_row14_col6, #T_cdcef_row14_col7, #T_cdcef_row15_col0, #T_cdcef_row15_col2, #T_cdcef_row15_col3, #T_cdcef_row15_col4, #T_cdcef_row15_col5, #T_cdcef_row15_col6, #T_cdcef_row15_col7 {
#   text-align: left;
# }
# #T_cdcef_row0_col3, #T_cdcef_row5_col7, #T_cdcef_row6_col2, #T_cdcef_row9_col5, #T_cdcef_row9_col6, #T_cdcef_row14_col4, #T_cdcef_row15_col1 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_cdcef_row0_col8, #T_cdcef_row1_col8, #T_cdcef_row3_col8, #T_cdcef_row4_col8, #T_cdcef_row5_col8, #T_cdcef_row6_col8, #T_cdcef_row7_col8, #T_cdcef_row8_col8, #T_cdcef_row9_col8, #T_cdcef_row10_col8, #T_cdcef_row11_col8, #T_cdcef_row12_col8, #T_cdcef_row13_col8, #T_cdcef_row14_col8, #T_cdcef_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_cdcef_row2_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_cdcef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cdcef_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cdcef_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_cdcef_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_cdcef_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_cdcef_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_cdcef_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_cdcef_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_cdcef_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_cdcef_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdcef_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_cdcef_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_cdcef_row0_col1" class="data row0 col1" >0.7820</td>
#       <td id="T_cdcef_row0_col2" class="data row0 col2" >0.7847</td>
#       <td id="T_cdcef_row0_col3" class="data row0 col3" >0.7050</td>
#       <td id="T_cdcef_row0_col4" class="data row0 col4" >0.0540</td>
#       <td id="T_cdcef_row0_col5" class="data row0 col5" >0.1002</td>
#       <td id="T_cdcef_row0_col6" class="data row0 col6" >0.0705</td>
#       <td id="T_cdcef_row0_col7" class="data row0 col7" >0.1522</td>
#       <td id="T_cdcef_row0_col8" class="data row0 col8" >0.7400</td>
#     </tr>
#     <tr>
#       <th id="T_cdcef_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_cdcef_row1_col0" class="data row1 col0" >Ada Boost Classifier</td>
#       <td id="T_cdcef_row1_col1" class="data row1 col1" >0.7755</td>
#       <td id="T_cdcef_row1_col2" class="data row1 col2" >0.7891</td>
#       <td id="T_cdcef_row1_col3" class="data row1 col3" >0.7027</td>
#       <td id="T_cdcef_row1_col4" class="data row1 col4" >0.0523</td>
#       <td id="T_cdcef_row1_col5" class="data row1 col5" >0.0973</td>
#       <td id="T_cdcef_row1_col6" class="data row1 col6" >0.0675</td>
#       <td id="T_cdcef_row1_col7" class="data row1 col7" >0.1479</td>
#       <td id="T_cdcef_row1_col8" class="data row1 col8" >0.4870</td>
#     </tr>
#     <tr>
#       <th id="T_cdcef_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_cdcef_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_cdcef_row2_col1" class="data row2 col1" >0.7940</td>
#       <td id="T_cdcef_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_cdcef_row2_col3" class="data row2 col3" >0.6956</td>
#       <td id="T_cdcef_row2_col4" class="data row2 col4" >0.0564</td>
#       <td id="T_cdcef_row2_col5" class="data row2 col5" >0.1043</td>
#       <td id="T_cdcef_row2_col6" class="data row2 col6" >0.0749</td>
#       <td id="T_cdcef_row2_col7" class="data row2 col7" >0.1563</td>
#       <td id="T_cdcef_row2_col8" class="data row2 col8" >0.1360</td>
#     </tr>
#     <tr>
#       <th id="T_cdcef_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_cdcef_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_cdcef_row3_col1" class="data row3 col1" >0.7944</td>
#       <td id="T_cdcef_row3_col2" class="data row3 col2" >0.7860</td>
#       <td id="T_cdcef_row3_col3" class="data row3 col3" >0.6956</td>
#       <td id="T_cdcef_row3_col4" class="data row3 col4" >0.0565</td>
#       <td id="T_cdcef_row3_col5" class="data row3 col5" >0.1045</td>
#       <td id="T_cdcef_row3_col6" class="data row3 col6" >0.0750</td>
#       <td id="T_cdcef_row3_col7" class="data row3 col7" >0.1565</td>
#       <td id="T_cdcef_row3_col8" class="data row3 col8" >0.1980</td>
#     </tr>
#     <tr>
#       <th id="T_cdcef_level0_row4" class="row_heading level0 row4" >nb</th>
#       <td id="T_cdcef_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_cdcef_row4_col1" class="data row4 col1" >0.6981</td>
#       <td id="T_cdcef_row4_col2" class="data row4 col2" >0.7495</td>
#       <td id="T_cdcef_row4_col3" class="data row4 col3" >0.6908</td>
#       <td id="T_cdcef_row4_col4" class="data row4 col4" >0.0389</td>
#       <td id="T_cdcef_row4_col5" class="data row4 col5" >0.0737</td>
#       <td id="T_cdcef_row4_col6" class="data row4 col6" >0.0425</td>
#       <td id="T_cdcef_row4_col7" class="data row4 col7" >0.1102</td>
#       <td id="T_cdcef_row4_col8" class="data row4 col8" >0.1550</td>
#     </tr>
#     <tr>
#       <th id="T_cdcef_level0_row5" class="row_heading level0 row5" >svm</th>
#       <td id="T_cdcef_row5_col0" class="data row5 col0" >SVM - Linear Kernel</td>
#       <td id="T_cdcef_row5_col1" class="data row5 col1" >0.8095</td>
#       <td id="T_cdcef_row5_col2" class="data row5 col2" >0.0000</td>
# Processing:   0%|          | 0/73 [00:00<?, ?it/s]

# %% [markdown]
# Because the recall value is still small due to data imbalance, I will use more weighting on smaller class values. Utilizing a class weight ratio of [0:1 to 1:10](https://gking.harvard.edu/files/0s.pdf) is a strategic approach to mitigate the bias towards the majority class in imbalanced datasets. This particular ratio amplifies the cost of misclassifying the minority class, effectively 'penalizing' the model more for errors made on the less represented class. Based on the research of [Hastie, Tibshirani, and Friedman](https://link.springer.com/book/10.1007/978-0-387-84858-7), I will perform these weights on **Logistic Regression and Random Forest classifiers** because they both allow adjusting the weights during model training to address class imbalance.

# %% [markdown]
# Create a model with adjusting class weights.

# %%
lr_pen = penalize.create_model('lr', class_weight={0: 1, 1: 10})
rf_pen = penalize.create_model('rf', class_weight={0: 1, 1: 10})
# Out:
# <style type="text/css">
# #T_d1b04_row10_col0, #T_d1b04_row10_col1, #T_d1b04_row10_col2, #T_d1b04_row10_col3, #T_d1b04_row10_col4, #T_d1b04_row10_col5, #T_d1b04_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d1b04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1b04_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_d1b04_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_d1b04_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_d1b04_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_d1b04_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_d1b04_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_d1b04_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1b04_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d1b04_row0_col0" class="data row0 col0" >0.3171</td>
#       <td id="T_d1b04_row0_col1" class="data row0 col1" >0.8153</td>
#       <td id="T_d1b04_row0_col2" class="data row0 col2" >0.9524</td>
#       <td id="T_d1b04_row0_col3" class="data row0 col3" >0.0231</td>
#       <td id="T_d1b04_row0_col4" class="data row0 col4" >0.0451</td>
#       <td id="T_d1b04_row0_col5" class="data row0 col5" >0.0124</td>
#       <td id="T_d1b04_row0_col6" class="data row0 col6" >0.0726</td>
#     </tr>
#     <tr>
#       <th id="T_d1b04_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d1b04_row1_col0" class="data row1 col0" >0.2893</td>
#       <td id="T_d1b04_row1_col1" class="data row1 col1" >0.7786</td>
#       <td id="T_d1b04_row1_col2" class="data row1 col2" >0.9286</td>
#       <td id="T_d1b04_row1_col3" class="data row1 col3" >0.0217</td>
#       <td id="T_d1b04_row1_col4" class="data row1 col4" >0.0423</td>
#       <td id="T_d1b04_row1_col5" class="data row1 col5" >0.0096</td>
#       <td id="T_d1b04_row1_col6" class="data row1 col6" >0.0598</td>
#     </tr>
#     <tr>
#       <th id="T_d1b04_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d1b04_row2_col0" class="data row2 col0" >0.3030</td>
#       <td id="T_d1b04_row2_col1" class="data row2 col1" >0.7984</td>
#       <td id="T_d1b04_row2_col2" class="data row2 col2" >0.9048</td>
#       <td id="T_d1b04_row2_col3" class="data row2 col3" >0.0215</td>
#       <td id="T_d1b04_row2_col4" class="data row2 col4" >0.0421</td>
#       <td id="T_d1b04_row2_col5" class="data row2 col5" >0.0093</td>
#       <td id="T_d1b04_row2_col6" class="data row2 col6" >0.0561</td>
#     </tr>
#     <tr>
#       <th id="T_d1b04_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d1b04_row3_col0" class="data row3 col0" >0.2909</td>
#       <td id="T_d1b04_row3_col1" class="data row3 col1" >0.7488</td>
#       <td id="T_d1b04_row3_col2" class="data row3 col2" >0.8837</td>
#       <td id="T_d1b04_row3_col3" class="data row3 col3" >0.0212</td>
#       <td id="T_d1b04_row3_col4" class="data row3 col4" >0.0414</td>
#       <td id="T_d1b04_row3_col5" class="data row3 col5" >0.0078</td>
#       <td id="T_d1b04_row3_col6" class="data row3 col6" >0.0478</td>
#     </tr>
#     <tr>
#       <th id="T_d1b04_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d1b04_row4_col0" class="data row4 col0" >0.2913</td>
#       <td id="T_d1b04_row4_col1" class="data row4 col1" >0.7859</td>
#       <td id="T_d1b04_row4_col2" class="data row4 col2" >0.9070</td>
#       <td id="T_d1b04_row4_col3" class="data row4 col3" >0.0217</td>
#       <td id="T_d1b04_row4_col4" class="data row4 col4" >0.0425</td>
#       <td id="T_d1b04_row4_col5" class="data row4 col5" >0.0089</td>
#       <td id="T_d1b04_row4_col6" class="data row4 col6" >0.0546</td>
#     </tr>
#     <tr>
#       <th id="T_d1b04_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d1b04_row5_col0" class="data row5 col0" >0.2631</td>
#       <td id="T_d1b04_row5_col1" class="data row5 col1" >0.7834</td>
#       <td id="T_d1b04_row5_col2" class="data row5 col2" >0.8837</td>
#       <td id="T_d1b04_row5_col3" class="data row5 col3" >0.0204</td>
#       <td id="T_d1b04_row5_col4" class="data row5 col4" >0.0399</td>
#       <td id="T_d1b04_row5_col5" class="data row5 col5" >0.0062</td>
#       <td id="T_d1b04_row5_col6" class="data row5 col6" >0.0410</td>
#     </tr>
#     <tr>
#       <th id="T_d1b04_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d1b04_row6_col0" class="data row6 col0" >0.3235</td>
#       <td id="T_d1b04_row6_col1" class="data row6 col1" >0.7148</td>
#       <td id="T_d1b04_row6_col2" class="data row6 col2" >0.8372</td>
#       <td id="T_d1b04_row6_col3" class="data row6 col3" >0.0211</td>
#       <td id="T_d1b04_row6_col4" class="data row6 col4" >0.0411</td>
#       <td id="T_d1b04_row6_col5" class="data row6 col5" >0.0076</td>
#       <td id="T_d1b04_row6_col6" class="data row6 col6" >0.0427</td>
#     </tr>
#     <tr>
#       <th id="T_d1b04_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d1b04_row7_col0" class="data row7 col0" >0.3074</td>
#       <td id="T_d1b04_row7_col1" class="data row7 col1" >0.7343</td>
#       <td id="T_d1b04_row7_col2" class="data row7 col2" >0.8140</td>
#       <td id="T_d1b04_row7_col3" class="data row7 col3" >0.0200</td>
#       <td id="T_d1b04_row7_col4" class="data row7 col4" >0.0391</td>
#       <td id="T_d1b04_row7_col5" class="data row7 col5" >0.0055</td>
#       <td id="T_d1b04_row7_col6" class="data row7 col6" >0.0321</td>
#     </tr>
#     <tr>
#       <th id="T_d1b04_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d1b04_row8_col0" class="data row8 col0" >0.2756</td>
#       <td id="T_d1b04_row8_col1" class="data row8 col1" >0.8183</td>
#       <td id="T_d1b04_row8_col2" class="data row8 col2" >0.9767</td>
#       <td id="T_d1b04_row8_col3" class="data row8 col3" >0.0228</td>
#       <td id="T_d1b04_row8_col4" class="data row8 col4" >0.0446</td>
#       <td id="T_d1b04_row8_col5" class="data row8 col5" >0.0112</td>
#       <td id="T_d1b04_row8_col6" class="data row8 col6" >0.0715</td>
#     </tr>
#     <tr>
#       <th id="T_d1b04_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d1b04_row9_col0" class="data row9 col0" >0.2788</td>
#       <td id="T_d1b04_row9_col1" class="data row9 col1" >0.7969</td>
#       <td id="T_d1b04_row9_col2" class="data row9 col2" >0.9535</td>
#       <td id="T_d1b04_row9_col3" class="data row9 col3" >0.0224</td>
#       <td id="T_d1b04_row9_col4" class="data row9 col4" >0.0438</td>
#       <td id="T_d1b04_row9_col5" class="data row9 col5" >0.0103</td>
#       <td id="T_d1b04_row9_col6" class="data row9 col6" >0.0653</td>
#     </tr>
#     <tr>
#       <th id="T_d1b04_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_d1b04_row10_col0" class="data row10 col0" >0.2940</td>
#       <td id="T_d1b04_row10_col1" class="data row10 col1" >0.7775</td>
#       <td id="T_d1b04_row10_col2" class="data row10 col2" >0.9042</td>
#       <td id="T_d1b04_row10_col3" class="data row10 col3" >0.0216</td>
#       <td id="T_d1b04_row10_col4" class="data row10 col4" >0.0422</td>
#       <td id="T_d1b04_row10_col5" class="data row10 col5" >0.0089</td>
#       <td id="T_d1b04_row10_col6" class="data row10 col6" >0.0544</td>
#     </tr>
#     <tr>
#       <th id="T_d1b04_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_d1b04_row11_col0" class="data row11 col0" >0.0180</td>
#       <td id="T_d1b04_row11_col1" class="data row11 col1" >0.0326</td>
#       <td id="T_d1b04_row11_col2" class="data row11 col2" >0.0491</td>
#       <td id="T_d1b04_row11_col3" class="data row11 col3" >0.0009</td>
#       <td id="T_d1b04_row11_col4
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# <style type="text/css">
# #T_e3630_row10_col0, #T_e3630_row10_col1, #T_e3630_row10_col2, #T_e3630_row10_col3, #T_e3630_row10_col4, #T_e3630_row10_col5, #T_e3630_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e3630">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3630_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e3630_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_e3630_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e3630_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_e3630_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_e3630_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_e3630_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3630_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3630_row0_col0" class="data row0 col0" >0.8594</td>
#       <td id="T_e3630_row0_col1" class="data row0 col1" >0.6445</td>
#       <td id="T_e3630_row0_col2" class="data row0 col2" >0.2381</td>
#       <td id="T_e3630_row0_col3" class="data row0 col3" >0.0306</td>
#       <td id="T_e3630_row0_col4" class="data row0 col4" >0.0542</td>
#       <td id="T_e3630_row0_col5" class="data row0 col5" >0.0250</td>
#       <td id="T_e3630_row0_col6" class="data row0 col6" >0.0413</td>
#     </tr>
#     <tr>
#       <th id="T_e3630_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e3630_row1_col0" class="data row1 col0" >0.8437</td>
#       <td id="T_e3630_row1_col1" class="data row1 col1" >0.7052</td>
#       <td id="T_e3630_row1_col2" class="data row1 col2" >0.3571</td>
#       <td id="T_e3630_row1_col3" class="data row1 col3" >0.0399</td>
#       <td id="T_e3630_row1_col4" class="data row1 col4" >0.0718</td>
#       <td id="T_e3630_row1_col5" class="data row1 col5" >0.0426</td>
#       <td id="T_e3630_row1_col6" class="data row1 col6" >0.0753</td>
#     </tr>
#     <tr>
#       <th id="T_e3630_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e3630_row2_col0" class="data row2 col0" >0.8562</td>
#       <td id="T_e3630_row2_col1" class="data row2 col1" >0.7237</td>
#       <td id="T_e3630_row2_col2" class="data row2 col2" >0.3810</td>
#       <td id="T_e3630_row2_col3" class="data row2 col3" >0.0461</td>
#       <td id="T_e3630_row2_col4" class="data row2 col4" >0.0823</td>
#       <td id="T_e3630_row2_col5" class="data row2 col5" >0.0537</td>
#       <td id="T_e3630_row2_col6" class="data row2 col6" >0.0912</td>
#     </tr>
#     <tr>
#       <th id="T_e3630_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e3630_row3_col0" class="data row3 col0" >0.8533</td>
#       <td id="T_e3630_row3_col1" class="data row3 col1" >0.6235</td>
#       <td id="T_e3630_row3_col2" class="data row3 col2" >0.2558</td>
#       <td id="T_e3630_row3_col3" class="data row3 col3" >0.0321</td>
#       <td id="T_e3630_row3_col4" class="data row3 col4" >0.0570</td>
#       <td id="T_e3630_row3_col5" class="data row3 col5" >0.0270</td>
#       <td id="T_e3630_row3_col6" class="data row3 col6" >0.0453</td>
#     </tr>
#     <tr>
#       <th id="T_e3630_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e3630_row4_col0" class="data row4 col0" >0.8683</td>
#       <td id="T_e3630_row4_col1" class="data row4 col1" >0.7565</td>
#       <td id="T_e3630_row4_col2" class="data row4 col2" >0.5581</td>
#       <td id="T_e3630_row4_col3" class="data row4 col3" >0.0723</td>
#       <td id="T_e3630_row4_col4" class="data row4 col4" >0.1280</td>
#       <td id="T_e3630_row4_col5" class="data row4 col5" >0.1004</td>
#       <td id="T_e3630_row4_col6" class="data row4 col6" >0.1655</td>
#     </tr>
#     <tr>
#       <th id="T_e3630_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e3630_row5_col0" class="data row5 col0" >0.8727</td>
#       <td id="T_e3630_row5_col1" class="data row5 col1" >0.7278</td>
#       <td id="T_e3630_row5_col2" class="data row5 col2" >0.4419</td>
#       <td id="T_e3630_row5_col3" class="data row5 col3" >0.0611</td>
#       <td id="T_e3630_row5_col4" class="data row5 col4" >0.1073</td>
#       <td id="T_e3630_row5_col5" class="data row5 col5" >0.0793</td>
#       <td id="T_e3630_row5_col6" class="data row5 col6" >0.1270</td>
#     </tr>
#     <tr>
#       <th id="T_e3630_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e3630_row6_col0" class="data row6 col0" >0.8602</td>
#       <td id="T_e3630_row6_col1" class="data row6 col1" >0.5747</td>
#       <td id="T_e3630_row6_col2" class="data row6 col2" >0.2558</td>
#       <td id="T_e3630_row6_col3" class="data row6 col3" >0.0337</td>
#       <td id="T_e3630_row6_col4" class="data row6 col4" >0.0596</td>
#       <td id="T_e3630_row6_col5" class="data row6 col5" >0.0299</td>
#       <td id="T_e3630_row6_col6" class="data row6 col6" >0.0489</td>
#     </tr>
#     <tr>
#       <th id="T_e3630_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e3630_row7_col0" class="data row7 col0" >0.8429</td>
#       <td id="T_e3630_row7_col1" class="data row7 col1" >0.6975</td>
#       <td id="T_e3630_row7_col2" class="data row7 col2" >0.5349</td>
#       <td id="T_e3630_row7_col3" class="data row7 col3" >0.0585</td>
#       <td id="T_e3630_row7_col4" class="data row7 col4" >0.1055</td>
#       <td id="T_e3630_row7_col5" class="data row7 col5" >0.0767</td>
#       <td id="T_e3630_row7_col6" class="data row7 col6" >0.1370</td>
#     </tr>
#     <tr>
#       <th id="T_e3630_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e3630_row8_col0" class="data row8 col0" >0.8574</td>
#       <td id="T_e3630_row8_col1" class="data row8 col1" >0.6721</td>
#       <td id="T_e3630_row8_col2" class="data row8 col2" >0.3256</td>
#       <td id="T_e3630_row8_col3" class="data row8 col3" >0.0413</td>
#       <td id="T_e3630_row8_col4" class="data row8 col4" >0.0733</td>
#       <td id="T_e3630_row8_col5" class="data row8 col5" >0.0439</td>
#       <td id="T_e3630_row8_col6" class="data row8 col6" >0.0731</td>
#     </tr>
#     <tr>
#       <th id="T_e3630_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e3630_row9_col0" class="data row9 col0" >0.8634</td>
#       <td id="T_e3630_row9_col1" class="data row9 col1" >0.6720</td>
#       <td id="T_e3630_row9_col2" class="data row9 col2" >0.3256</td>
#       <td id="T_e3630_row9_col3" class="data row9 col3" >0.0432</td>
#       <td id="T_e3630_row9_col4" class="data row9 col4" >0.0763</td>
#       <td id="T_e3630_row9_col5" class="data row9 col5" >0.0471</td>
#       <td id="T_e3630_row9_col6" class="data row9 col6" >0.0769</td>
#     </tr>
#     <tr>
#       <th id="T_e3630_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_e3630_row10_col0" class="data row10 col0" >0.8577</td>
#       <td id="T_e3630_row10_col1" class="data row10 col1" >0.6797</td>
#       <td id="T_e3630_row10_col2" class="data row10 col2" >0.3674</td>
#       <td id="T_e3630_row10_col3" class="data row10 col3" >0.0459</td>
#       <td id="T_e3630_row10_col4" class="data row10 col4" >0.0815</td>
#       <td id="T_e3630_row10_col5" class="data row10 col5" >0.0526</td>
#       <td id="T_e3630_row10_col6" class="data row10 col6" >0.0881</td>
#     </tr>
#     <tr>
#       <th id="T_e3630_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_e3630_row11_col0" class="data row11 col0" >0.0090</td>
#       <td id="T_e3630_row11_col1" class="data row11 col1" >0.0516</td>
#       <td id="T_e3630_row11_col2" class="data row11 col2" >0.1074</td>
#       <td id="T_e3630_row11_col3" class="data row11 col3" >0.0131</td>
#       <td id="T_e3630_row11_col4
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# Having identified the top-performing models based on recall value; Logistic Regression and Random Forest Classifier. The next logical step is comparing the top eight models from the previous benchmark.

# %% [markdown]
# #### **Compare the Top Eight Models**

# %% [markdown]
# | Model                            | Technique   | Accuracy |    AUC | Recall | Precision |    F1 | Kappa  |   MCC | TT (Sec) |
# |----------------------------------|-------------|----------|--------|--------|-----------|-------|--------|-------|----------|
# | Logistic Regression              | Penalized   |  0.0975  | 0.7999 | 0.9719 |   0.0182  | 0.0357|  0.0020| 0.0258|    -     |
# | Quadratic Discriminant Analysis  | SMOTE       |  0.7266  | 0.7526 | 0.7118 |   0.0492  | 0.0914|  0.0612| 0.1355|  0.1710  |
# | Logistic Regression              | SMOTE       |  0.7996  | 0.8043 | 0.7025 |   0.0584  | 0.1078|  0.0785| 0.1617|  0.5240  |
# | Logistic Regression              | ADASYN      |  0.7941  | 0.8047 | 0.6978 |   0.0565  | 0.1045|  0.0751| 0.1569|  1.2640  |
# | Ridge Classifier                 | ADASYN      |  0.8135  | 0.0000 | 0.6697 |   0.0599  | 0.1100|  0.0809| 0.1602|  0.1720  |
# | Linear Discriminant Analysis     | ADASYN      |  0.8134  | 0.8012 | 0.6697 |   0.0599  | 0.1099|  0.0809| 0.1601|  0.2750  |
# | Ridge Classifier                 | SMOTE       |  0.8189  | 0.0000 | 0.6650 |   0.0613  | 0.1122|  0.0833| 0.1624|  0.1860  |
# | Random Forest Classifier         | Penalized   |  0.9039  | 0.6866 | 0.3230 |   0.0613  | 0.1029|  0.0763| 0.1071|    -     |

# %% [markdown]
# After comparing the top eight models, we can choose the best three models based on recall value, and the best three models are logistic regression with penalized and smote, QDA with SMOTE. The next logical step is hyperparameter tuning.

# %% [markdown]
# ### **Hyperparameter Tuning Three Best Model**
#
# [The critical role of hyperparameter tuning in machine learning](​(https://sparkbyexamples.com/machine-learning/hyperparameter-tuning-in-machine-learning/)), emphasizing its importance in defining model behavior and effectiveness, and the standard methods like grid search, random search, and Bayesian optimization used in this process are well-documented in the broader field of machine learning​​​​​. Because of the critical role of hyperparameters, hyperparameter tuning will be carried out, especially on three models, namely logistic regression with penalized and SMOTE, QDA with SMOTE. First step for hyperparameter tuning is set the parameter for penalized logistic regression and Naive Bayes, then use the parameter for tuning the model to optimize the Recall value.

# %%
# Logistic Regression Parameters for Penalized and SMOTE
lr_param = {
    'penalty': ['l2'], 
    'C': [1, 10], 
    'solver': ['lbfgs'], 
    'class_weight': [None, 'balanced'], 
    'l1_ratio': [None] 
}

# QDA Parameters
qda_param = {
    'reg_param': [0.0, 0.1, 0.5, 1.0]
}


# Tuning Penalized Logistic Regression
print('Model 1 (Tuned Penalized Logistic Regression)')
tuned_lr_penalized = penalize.tune_model(
    estimator=lr_pen, 
    custom_grid=lr_param,
    optimize='Recall',
    search_library='scikit-learn',
    search_algorithm='grid',
    choose_better=True,
    verbose=True)

# Tuning Logistic Regression with SMOTE
print('Model 2 (Tuned Logistic Regression with SMOTE)')
tuned_lr_smote = smote.tune_model(
    estimator=lr_smote, 
    custom_grid=lr_param,
    optimize='Recall',
    search_library='scikit-learn',
    search_algorithm='grid',
    choose_better=True,
    verbose=True)

# Tuning Quadratic Discriminant Analysis with SMOTE
print('Model 3 (Tuned QDA with SMOTE)')
tuned_qda_smote = smote.tune_model(
    estimator=qda_smote, 
    custom_grid=qda_param,
    optimize='Recall',
    search_library='scikit-learn',
    search_algorithm='grid',
    choose_better=True,
    verbose=True)
# Out:
# Model 1 (Tuned Penalized Logistic Regression)
# <style type="text/css">
# #T_f4f82_row10_col0, #T_f4f82_row10_col1, #T_f4f82_row10_col2, #T_f4f82_row10_col3, #T_f4f82_row10_col4, #T_f4f82_row10_col5, #T_f4f82_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f4f82">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4f82_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f4f82_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f4f82_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f4f82_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f4f82_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f4f82_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f4f82_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4f82_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f4f82_row0_col0" class="data row0 col0" >0.8163</td>
#       <td id="T_f4f82_row0_col1" class="data row0 col1" >0.8286</td>
#       <td id="T_f4f82_row0_col2" class="data row0 col2" >0.6667</td>
#       <td id="T_f4f82_row0_col3" class="data row0 col3" >0.0596</td>
#       <td id="T_f4f82_row0_col4" class="data row0 col4" >0.1094</td>
#       <td id="T_f4f82_row0_col5" class="data row0 col5" >0.0808</td>
#       <td id="T_f4f82_row0_col6" class="data row0 col6" >0.1598</td>
#     </tr>
#     <tr>
#       <th id="T_f4f82_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f4f82_row1_col0" class="data row1 col0" >0.8022</td>
#       <td id="T_f4f82_row1_col1" class="data row1 col1" >0.7933</td>
#       <td id="T_f4f82_row1_col2" class="data row1 col2" >0.6905</td>
#       <td id="T_f4f82_row1_col3" class="data row1 col3" >0.0572</td>
#       <td id="T_f4f82_row1_col4" class="data row1 col4" >0.1056</td>
#       <td id="T_f4f82_row1_col5" class="data row1 col5" >0.0768</td>
#       <td id="T_f4f82_row1_col6" class="data row1 col6" >0.1582</td>
#     </tr>
#     <tr>
#       <th id="T_f4f82_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f4f82_row2_col0" class="data row2 col0" >0.7917</td>
#       <td id="T_f4f82_row2_col1" class="data row2 col1" >0.8332</td>
#       <td id="T_f4f82_row2_col2" class="data row2 col2" >0.7381</td>
#       <td id="T_f4f82_row2_col3" class="data row2 col3" >0.0577</td>
#       <td id="T_f4f82_row2_col4" class="data row2 col4" >0.1071</td>
#       <td id="T_f4f82_row2_col5" class="data row2 col5" >0.0781</td>
#       <td id="T_f4f82_row2_col6" class="data row2 col6" >0.1662</td>
#     </tr>
#     <tr>
#       <th id="T_f4f82_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f4f82_row3_col0" class="data row3 col0" >0.7990</td>
#       <td id="T_f4f82_row3_col1" class="data row3 col1" >0.7817</td>
#       <td id="T_f4f82_row3_col2" class="data row3 col2" >0.6744</td>
#       <td id="T_f4f82_row3_col3" class="data row3 col3" >0.0564</td>
#       <td id="T_f4f82_row3_col4" class="data row3 col4" >0.1041</td>
#       <td id="T_f4f82_row3_col5" class="data row3 col5" >0.0745</td>
#       <td id="T_f4f82_row3_col6" class="data row3 col6" >0.1531</td>
#     </tr>
#     <tr>
#       <th id="T_f4f82_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f4f82_row4_col0" class="data row4 col0" >0.7998</td>
#       <td id="T_f4f82_row4_col1" class="data row4 col1" >0.7977</td>
#       <td id="T_f4f82_row4_col2" class="data row4 col2" >0.6744</td>
#       <td id="T_f4f82_row4_col3" class="data row4 col3" >0.0566</td>
#       <td id="T_f4f82_row4_col4" class="data row4 col4" >0.1045</td>
#       <td id="T_f4f82_row4_col5" class="data row4 col5" >0.0749</td>
#       <td id="T_f4f82_row4_col6" class="data row4 col6" >0.1536</td>
#     </tr>
#     <tr>
#       <th id="T_f4f82_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f4f82_row5_col0" class="data row5 col0" >0.7849</td>
#       <td id="T_f4f82_row5_col1" class="data row5 col1" >0.8148</td>
#       <td id="T_f4f82_row5_col2" class="data row5 col2" >0.7209</td>
#       <td id="T_f4f82_row5_col3" class="data row5 col3" >0.0561</td>
#       <td id="T_f4f82_row5_col4" class="data row5 col4" >0.1040</td>
#       <td id="T_f4f82_row5_col5" class="data row5 col5" >0.0743</td>
#       <td id="T_f4f82_row5_col6" class="data row5 col6" >0.1589</td>
#     </tr>
#     <tr>
#       <th id="T_f4f82_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f4f82_row6_col0" class="data row6 col0" >0.7905</td>
#       <td id="T_f4f82_row6_col1" class="data row6 col1" >0.7613</td>
#       <td id="T_f4f82_row6_col2" class="data row6 col2" >0.6512</td>
#       <td id="T_f4f82_row6_col3" class="data row6 col3" >0.0525</td>
#       <td id="T_f4f82_row6_col4" class="data row6 col4" >0.0972</td>
#       <td id="T_f4f82_row6_col5" class="data row6 col5" >0.0673</td>
#       <td id="T_f4f82_row6_col6" class="data row6 col6" >0.1411</td>
#     </tr>
#     <tr>
#       <th id="T_f4f82_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f4f82_row7_col0" class="data row7 col0" >0.8006</td>
#       <td id="T_f4f82_row7_col1" class="data row7 col1" >0.7780</td>
#       <td id="T_f4f82_row7_col2" class="data row7 col2" >0.7209</td>
#       <td id="T_f4f82_row7_col3" class="data row7 col3" >0.0603</td>
#       <td id="T_f4f82_row7_col4" class="data row7 col4" >0.1113</td>
#       <td id="T_f4f82_row7_col5" class="data row7 col5" >0.0820</td>
#       <td id="T_f4f82_row7_col6" class="data row7 col6" >0.1684</td>
#     </tr>
#     <tr>
#       <th id="T_f4f82_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f4f82_row8_col0" class="data row8 col0" >0.8046</td>
#       <td id="T_f4f82_row8_col1" class="data row8 col1" >0.8303</td>
#       <td id="T_f4f82_row8_col2" class="data row8 col2" >0.7674</td>
#       <td id="T_f4f82_row8_col3" class="data row8 col3" >0.0650</td>
#       <td id="T_f4f82_row8_col4" class="data row8 col4" >0.1198</td>
#       <td id="T_f4f82_row8_col5" class="data row8 col5" >0.0907</td>
#       <td id="T_f4f82_row8_col6" class="data row8 col6" >0.1852</td>
#     </tr>
#     <tr>
#       <th id="T_f4f82_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f4f82_row9_col0" class="data row9 col0" >0.8062</td>
#       <td id="T_f4f82_row9_col1" class="data row9 col1" >0.8239</td>
#       <td id="T_f4f82_row9_col2" class="data row9 col2" >0.7209</td>
#       <td id="T_f4f82_row9_col3" class="data row9 col3" >0.0620</td>
#       <td id="T_f4f82_row9_col4" class="data row9 col4" >0.1142</td>
#       <td id="T_f4f82_row9_col5" class="data row9 col5" >0.0850</td>
#       <td id="T_f4f82_row9_col6" class="data row9 col6" >0.1720</td>
#     </tr>
#     <tr>
#       <th id="T_f4f82_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f4f82_row10_col0" class="data row10 col0" >0.7996</td>
#       <td id="T_f4f82_row10_col1" class="data row10 col1" >0.8043</td>
#       <td id="T_f4f82_row10_col2" class="data row10 col2" >0.7025</td>
#       <td id="T_f4f82_row10_col3" class="data row10 col3" >0.0583</td>
#       <td id="T_f4f82_row10_col4" class="data row10 col4" >0.1077</td>
#       <td id="T_f4f82_row10_col5" class="data row10 col5" >0.0784</td>
#       <td id="T_f4f82_row10_col6" class="data row10 col6" >0.1617</td>
#     </tr>
#     <tr>
#       <th id="T_f4f82_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_f4f82_row11_col0" class="data row11 col0" >0.0085</td>
#       <td id="T_f4f82_row11_col1" class="data row11 col1" >0.0241</td>
#       <td id="T_f4f82_row11_col2" class="data row11 col2" >0.0348</td>
#       <td id="T_f4f82_row11_col3" class="data row11 col3" >0.0033</td>
#       <td id="T_f4f82_row11_col4
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# Model 2 (Tuned Logistic Regression with SMOTE)
# <style type="text/css">
# #T_372a7_row10_col0, #T_372a7_row10_col1, #T_372a7_row10_col2, #T_372a7_row10_col3, #T_372a7_row10_col4, #T_372a7_row10_col5, #T_372a7_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_372a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_372a7_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_372a7_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_372a7_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_372a7_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_372a7_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_372a7_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_372a7_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_372a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_372a7_row0_col0" class="data row0 col0" >0.8163</td>
#       <td id="T_372a7_row0_col1" class="data row0 col1" >0.8286</td>
#       <td id="T_372a7_row0_col2" class="data row0 col2" >0.6667</td>
#       <td id="T_372a7_row0_col3" class="data row0 col3" >0.0596</td>
#       <td id="T_372a7_row0_col4" class="data row0 col4" >0.1094</td>
#       <td id="T_372a7_row0_col5" class="data row0 col5" >0.0808</td>
#       <td id="T_372a7_row0_col6" class="data row0 col6" >0.1598</td>
#     </tr>
#     <tr>
#       <th id="T_372a7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_372a7_row1_col0" class="data row1 col0" >0.8022</td>
#       <td id="T_372a7_row1_col1" class="data row1 col1" >0.7933</td>
#       <td id="T_372a7_row1_col2" class="data row1 col2" >0.6905</td>
#       <td id="T_372a7_row1_col3" class="data row1 col3" >0.0572</td>
#       <td id="T_372a7_row1_col4" class="data row1 col4" >0.1056</td>
#       <td id="T_372a7_row1_col5" class="data row1 col5" >0.0768</td>
#       <td id="T_372a7_row1_col6" class="data row1 col6" >0.1582</td>
#     </tr>
#     <tr>
#       <th id="T_372a7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_372a7_row2_col0" class="data row2 col0" >0.7917</td>
#       <td id="T_372a7_row2_col1" class="data row2 col1" >0.8332</td>
#       <td id="T_372a7_row2_col2" class="data row2 col2" >0.7381</td>
#       <td id="T_372a7_row2_col3" class="data row2 col3" >0.0577</td>
#       <td id="T_372a7_row2_col4" class="data row2 col4" >0.1071</td>
#       <td id="T_372a7_row2_col5" class="data row2 col5" >0.0781</td>
#       <td id="T_372a7_row2_col6" class="data row2 col6" >0.1662</td>
#     </tr>
#     <tr>
#       <th id="T_372a7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_372a7_row3_col0" class="data row3 col0" >0.7990</td>
#       <td id="T_372a7_row3_col1" class="data row3 col1" >0.7817</td>
#       <td id="T_372a7_row3_col2" class="data row3 col2" >0.6744</td>
#       <td id="T_372a7_row3_col3" class="data row3 col3" >0.0564</td>
#       <td id="T_372a7_row3_col4" class="data row3 col4" >0.1041</td>
#       <td id="T_372a7_row3_col5" class="data row3 col5" >0.0745</td>
#       <td id="T_372a7_row3_col6" class="data row3 col6" >0.1531</td>
#     </tr>
#     <tr>
#       <th id="T_372a7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_372a7_row4_col0" class="data row4 col0" >0.7998</td>
#       <td id="T_372a7_row4_col1" class="data row4 col1" >0.7977</td>
#       <td id="T_372a7_row4_col2" class="data row4 col2" >0.6744</td>
#       <td id="T_372a7_row4_col3" class="data row4 col3" >0.0566</td>
#       <td id="T_372a7_row4_col4" class="data row4 col4" >0.1045</td>
#       <td id="T_372a7_row4_col5" class="data row4 col5" >0.0749</td>
#       <td id="T_372a7_row4_col6" class="data row4 col6" >0.1536</td>
#     </tr>
#     <tr>
#       <th id="T_372a7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_372a7_row5_col0" class="data row5 col0" >0.7849</td>
#       <td id="T_372a7_row5_col1" class="data row5 col1" >0.8148</td>
#       <td id="T_372a7_row5_col2" class="data row5 col2" >0.7209</td>
#       <td id="T_372a7_row5_col3" class="data row5 col3" >0.0561</td>
#       <td id="T_372a7_row5_col4" class="data row5 col4" >0.1040</td>
#       <td id="T_372a7_row5_col5" class="data row5 col5" >0.0743</td>
#       <td id="T_372a7_row5_col6" class="data row5 col6" >0.1589</td>
#     </tr>
#     <tr>
#       <th id="T_372a7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_372a7_row6_col0" class="data row6 col0" >0.7905</td>
#       <td id="T_372a7_row6_col1" class="data row6 col1" >0.7613</td>
#       <td id="T_372a7_row6_col2" class="data row6 col2" >0.6512</td>
#       <td id="T_372a7_row6_col3" class="data row6 col3" >0.0525</td>
#       <td id="T_372a7_row6_col4" class="data row6 col4" >0.0972</td>
#       <td id="T_372a7_row6_col5" class="data row6 col5" >0.0673</td>
#       <td id="T_372a7_row6_col6" class="data row6 col6" >0.1411</td>
#     </tr>
#     <tr>
#       <th id="T_372a7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_372a7_row7_col0" class="data row7 col0" >0.8006</td>
#       <td id="T_372a7_row7_col1" class="data row7 col1" >0.7780</td>
#       <td id="T_372a7_row7_col2" class="data row7 col2" >0.7209</td>
#       <td id="T_372a7_row7_col3" class="data row7 col3" >0.0603</td>
#       <td id="T_372a7_row7_col4" class="data row7 col4" >0.1113</td>
#       <td id="T_372a7_row7_col5" class="data row7 col5" >0.0820</td>
#       <td id="T_372a7_row7_col6" class="data row7 col6" >0.1684</td>
#     </tr>
#     <tr>
#       <th id="T_372a7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_372a7_row8_col0" class="data row8 col0" >0.8046</td>
#       <td id="T_372a7_row8_col1" class="data row8 col1" >0.8303</td>
#       <td id="T_372a7_row8_col2" class="data row8 col2" >0.7674</td>
#       <td id="T_372a7_row8_col3" class="data row8 col3" >0.0650</td>
#       <td id="T_372a7_row8_col4" class="data row8 col4" >0.1198</td>
#       <td id="T_372a7_row8_col5" class="data row8 col5" >0.0907</td>
#       <td id="T_372a7_row8_col6" class="data row8 col6" >0.1852</td>
#     </tr>
#     <tr>
#       <th id="T_372a7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_372a7_row9_col0" class="data row9 col0" >0.8062</td>
#       <td id="T_372a7_row9_col1" class="data row9 col1" >0.8239</td>
#       <td id="T_372a7_row9_col2" class="data row9 col2" >0.7209</td>
#       <td id="T_372a7_row9_col3" class="data row9 col3" >0.0620</td>
#       <td id="T_372a7_row9_col4" class="data row9 col4" >0.1142</td>
#       <td id="T_372a7_row9_col5" class="data row9 col5" >0.0850</td>
#       <td id="T_372a7_row9_col6" class="data row9 col6" >0.1720</td>
#     </tr>
#     <tr>
#       <th id="T_372a7_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_372a7_row10_col0" class="data row10 col0" >0.7996</td>
#       <td id="T_372a7_row10_col1" class="data row10 col1" >0.8043</td>
#       <td id="T_372a7_row10_col2" class="data row10 col2" >0.7025</td>
#       <td id="T_372a7_row10_col3" class="data row10 col3" >0.0583</td>
#       <td id="T_372a7_row10_col4" class="data row10 col4" >0.1077</td>
#       <td id="T_372a7_row10_col5" class="data row10 col5" >0.0784</td>
#       <td id="T_372a7_row10_col6" class="data row10 col6" >0.1617</td>
#     </tr>
#     <tr>
#       <th id="T_372a7_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_372a7_row11_col0" class="data row11 col0" >0.0085</td>
#       <td id="T_372a7_row11_col1" class="data row11 col1" >0.0241</td>
#       <td id="T_372a7_row11_col2" class="data row11 col2" >0.0348</td>
#       <td id="T_372a7_row11_col3" class="data row11 col3" >0.0033</td>
#       <td id="T_372a7_row11_col4
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# Model 3 (Tuned QDA with SMOTE)
# <style type="text/css">
# #T_0839e_row10_col0, #T_0839e_row10_col1, #T_0839e_row10_col2, #T_0839e_row10_col3, #T_0839e_row10_col4, #T_0839e_row10_col5, #T_0839e_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_0839e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0839e_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_0839e_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_0839e_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_0839e_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_0839e_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_0839e_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_0839e_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0839e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0839e_row0_col0" class="data row0 col0" >0.6785</td>
#       <td id="T_0839e_row0_col1" class="data row0 col1" >0.7528</td>
#       <td id="T_0839e_row0_col2" class="data row0 col2" >0.6905</td>
#       <td id="T_0839e_row0_col3" class="data row0 col3" >0.0356</td>
#       <td id="T_0839e_row0_col4" class="data row0 col4" >0.0678</td>
#       <td id="T_0839e_row0_col5" class="data row0 col5" >0.0368</td>
#       <td id="T_0839e_row0_col6" class="data row0 col6" >0.1013</td>
#     </tr>
#     <tr>
#       <th id="T_0839e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0839e_row1_col0" class="data row1 col0" >0.7470</td>
#       <td id="T_0839e_row1_col1" class="data row1 col1" >0.7538</td>
#       <td id="T_0839e_row1_col2" class="data row1 col2" >0.7143</td>
#       <td id="T_0839e_row1_col3" class="data row1 col3" >0.0464</td>
#       <td id="T_0839e_row1_col4" class="data row1 col4" >0.0872</td>
#       <td id="T_0839e_row1_col5" class="data row1 col5" >0.0573</td>
#       <td id="T_0839e_row1_col6" class="data row1 col6" >0.1358</td>
#     </tr>
#     <tr>
#       <th id="T_0839e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0839e_row2_col0" class="data row2 col0" >0.8292</td>
#       <td id="T_0839e_row2_col1" class="data row2 col1" >0.7941</td>
#       <td id="T_0839e_row2_col2" class="data row2 col2" >0.6905</td>
#       <td id="T_0839e_row2_col3" class="data row2 col3" >0.0659</td>
#       <td id="T_0839e_row2_col4" class="data row2 col4" >0.1203</td>
#       <td id="T_0839e_row2_col5" class="data row2 col5" >0.0923</td>
#       <td id="T_0839e_row2_col6" class="data row2 col6" >0.1763</td>
#     </tr>
#     <tr>
#       <th id="T_0839e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0839e_row3_col0" class="data row3 col0" >0.7889</td>
#       <td id="T_0839e_row3_col1" class="data row3 col1" >0.7785</td>
#       <td id="T_0839e_row3_col2" class="data row3 col2" >0.6744</td>
#       <td id="T_0839e_row3_col3" class="data row3 col3" >0.0538</td>
#       <td id="T_0839e_row3_col4" class="data row3 col4" >0.0997</td>
#       <td id="T_0839e_row3_col5" class="data row3 col5" >0.0698</td>
#       <td id="T_0839e_row3_col6" class="data row3 col6" >0.1473</td>
#     </tr>
#     <tr>
#       <th id="T_0839e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0839e_row4_col0" class="data row4 col0" >0.6358</td>
#       <td id="T_0839e_row4_col1" class="data row4 col1" >0.7359</td>
#       <td id="T_0839e_row4_col2" class="data row4 col2" >0.6977</td>
#       <td id="T_0839e_row4_col3" class="data row4 col3" >0.0326</td>
#       <td id="T_0839e_row4_col4" class="data row4 col4" >0.0622</td>
#       <td id="T_0839e_row4_col5" class="data row4 col5" >0.0301</td>
#       <td id="T_0839e_row4_col6" class="data row4 col6" >0.0898</td>
#     </tr>
#     <tr>
#       <th id="T_0839e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0839e_row5_col0" class="data row5 col0" >0.8376</td>
#       <td id="T_0839e_row5_col1" class="data row5 col1" >0.8228</td>
#       <td id="T_0839e_row5_col2" class="data row5 col2" >0.7907</td>
#       <td id="T_0839e_row5_col3" class="data row5 col3" >0.0794</td>
#       <td id="T_0839e_row5_col4" class="data row5 col4" >0.1444</td>
#       <td id="T_0839e_row5_col5" class="data row5 col5" >0.1166</td>
#       <td id="T_0839e_row5_col6" class="data row5 col6" >0.2173</td>
#     </tr>
#     <tr>
#       <th id="T_0839e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0839e_row6_col0" class="data row6 col0" >0.7691</td>
#       <td id="T_0839e_row6_col1" class="data row6 col1" >0.7426</td>
#       <td id="T_0839e_row6_col2" class="data row6 col2" >0.6279</td>
#       <td id="T_0839e_row6_col3" class="data row6 col3" >0.0462</td>
#       <td id="T_0839e_row6_col4" class="data row6 col4" >0.0861</td>
#       <td id="T_0839e_row6_col5" class="data row6 col5" >0.0556</td>
#       <td id="T_0839e_row6_col6" class="data row6 col6" >0.1229</td>
#     </tr>
#     <tr>
#       <th id="T_0839e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0839e_row7_col0" class="data row7 col0" >0.6805</td>
#       <td id="T_0839e_row7_col1" class="data row7 col1" >0.7533</td>
#       <td id="T_0839e_row7_col2" class="data row7 col2" >0.7674</td>
#       <td id="T_0839e_row7_col3" class="data row7 col3" >0.0404</td>
#       <td id="T_0839e_row7_col4" class="data row7 col4" >0.0768</td>
#       <td id="T_0839e_row7_col5" class="data row7 col5" >0.0454</td>
#       <td id="T_0839e_row7_col6" class="data row7 col6" >0.1240</td>
#     </tr>
#     <tr>
#       <th id="T_0839e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0839e_row8_col0" class="data row8 col0" >0.6950</td>
#       <td id="T_0839e_row8_col1" class="data row8 col1" >0.7750</td>
#       <td id="T_0839e_row8_col2" class="data row8 col2" >0.7209</td>
#       <td id="T_0839e_row8_col3" class="data row8 col3" >0.0399</td>
#       <td id="T_0839e_row8_col4" class="data row8 col4" >0.0757</td>
#       <td id="T_0839e_row8_col5" class="data row8 col5" >0.0443</td>
#       <td id="T_0839e_row8_col6" class="data row8 col6" >0.1169</td>
#     </tr>
#     <tr>
#       <th id="T_0839e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0839e_row9_col0" class="data row9 col0" >0.7776</td>
#       <td id="T_0839e_row9_col1" class="data row9 col1" >0.7880</td>
#       <td id="T_0839e_row9_col2" class="data row9 col2" >0.8140</td>
#       <td id="T_0839e_row9_col3" class="data row9 col3" >0.0604</td>
#       <td id="T_0839e_row9_col4" class="data row9 col4" >0.1125</td>
#       <td id="T_0839e_row9_col5" class="data row9 col5" >0.0830</td>
#       <td id="T_0839e_row9_col6" class="data row9 col6" >0.1823</td>
#     </tr>
#     <tr>
#       <th id="T_0839e_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_0839e_row10_col0" class="data row10 col0" >0.7439</td>
#       <td id="T_0839e_row10_col1" class="data row10 col1" >0.7697</td>
#       <td id="T_0839e_row10_col2" class="data row10 col2" >0.7188</td>
#       <td id="T_0839e_row10_col3" class="data row10 col3" >0.0501</td>
#       <td id="T_0839e_row10_col4" class="data row10 col4" >0.0933</td>
#       <td id="T_0839e_row10_col5" class="data row10 col5" >0.0631</td>
#       <td id="T_0839e_row10_col6" class="data row10 col6" >0.1414</td>
#     </tr>
#     <tr>
#       <th id="T_0839e_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_0839e_row11_col0" class="data row11 col0" >0.0650</td>
#       <td id="T_0839e_row11_col1" class="data row11 col1" >0.0256</td>
#       <td id="T_0839e_row11_col2" class="data row11 col2" >0.0538</td>
#       <td id="T_0839e_row11_col3" class="data row11 col3" >0.0140</td>
#       <td id="T_0839e_row11_col4
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# ### **Model Selection**
# After tuning the best three models, we compared the three models to consider which model to use for the final model.

# %% [markdown]
# #### **Before VS After tuning**

# %% [markdown]
# | Model                            | Technique   | Accuracy |    AUC | Recall | Precision |    F1 | Kappa  |   MCC | TT (Sec) |
# |----------------------------------|-------------|----------|--------|--------|-----------|-------|--------|-------|----------|
# | **Before Tuning**                |             |          |        |        |           |       |        |       |          |
# | Logistic Regression              | Penalized   |  0.0975  | 0.7999 | 0.9719 |   0.0182  | 0.0357|  0.0020| 0.0258|    -     |
# | Quadratic Discriminant Analysis  | SMOTE       |  0.7266  | 0.7526 | 0.7118 |   0.0492  | 0.0914|  0.0612| 0.1355|  0.1710  |
# | Logistic Regression              | SMOTE       |  0.7996  | 0.8043 | 0.7025 |   0.0584  | 0.1078|  0.0785| 0.1617|  0.5240  |
# | **After Tuning**                 |             |          |        |        |           |       |        |       |          |
# | Logistic Regression  | Penalized   |  0.7580  | 0.8017 | 0.7207 |   0.0506  | 0.0946|  0.0641| 0.1454|    -     |
# | Logistic Regression       | SMOTE       |  0.7996  | 0.8043 | 0.7025 |   0.0584  | 0.1078|  0.0785| 0.1617|  0.5240  |
# | QDA                      | SMOTE       |  0.7266  | 0.7526 | 0.7118 |   0.0492  | 0.0914|  0.0612| 0.1355|  0.1710  |

# %% [markdown]
# Insight :
# 1. Logistic Regression (Penalized):
#     - Before Tuning: This model had an exceptionally high recall but very low precision, indicating it could identify most positive cases at the expense of a high false positive rate.
#     - After Tuning: The model's accuracy improved significantly from 9.75% to 75.80%, and the precision increased, indicating a more balanced prediction capability between positive and negative classes. However, this improvement came at the cost of recall, which decreased to 72.07%.
# 2. Quadratic Discriminant Analysis (SMOTE):
#     - Before and After Tuning: There was no change in performance metrics after tuning for QDA with SMOTE. This suggests that the original model's parameters were already optimal or that the tuning process did not find a better set of parameters within the explored search space.
# 3. Logistic Regression (SMOTE):
#     - Before and After Tuning: Similar to QDA with SMOTE, the performance metrics for Logistic Regression with SMOTE remained unchanged after tuning.
#
# In conclusion, while the tuning process has improved the model's accuracy and F1 score, it has done so at the expense of recall. For applications requiring capturing as many positive instances as possible, further model adjustment and tuning would be necessary to improve recall without significantly affecting other performance metrics. **I decided to use the original rather than the tuned model**.

# %% [markdown]
# ### **Determine the Final Model**

# %% [markdown]
# | Model                            | Technique   | Accuracy |    AUC | **Recall** | Precision |    F1 | Kappa  |   MCC |
# |----------------------------------|-------------|----------|--------|--------|-----------|-------|--------|-------|
# | Logistic Regression              | Penalized   |  0.0975  | 0.7999 | **0.9719** |   0.0182  | 0.0357|  0.0020| 0.0258|

# %% [markdown]
# Based on the analysis of the provided performance metrics for the penalized logistic regression model, it is evident that the model demonstrates an exceptionally high recall of 97.19% before tuning. This result indicates that the model is particularly effective at correctly identifying positive cases, a critical advantage in applications where the cost of missing positives is substantial. Thus, prioritizing recall, this pre-tuned penalized logistic regression model could be deemed the most suitable choice for scenarios where catching every possible positive case outweighs the need for precision or overall accuracy.

# %%
# Finalize Model
finalmodel = penalize.finalize_model(lr_pen)

# %% [markdown]
# After determining the final model, next step is to evaluate the model.

# %% [markdown]
# ## **Evaluate Final Model**

# %% [markdown]
# ### **Learning Curve**

# %%
#plot_model with 'learning' plots the learning curve of the model
penalize.plot_model(finalmodel, plot='learning')

# %% [markdown]
# The learning curvve provide for logistic regression show the models peformance in terms of training score and cross validation score as the number of training instance increases.
#
# Insight :
#
# 1. The x-axis represents the number of training instances used to train the model, while the y-axis shows the score, which could be accuracy, F1 score, or another metric.
#
# 2. The graph has two lines: one for the training score (blue) and one for the cross-validation score (green). The training score line starts high and decreases as more training instances are added, suggesting the model fits very well to a small dataset but starts to generalize as more data is added.
#
# 3. The cross-validation score line starts low and increases with more training instances, indicating the model's improving ability to generalize to unseen data as it learns from more examples.
#
# 4. The convergence of the training and cross-validation lines as the number of training instances increases suggests that adding more data helps the model generalize better. However, the fact that the scores are converging at a lower score than the initial training score might indicate a high bias in the model — the model may be too simple to capture the underlying pattern of the data.
#
# 5. If both curves have plateaued, adding more training data may not significantly improve the model's performance. At this point, trying a more complex model or improving the model's features could be beneficial to enhance performance.
#
# 6. Lastly, the gap between the training and cross-validation scores provides information about the model's variance. A small hole indicates low friction, which is good, but as mentioned earlier, the relatively low convergence score could be an issue of high bias.

# %% [markdown]
# ### **ROC Curves**

# %%
from yellowbrick.classifier import roc_auc

visualizer = roc_auc(finalmodel, penalize.get_config('X_test'), penalize.get_config('y_test'))

# %% [markdown]
# 1. Three ROC curves are presented, each corresponding to a different aspect of the model's performance.
# 2. The ROC curve for class 0 (in blue) and class 1 (in green) both have an Area Under Curve (AUC) of 0.78, indicating a good level of separability between positive and negative classes.
# 3. The dashed lines represent micro-average and macro-average ROC curves, with the macro-average having the same AUC as the individual classes (0.78), typically a sign of consistent performance across categories.
# 4. The micro-average ROC curve (in dashed green line) has a significantly lower AUC of 0.14, suggesting that the model could perform better when considering the average performance over all instances.
# 5. The dotted diagonal line represents a no-skill classifier; an ideal model's ROC curve would bow towards the top left corner, away from the diagonal.
#
#
# The summary indicates that the Logistic Regression model can distinguish between the two classes for individual classes but may have inconsistencies when averaged across all instances.

# %% [markdown]
# ## **Prediction on Unseen Data**

# %%
#predict model from finalmodel1 with unseen data
penalize.predict_model(finalmodel, data=unseen)
# Out:
#       Agency    Agency Type Distribution Channel              Product Name  \
# 33427    EPX  Travel Agency               Online         Cancellation Plan
# 10883    JZI       Airlines               Online                Basic Plan
# 6962     EPX  Travel Agency               Online         Cancellation Plan
# 20215    C2B       Airlines               Online               Silver Plan
# 36168    C2B       Airlines               Online               Bronze Plan
# ...      ...            ...                  ...                       ...
# 11125    EPX  Travel Agency               Online  2 way Comprehensive Plan
# 13990    JZI       Airlines               Online                Basic Plan
# 10816    C2B       Airlines               Online               Silver Plan
# 12183    EPX  Travel Agency               Online         Cancellation Plan
# 24422    JZI       Airlines               Online                Basic Plan
#
#        Destination  Net Sales  Commision (in value) Duration Category  \
# 33427    HONG KONG       31.0                  0.00        1-4 months
# 10883  PHILIPPINES       22.0                  7.70        1-4 months
# 6962         JAPAN       41.0                  0.00        1-4 months
# 20215    SINGAPORE       42.0                 10.50        1-4 months
# 36168    SINGAPORE       23.0                  5.75        1-4 months
# ...            ...        ...                   ...               ...
# 11125    SINGAPORE       23.0                  0.00        1-4 months
# 13990     THAILAND       22.0                  7.70        1-4 months
# 10816    SINGAPORE       54.5                 13.63        1-4 months
# 12183     THAILAND       10.0                  0.00        5-8 months
# 24422    HONG KONG       56.0                 19.60        1-4 months
#
#             Age Group  Claim  prediction_label  prediction_score
# 33427           Adult      0                 1            0.7633
# 10883  Pra-Senior Age      0                 0            0.5481
# 6962            Adult      0                 0            0.5070
# 20215           Adult      0                 1            0.9745
# 36168           Adult      0                 1            0.9743
# ...               ...    ...               ...               ...
# 11125           Adult      0                 1            0.8782
# 13990  Pra-Senior Age      0                 1            0.5275
# 10816           Adult      0                 1            0.9792
# 12183           Adult      0                 0            0.5372
# 24422           Adult      0                 1            0.8449
#
# [7757 rows x 12 columns]

# %%
from yellowbrick.classifier import confusion_matrix

X_test = unseen.drop(columns=['Claim'])
y_test = unseen['Claim']

visualizer = confusion_matrix(finalmodel, X_test, y_test, cmap="Greens")

# %% [markdown]
# 1. True Positives (TP): The top-right cell, with the number 6216, represents the cases where the model correctly predicted the positive class.
# 2. True Negatives (TN): The top-left cell, with the number 1407, shows the cases where the model correctly predicted the negative class.
# 3. False Positives (FP): The bottom-left cell, with the number 5, represents the instances where the model incorrectly predicted the positive class.
# 4. False Negatives (FN): The bottom-right cell, with the number 129, shows the cases where the model incorrectly predicted the negative class.
#
# Summary Insight:
# The model has a high number of true positives and true negatives, which suggests it performs well in identifying both classes.
# The number of false negatives is relatively low, which is good as it means the model often needs to identify the positive class.
# The false positives are very low, indicating that the model rarely misclassifies the negative class as positive.
# Overall, the high values of TP and TN and the low values of FP and FN suggest the Logistic Regression model has a good predictive performance for this dataset.
#
#
# - Cost per False Positive (FP):
# Since the total estimated cost for FP is 128.65 million rupiah for 5 FP cases, the cost per FP case remains the same.
#
# - Cost per False Negative (FN):
# With FN cases at 129, we'll recalculate the cost per FN case using the total estimated FN cost of 344.85 million rupiah.
# Finally, we'll calculate the total costs for the 5 FP cases and the 129 FN cases.
#
#
# The cost per False Positive (FP) case is approximately 25.73 million rupiah.
# The cost per False Negative (FN) case, with the updated number of 129 FN cases, is approximately 2.67 million rupiah.
# The total cost for 5 FP cases remains at 128.65 million rupiah.
# The total cost for 129 FN cases remains at 344.85 million rupiah.

# %% [markdown]
# ## **Model Interpretation**

# %%
penalize.plot_model(finalmodel, plot='feature')

# %% [markdown]
# Feature Importance Plot is commonly used in machine learning to visualize the importance of different variables in a predictive model. The vertical axis (y-axis) lists various features used in the model, while the horizontal axis (x-axis) shows the "Variable Importance" of each part. Attributes are ranked from bottom to top, with "Product Name_0" at the bottom, suggesting it has minor importance, and "Distribution Channel_2" at the top, indicating it has the highest priority. The points on the plot represent the importance score for each feature, with scores ranging from 0 to above 6.

# %% [markdown]
# ## Conclusion and Reccomendation
#
# The final model is a logistic regression classifier used for binary classification. It's encapsulated within a pipeline, including data preprocessing steps like encoding categorical variables, scaling numerical data, and cleaning up column names. These preprocessing steps are crucial as they convert raw data into a suitable format for the model to learn from.
#
# The total benefit from correctly predicting True Positives (TP) and True Negatives (TN) is approximately 52.82 billion rupiah.
# After subtracting the costs from False Positives (FP) and False Negatives (FN), the net profit is approximately 52.35 billion rupiah. This results in a profit percentage of approximately 99.10%. This high profit percentage suggests that the model is very effective from a cost-benefit perspective, under the assumption that the value of correctly identifying a TP or TN is equivalent to the cost avoided from an FN or FP, respectively.
#
#
# The model works well when the following conditions are met:
#
# - High Recall: The model has a high recall (98.02%), indicating it is very good at correctly identifying prospective travelers who will make claims (TP). - his is particularly important for the company because the cost associated with FN (potential travelers who make claims but are predicted not to) is higher than for FP. High recall means the model minimizes the loss of potential claimants.
# - Low FP and FN: The absolute numbers of FP and FN are low (5 and 129, respectively), which implies that the model makes very few errors in both predicting claims and non-claims.
# - Cost Savings: The model's performance in terms of recall, combined with the low numbers of FP and FN, leads to substantial cost savings. As calculated, the net profit percentage is very high (approximately 99.10%), indicating the model is cost-effective.
#
# Recommendation:
# 1. Focus on FN Reduction: Given that FNs have a higher cost than FPs, the model should continue to focus on minimizing FN. Strategies could include further feature engineering, collecting more data, or trying different algorithms that may perform better on minimizing FN.
# 2. Model Monitoring and Updating: Regularly monitor the model's performance to ensure that it maintains high recall and low error rates as new data comes in. Update the model periodically to adapt to changing patterns in traveler behavior.
# 3. Cost-Benefit Analysis: Conduct a detailed cost-benefit analysis that includes the financial benefits of TP and TN predictions. This will provide a clearer picture of the model's profitability and inform decisions on whether further improvements are needed.
# 4. Business Strategy Alignment: Ensure that the model's evaluation metrics are aligned with the company's business objectives. If minimizing FN is a priority due to higher costs, continue using recall as the primary metric.
# 5. Expand Data Collection: More data on the actual financial impact of TP and TN predictions can help refine the cost-benefit analysis. Collecting data on customer lifetime value, the cost of claims processing, and the impact of customer satisfaction on retention could be beneficial.
# 6. Cross-Validation: Use cross-validation to test the model's performance on different subsets of the data to ensure its robustness and generalizability.
# 7. Customer Segmentation: Consider using the model's predictions to segment customers into different risk categories, which can then inform targeted marketing and customer service strategies.
# 8. Risk Management: Use the insights from the model to improve risk management practices, potentially by identifying patterns that lead to claims and working to mitigate those risks.
#
# The model's current performance indicates it is doing well in the context of minimizing the more costly FN errors. Any steps taken to improve the model should maintain or improve upon these performance metrics.
